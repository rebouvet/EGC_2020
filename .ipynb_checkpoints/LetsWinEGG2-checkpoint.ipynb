# %%
import nltk
import pandas as pd
import random
import numpy as np
import string
import math

from nltk import ngrams
from nltk.corpus import stopwords
from nltk.stem.snowball import FrenchStemmer
from nltk.tokenize import word_tokenize

from numpy import array
from collections import Counter
from scipy.sparse import csr_matrix

from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
from gensim import corpora, models, utils
from gensim.test.utils import common_corpus, common_dictionary, get_tmpfile
from gensim.models import LsiModel
from gensim.corpora import Dictionary

import re

# %%
# Use spacy lib
# On https://spacy.io/

import spacy
nlp = spacy.load('fr')

# %%
##############
# Parameters #
##############

min_gram = 1
max_gram = 3

# To create ours partitions, we must first know the years which will be the limits
limit_years = [2007, 2010, 2013, 2016]

# Ignore words that appear at a frequency less than max_frequ in the corpus
max_frequ = 0.8

# Ignore words appearing less than min_appear in the whole corpus
min_appear = 5

# Range fo cluster number you want to test
cluster_ranges = range(2, 30) #range(2, 100) # Warning, long to compute

# Number of trial you want to do for each test
nb_trial_by_test = 3

# Number of cluster you finally choose
nb_cluster = 20

# %%
# Datas preprocessing methods.

# Lemmatisation without poncutations

stemmer = nltk.stem.snowball.FrenchStemmer()
fstw = stopwords.words('french')

# French Stop Words, extraits depuis le fichier stopwords-fr.txt + stopwords french de nltk
sourceFST = [x.replace('\n', '') for x in open('stopwords-fr.txt', mode="r", encoding="utf-8").readlines()]+fstw
sourceFST += [x.replace('\n', '') for x in open('perso_words-fr.txt', mode="r", encoding="utf-8").readlines()]

# Based on ration of french and english stopwords
def isEnglish(article):
    total_fsw = len([x for x in article.split() if x in sourceFST])
    total_esw = len([x for x in article.split() if x in stopwords.words('english')])
    ratio = 100
    if total_fsw != 0:
        ratio = total_esw/total_fsw
    return ratio > 1 and total_esw > 3

def lemmatize(article):
    arti_lower = article.lower()
    arti_2words = re.sub(" [0-z][0-z] ", " ", arti_lower) # word of length < 2
    arti_e = re.sub("(é|è|ê)", "e", arti_2words)
    arti_o = re.sub("à", "a", arti_e)
    arti_i = re.sub("ô", "o", arti_o)
    artiregex = re.sub("î", "i", arti_i)
    output = []
    outPonc = artiregex.translate(artiregex.maketrans("","", string.punctuation))
    outLem = nlp(outPonc)
    for token in outLem:
        if token.lemma_ not in sourceFST and [x for x in token.lemma_ if x not in "0123456789"] != []:
            output.append(token.lemma_)
    res = ' '.join(output)
    return res

# %%
# Data Reading
data = pd.read_csv('export_articles_EGC_2004_2018.csv', sep='\t', header=0)

# %%
# Let's process our corpus, and determine a limit to split it in partitions

# usable[] correspond to our corpus processed
# limits[] let us know when to delimit partitions
limits = []
usable = []

prev_year = data['year'][0]
numArti = 0
for i in range(0, len(data['abstract']), 1):
    #if not null, empty, or whatever (so if there is a abstract):
    if not isinstance(data['abstract'][i], float) and not isEnglish(data['abstract'][i]):
        text = data['abstract'][i]
        if not isinstance(data['title'][i], float):
            text += " "+data['title'][i]

        numArti+=1
        usable.append(re.sub(" [0-z][0-z] ", " ", stemmer.stem(lemmatize(text))))
        year = data['year'][i]
        if year != prev_year:
            prev_year = year
            if year in limit_years:
                limits.append(numArti)
limits.append(numArti)

# %%
# Post-process word removal
post_words = [x.replace('\n', '') for x in open('post_process_words-fr.txt', mode="r", encoding="utf-8").readlines()]

for i in range(0, len(usable)):
    arti = usable[i].split()
    res = []
    for word in arti:
        if word not in post_words:
            res.append(word)
    usable[i] = ' '.join(res)

# %%
# Display pre-processed datas

vectorizer = TfidfVectorizer(stop_words=sourceFST, use_idf=True, ngram_range=(min_gram, max_gram), max_df=max_frequ, min_df=min_appear)
tfidf = vectorizer.fit_transform(usable)

print("nombre d'articles =", len(usable))
print("nombre de mots =", len(tfidf.toarray()[0]))
print("limits =", limits)

usable[0]
# Out:
# nombre d'articles = 991
# nombre de mots = 2179
# limits = [114, 301, 468, 694, 991]
# 'plateforme objectif permettre citoyen euxmemer tweet politique devenement specifiqu francepour lelection presidentiell ideo2017 analyser quasitemps reel message candidat fournir principal caracteristiqueslusage lexiqu politique comparaison candidat ideo2017 plateforme citoyen dediee lanalyse tweet evenement polit'

# %%
# Creation of partitions_tfidf[], which give us the TFIDF of each cluster of each partition
# partitions_tfidf[num_partition][num_doc][num_word]
# Beware, num_doc can't be equals to 1091 (max). You have partitions, so every doc aren't in every partitions
# num_word can be found via vectorizer.get_feature_name()
partitions_tfidf = []
beg = 0
for l in limits:
    last = l
    partitions_tfidf.append([list(x) for x in list(tfidf.toarray())[beg:last]])
    beg = l

# %%
vectorizer.get_feature_names()
# Out:
# ['acce',
#  'accessible',
#  'achat',
#  'acquisition',
#  'acquérir',
#  'acteur',
#  'actif',
#  'action',
#  'activite',
#  'actuel',
#  'actuellement',
#  'adapt',
#  'adaptatif',
#  'adaptation',
#  'adapte',
#  'adaptee',
#  'adapter',
#  'adequat',
#  'adn',
#  'adopter',
#  'afc',
#  'affiner',
#  'agent',
#  'agregation',
#  'aid',
#  'aider',
#  'ainsiqu',
#  'ajoutee',
#  'ajouter',
#  'ala',
#  'aleatoir',
#  'algebriqu',
#  'algorithme',
#  'algorithme dapprentissage',
#  'algorithme dextraction',
#  'algorithme efficace',
#  'algorithme fouiller',
#  'algorithme incremental',
#  'algorithmique',
#  'alignement',
#  'alternatif',
#  'amelior',
#  'amelioration',
#  'ameliore',
#  'amelioree',
#  'ameliorer',
#  'ameliorer qualite',
#  'amene',
#  'amont',
#  'analys',
#  'analyse',
#  'analyser',
#  'analyser factoriel',
#  'analyser semantiqu',
#  'analytique',
#  'anne',
#  'annees',
#  'annot',
#  'annotation',
#  'annotation semantiqu',
#  'annoter',
#  'anormal',
#  'anr',
#  'apartir',
#  'apparer',
#  'appartenir',
#  'appel',
#  'appele',
#  'appelee',
#  'appeler',
#  'applicable',
#  'applicatif',
#  'application',
#  'application reell',
#  'appliqu',
#  'applique',
#  'appliquee',
#  'appliquees',
#  'appliquer',
#  'apport',
#  'apporter',
#  'apprehender',
#  'apprendre',
#  'apprentissage',
#  'apprentissage automatique',
#  'apprentissage supervis',
#  'approche',
#  'approche existant',
#  'appropriee',
#  'approprier',
#  'approximatif',
#  'approximation',
#  'arbitraire',
#  'arborescent',
#  'arbre',
#  'arbre decision',
#  'architecturer',
#  'article',
#  'article classification',
#  'article decrit',
#  'article etuder',
#  'article etudie',
#  'article interesser',
#  'article introduire',
#  'article methode',
#  'article methode original',
#  'article methodologie',
#  'article montrer',
#  'article nouvel',
#  'article permettre',
#  'article present',
#  'article present methode',
#  'article presenter',
#  'article presenton',
#  'article traire',
#  'artificiel',
#  'ascendant',
#  'ascendant hierarchiqu',
#  'aspect',
#  'assister',
#  'associ',
#  'association',
#  'associe',
#  'associee',
#  'associeer',
#  'associees',
#  'associer',
#  'assurer',
#  'attaquer',
#  'atteindre',
#  'attention',
#  'attribu',
#  'attribut',
#  'atypique',
#  'augmenter',
#  'automat',
#  'automate',
#  'automatique',
#  'automatiquement',
#  'automatiser',
#  'autoorganisatrice',
#  'autour',
#  'avancee',
#  'avantage',
#  'axe',
#  'axer',
#  'axiome',
#  'baptis',
#  'base',
#  'base donneer',
#  'base relationnel',
#  'baser',
#  'baser dapprentissage',
#  'baser donneer',
#  'baser modele',
#  'baser relationnel',
#  'baser technique',
#  'batch',
#  'bayesien',
#  'bayesien naïf',
#  'bayesienn',
#  'benchmark',
#  'beneficier',
#  'besoin',
#  'biais',
#  'bibliographique',
#  'biclustering',
#  'binaire',
#  'bioinformatique',
#  'biologique',
#  'biomedical',
#  'bloc',
#  'block',
#  'booleenn',
#  'boosting',
#  'born',
#  'bruitees',
#  'brut',
#  'cadrer',
#  'cadrer article',
#  'cadrer classification',
#  'cadrer general',
#  'cadrer lanalyse',
#  'cadrer projet',
#  'cadrer rechercher',
#  'cadrer theoriqu',
#  'cadrer travail',
#  'calcul',
#  'calcul similarite',
#  'calculee',
#  'calculer',
#  'campagne',
#  'cancer',
#  'candidat',
#  'capable',
#  'capacite',
#  'capteur',
#  'capturer',
#  'caracter',
#  'caractere',
#  'caracterisation',
#  'caracterise',
#  'caracteriseer',
#  'caracteriser',
#  'caracteristiqu',
#  'caracteristique',
#  'caracteristiquer',
#  'cart',
#  'carte',
#  'carte autoorganisatrice',
#  'carte topologique',
#  'cartographie',
#  'cartographique',
#  'categorie',
#  'categoriel',
#  'categoriell',
#  'categorisation',
#  'causer',
#  'celer',
#  'cell',
#  'cellule',
#  'centaine',
#  'central',
#  'centree',
#  'centrer',
#  'cesser',
#  'cestadir',
#  'chain',
#  'chaine',
#  'chaine markov',
#  'challenge',
#  'champ',
#  'changement',
#  'charger',
#  'chemin',
#  'chercheur',
#  'choisir',
#  'choix',
#  'choix mesurer',
#  'chronique',
#  'cibl',
#  'cibler',
#  'classe',
#  'classement',
#  'classer',
#  'classificateur',
#  'classification',
#  'classification automatique',
#  'classification document',
#  'classification hierarchiqu',
#  'classification multilabel',
#  'classification supervise',
#  'classification supervisee',
#  'classifier',
#  'classifieur',
#  'classifieur bayesien',
#  'classifieur bayesien naïf',
#  'classique',
#  'cle',
#  'clef',
#  'client',
#  'cluster',
#  'clustering',
#  'coclustering',
#  'codage',
#  'coefficient',
#  'coeur',
#  'cognitif',
#  'coherence',
#  'collaboratif',
#  'collaboration',
#  'collecter',
#  'collectif',
#  'collection',
#  'collection document',
#  'colonne',
#  'combin',
#  'combinaison',
#  'combinatoire',
#  'combiner',
#  'commencer',
#  'commercial',
#  'commun',
#  'communaut',
#  'communautair',
#  'communautaire',
#  'communaute',
#  'communication',
#  'compact',
#  'compacter',
#  'comparaison',
#  'comparatif',
#  'comparee',
#  'comparer',
#  'comparer resultat',
#  'compatible',
#  'competence',
#  'complementair',
#  'complementarite',
#  'complet',
#  'completer',
#  'complex',
#  'complexe',
#  'complexit',
#  'complexite',
#  'comportement',
#  'comportemer',
#  'comporter',
#  'composant',
#  'compose',
#  'composer',
#  'comprehension',
#  'comprendre',
#  'compromis',
#  'compter',
#  'concentrer',
#  'concept',
#  'concept treillis',
#  'concepteur',
#  'conception',
#  'conceptuel',
#  'concerner',
#  'concevoir',
#  'concret',
#  'condensee',
#  'condensees',
#  'condition',
#  'conditionnel',
#  'conduire',
#  'conferenc',
#  'conference',
#  'confiance',
#  'configuration',
#  'confirmer',
#  'conflit',
#  'confronter',
#  'conjoint',
#  'conjointement',
#  'connaissancer',
#  'connaître',
#  'connexion',
#  'connu',
#  'consequent',
#  'conserver',
#  'consider',
#  'considere',
#  'consideree',
#  'considerer',
#  'consist',
#  'consister',
#  'consommation',
#  'constant',
#  'constater',
#  'constituer',
#  'construction',
#  'construction automatique',
#  'construction darbr',
#  'construction dontologie',
#  'construir',
#  'construire',
#  'construire partir',
#  'construit',
#  'construit partir',
#  'contenir',
#  'contenir document',
#  'contenu',
#  'context',
#  'contexte',
#  'contextuel',
#  'contingence',
#  'continu',
#  'continuer',
#  'contraindre',
#  'contraint',
#  'contrainte',
#  'contrairement',
#  'contribuer',
#  'contribution',
#  'controle',
#  'controler',
#  'convergence',
#  'convier',
#  'conçu',
#  'cooperativ',
#  'corpu',
#  'corpus',
#  'correct',
#  'correctement',
#  'correlation',
#  'correspondance',
#  'correspondance afc',
#  'correspondant',
#  'correspondre',
#  'couleur',
#  'coupl',
#  'couple',
#  'coupler',
#  'courir',
#  'courir temps',
#  'cours',
#  'court',
#  'couverture',
#  'couvrir',
#  'coût',
#  'coûteux',
#  'creation',
#  'cree',
#  'creer',
#  'criter',
#  'critere',
#  'critere devaluation',
#  'croisee',
#  'croiser',
#  'croissance',
#  'croyance',
#  'croître',
#  'cube',
#  'cuber',
#  'culturel',
#  'cycle',
#  'dabord',
#  'daccelerer',
#  'dacquisition',
#  'dadapter',
#  'dagregation',
#  'daid',
#  'daid decision',
#  'daider',
#  'dalgorithme',
#  'dalignemer',
#  'dameliorer',
#  'dameliorer performance',
#  'danalyse',
#  'danalyser',
#  'dannotation',
#  'danscet',
#  'danscet article',
#  'dansl',
#  'dansun',
#  'dappariemer',
#  'dapparition',
#  'dappartenance',
#  'dapplication',
#  'dapporter',
#  'dapprendre',
#  'dapprentissage',
#  'dapprentissage automatique',
#  'dapprentissage supervis',
#  'darbr',
#  'darbr decision',
#  'darticl',
#  'dassoci',
#  'dassociation',
#  'dater',
#  'dater mining',
#  'dater stream',
#  'dattribut',
#  'dattributs',
#  'daugmenter',
#  'dautre',
#  'dautre partir',
#  'debut',
#  'decd',
#  'decennie',
#  'dechantillon',
#  'dechantillonnage',
#  'decider',
#  'decideur',
#  'decis',
#  'decision',
#  'decisionnel',
#  'decisionnell',
#  'decomposition',
#  'decoupage',
#  'decouvert',
#  'decouverte',
#  'decouverte motif',
#  'decouvrir',
#  'decouvrir motif',
#  'decrir',
#  'decrire',
#  'decrit',
#  'decrite',
#  'decrivant',
#  'decriver',
#  'decrivons',
#  'dedie',
#  'dediee',
#  'dedition',
#  'dedonnee',
#  'deduire',
#  'defaut',
#  'deffectuer',
#  'defi',
#  'defi egc',
#  'defini',
#  'definie',
#  'definier',
#  'definir',
#  'definis',
#  'definisser',
#  'definit',
#  'definition',
#  'degager',
#  'degr',
#  'degre',
#  'delagage',
#  'delement',
#  'demander',
#  'demarch',
#  'demonstration',
#  'denrichir',
#  'dense',
#  'densembl',
#  'densite',
#  'dentiter',
#  'dentre',
#  'dentrepris',
#  'depart',
#  'dependanc',
#  'dependance',
#  'dependance fonctionnel',
#  'depender',
#  'deper',
#  'dequivalence',
#  'derive',
#  'derreur',
#  'descripteur',
#  'descriptif',
#  'description',
#  'desdonnee',
#  'desequilibre',
#  'destimer',
#  'detablir',
#  'detailler',
#  'detat',
#  'detecter',
#  'detection',
#  'detection changement',
#  'detectiond',
#  'detendre',
#  'determination',
#  'determine',
#  'determiner',
#  'detr',
#  'detre',
#  'detude',
#  'detudier',
#  'deuxieme',
#  'devaluation',
#  'devaluer',
#  'devaluer qualite',
#  'developp',
#  'developpe',
#  'developpee',
#  'developpement',
#  'developpemer',
#  'developper',
#  'devenement',
#  'devenir',
#  'devolution',
#  'dexecution',
#  'dexempl',
#  'dexperience',
#  'dexperimentation',
#  'dexploiter',
#  'dexploration',
#  'dexplorer',
#  'dexpression',
#  'dexprimer',
#  'dextraction',
#  'dextraction motif',
#  'dextraction partir',
#  'dextrair',
#  'dextraire',
#  'dextraire motif',
#  'dheuristiqu',
#  'diagnostic',
#  'dictionnair',
#  'didentification',
#  'didentifier',
#  'difference',
#  'differenter',
#  'difficile',
#  'difficilement',
#  'difficult',
#  'difficulte',
#  'diffusion',
#  'dimag',
#  'dimage',
#  'dimager',
#  'dimension',
#  'dincertitude',
#  'dindexation',
#  'dindice',
#  'dindividus',
#  'dinduction',
#  'dinference',
#  'dinferer',
#  'dinfluence',
#  'dinform',
#  'dinformation',
#  'dintegration',
#  'dintegrer',
#  'dinteraction',
#  'dinteret',
#  'dinternet',
#  'dinterpretation',
#  'dinterrogation',
#  'dintroduir',
#  'direct',
#  'direction',
#  'discret',
#  'discretisation',
#  'discriminant',
#  'discriminanter',
#  'discrimination',
#  'discriminer',
#  'discussion',
#  'discuter',
#  'disponible',
#  'disposer',
#  'dispositif',
#  'disposition',
#  'dissimilarit',
#  'dissimilarite',
#  'distance',
#  'distancer',
#  'distinct',
#  'distinguer',
#  'distribu',
#  'distribuer',
#  'distribution',
#  'ditems',
#  'ditemset',
#  'ditemset frequent',
#  'diversite',
#  'diviser',
#  'dizaine',
#  'dobjet',
#  'dobjets',
#  'dobtenir',
#  'docu',
#  'document',
#  'document textuel',
#  'document xml',
#  'documentaire',
#  'doffr',
#  'domaine',
#  'domaine dapplication',
#  'domaine fouiller',
#  'domaine lapprentissage',
#  'donneer',
#  'donneer article',
#  'donneer luci',
#  'donneer reell',
#  'donneer textuel',
#  'donnees',
#  'donner',
#  'donner resultat',
#  'dontologie',
#  'dontologie partir',
#  'dontologier',
#  'dopinion',
#  'doptimisation',
#  'dordre',
#  'dorigine',
#  'doter',
#  'doutil',
#  'doutils',
#  'duree',
#  'durer',
#  'durer processus',
#  'dusage',
#  'dutilisateur',
#  'dutilisation',
#  'dutiliser',
#  'dynam',
#  'dynamique',
#  'ecd',
#  'echantillon',
#  'echantillonnage',
#  'echell',
#  'echelle',
#  'eclairage',
#  'economiqu',
#  'effectu',
#  'efficace',
#  'efficacement',
#  'efficacite',
#  'effort',
#  'egc',
#  'element',
#  'elev',
#  'eleve',
#  'elevee',
#  'emergent',
#  'empirique',
#  'empiriquement',
#  'employer',
#  'encompte',
#  'encourageant',
#  'encourageant prometteur',
#  'engendrer',
#  'enjeu',
#  'enjeu majeur',
#  'enregistrement',
#  'enrichir',
#  'enrichissement',
#  'ensembl',
#  'ensembl donneer',
#  'ensembl mesure',
#  'ensemble',
#  'ensemble donneer',
#  'ensemble regl',
#  'ensembliste',
#  'entite',
#  'entrainer',
#  'entrepot',
#  'entreprendre',
#  'entreprise',
#  'environnement',
#  'envisageable',
#  'equivalent',
#  'erreur',
#  'espac',
#  'espace',
#  'espacer',
#  'essentiel',
#  'essentiellement',
#  'estim',
#  'estimateur',
#  'estimation',
#  'estimation densite',
#  'estimee',
#  'estimer',
#  'etablie',
#  'etablir',
#  'etablisser',
#  'etape',
#  'etat',
#  'etde',
#  'etendu',
#  'eter',
#  'etiquetage',
#  'etiquete',
#  'etl',
#  'etle',
#  'etroitement',
#  'etude',
#  'etude comparatif',
#  'etude experimental',
#  'etuder',
#  'etudie',
#  'etudiee',
#  'etudier',
#  'euclidien',
#  'evalu',
#  'evaluation',
#  'evalue',
#  'evaluee',
#  'evaluees',
#  'evaluer',
#  'evenement',
#  'evidence',
#  'eviter',
#  'evoluer',
#  'evolution',
#  'evolutiv',
#  'exact',
#  'examiner',
#  'exemple',
#  'exhaustif',
#  'exhiber',
#  'existant',
#  'exister',
#  'experience',
#  'experience meneer',
#  'experience montrer',
#  'experiment',
#  'experimental',
#  'experimentalement',
#  'experimentation',
#  'experimentation jeu',
#  'experimentation menee',
#  'experimentation montrer',
#  'experimentaux',
#  'experimentaux montrer',
#  'expert',
#  'expert domaine',
#  'explicatif',
#  'expliciter',
#  'expliquer',
#  'exploitable',
#  'exploitation',
#  'exploiter',
#  'exploration',
#  'exploratoire',
#  'explorer',
#  'exponentiel',
#  'exposer',
#  'expression',
#  'exprimeer',
#  'exprimer',
#  'extension',
#  'extraction',
#  'extraction motif',
#  'extraction regl',
#  'extraire',
#  'extraire motif',
#  'extrait',
#  'extraite',
#  'face',
#  'facile',
#  'facilement',
#  'faciliter',
#  'facteur',
#  'factoriel',
#  'factoriel correspondance',
#  'factoriel correspondance afc',
#  'factorisation',
#  'faible',
#  'faire',
#  'faire appel',
#  'faire face',
#  'faire lobjet',
#  'faire partir',
#  'faisabilite',
#  'famille',
#  'favoriser',
#  'feature',
#  'ferme',
#  'ferme frequent',
#  'fiabilite',
#  'fiable',
#  'fichier',
#  'filtrage',
#  'filtrer',
#  'fin',
#  'final',
#  'finalement',
#  'financier',
#  'fixe',
#  'fixer',
#  'flexible',
#  'flot',
#  'flot donneer',
#  'flou',
#  'flouer',
#  'flux',
#  'flux donneer',
#  'focaliser',
#  'fonction',
#  'fonction croyance',
#  'fonctionnalite',
#  'fonctionnel',
#  'fonctionnement',
#  'fonctionner',
#  'fond',
#  'fondamental',
#  'fondee',
#  'fondre',
#  'foret',
#  'foret aleatoir',
#  'formalisation',
#  'formaliser',
#  'formalisme',
#  'format',
#  'formation',
#  'forme',
#  'formel',
#  'formel concept',
#  'former',
#  'former regl',
#  'formulation',
#  'formuler',
#  'fort',
#  'fortement',
#  'fouill',
#  'fouill donneer',
#  'fouiller',
#  'fouiller donneer',
#  'fouiller grand',
#  'fouiller texter',
#  'fournir',
#  'framework',
#  'france',
#  'français',
#  'frequence',
#  'frequent',
#  'frequente',
#  'fusion',
#  'futur',
#  'gain',
#  'galoi',
#  'garantir',
#  'gene',
#  'gener',
#  'general',
#  'generalement',
#  'generalisation',
#  'generalise',
#  'generaliser',
#  'generalist',
#  'generateur',
#  'generatif',
#  'generation',
#  'genere',
#  'generee',
#  'generees',
#  'generer',
#  'generiqu',
#  'genetiqu',
#  'genre',
#  'geographiqu',
#  'gerer',
#  'gestion',
#  'gestion flux',
#  'gestion flux donneer',
#  'global',
#  'graduel',
#  'grammaire',
#  'grand',
#  'grand base',
#  'grand base donneer',
#  'grand echelle',
#  'grand ensembl',
#  'grand graphe',
#  'grand nombre',
#  'grand quantite',
#  'grand tailler',
#  'grand volume',
#  'granularite',
#  'graph',
#  'graph voisinage',
#  'graphe',
#  'graphe conceptuel',
#  'graphe voisinage',
#  'grapher',
#  'graphique',
#  'griller',
#  'gros',
#  'groupe',
#  'groupement',
#  'grouper',
#  'grâce',
#  'grâce algorithme',
#  'guid',
#  'guidee',
#  'guider',
#  'habituellement',
#  'heterogen',
#  'heterogener',
#  'heuristique',
#  'hierarchi',
#  'hierarchie',
#  'hierarchiqu',
#  'historique',
#  'homogen',
#  'humain',
#  'hybride',
#  'hypothese',
#  'idee',
#  'identification',
#  'identifier',
#  'ignorer',
#  'iii',
#  'illustree',
#  'illustrer',
#  'image',
#  'imager',
#  'impact',
#  'implement',
#  'implementation',
#  'implemente',
#  'implicatif',
#  'implicitement',
#  'impliqu',
#  'impliquer',
#  'importance',
#  'important',
#  'importer',
#  'imposer',
#  'impossible',
#  'inclure',
#  'inconvenient',
#  'incremental',
#  'independamment',
#  'independant',
#  'index',
#  'indicateur',
#  'indice',
#  'indiquer',
#  'indispensable',
#  'individu',
#  'individuel',
#  'inductif',
#  'induire',
#  'induit',
#  'industriel',
#  ...]

# %% [markdown]
# # KMeans & Silhouette Score

# %%
# Applying KMeans on tfidf
# the labels_ give assignment of doc to the cluster number

# %%
# doc_clustering is a dictionnary 
# it looks like -> { doc_number : [partition_number, cluster_number] }
# This is used to reassign doc number to their respective partition and and cluster

def kmeans(nb_clusters):
    doc_clustering = {}
    
    km = KMeans(n_clusters=nb_clusters)

    # Silhouette score mean
    silhouette_mean = 0

    numDoc = 0
    for i in range(0, len(limits)):
        dash = km.fit(partitions_tfidf[i])

        # Silhouette
        silhouette_mean += silhouette_score(partitions_tfidf[i], dash.labels_)

        previousBound = 0
        if i > 0:
            previousBound = limits[i-1]
        for numDocItern in range(0, limits[i]-previousBound):
            doc_clustering[numDoc] = [i, dash.labels_[numDocItern]]
            numDoc+=1

    silhouette_mean = silhouette_mean / len(limits)
    res = {}
    res["silhouette"] = silhouette_mean
    res["clustering"] = doc_clustering
    return res

# %%
# Compute Silhouette Score for each number of cluster

silhouette_by_cluster_nb = {}

for nb_clusters in cluster_ranges:
    print(nb_clusters, "...")
    silhouette_avg = 0
    for trial in range(0, nb_trial_by_test):
        km = kmeans(nb_clusters)
        silhouette_avg += km["silhouette"]
    silhouette_avg = silhouette_avg / nb_trial_by_test
    silhouette_by_cluster_nb[nb_clusters] = silhouette_avg

# %%
# We want silhouette scores to be high
silhouette_by_cluster_nb
# Out:
# {2: 0.0054740282018152404,
#  3: 0.006202259322154819,
#  4: 0.006725961699797772,
#  5: 0.008169104093096841,
#  6: 0.00828100132576603,
#  7: 0.009184458258625803,
#  8: 0.010909682485213327,
#  9: 0.011348909716331816,
#  10: 0.011971638000757205,
#  11: 0.013293378793811804,
#  12: 0.014073248869127752,
#  13: 0.0150240180771855,
#  14: 0.01572429432104498,
#  15: 0.01610935106746842,
#  16: 0.01688550832616915,
#  17: 0.01836280137123844,
#  18: 0.01835095394447015,
#  19: 0.01856607041523305,
#  20: 0.019836531712235834,
#  21: 0.0204573754363408,
#  22: 0.021957673884057338,
#  23: 0.022114850786949705,
#  24: 0.023708963360473456,
#  25: 0.02292860478401154,
#  26: 0.02469598510885628,
#  27: 0.024747128902277357,
#  28: 0.024223158756226992,
#  29: 0.024972287911091778,
#  30: 0.02617201920145228,
#  31: 0.026254724044693135,
#  32: 0.027081426737909295,
#  33: 0.026805582575231995,
#  34: 0.027976835560019852,
#  35: 0.028197244378355663,
#  36: 0.028112067900477464,
#  37: 0.029732948382706226,
#  38: 0.029476715025836663,
#  39: 0.030483684056777382,
#  40: 0.030232185905962227,
#  41: 0.03037173015955416,
#  42: 0.030349315699187803,
#  43: 0.03180248721150072,
#  44: 0.03152911110338427,
#  45: 0.032038783111770365,
#  46: 0.032029884248231395,
#  47: 0.03222241762101345,
#  48: 0.03215597965255612,
#  49: 0.033026082605319064,
#  50: 0.034010099699202524,
#  51: 0.03296223673762453,
#  52: 0.034106411920720454,
#  53: 0.033436291791640704,
#  54: 0.034579970378473275,
#  55: 0.03510104482866874,
#  56: 0.03507416928598542,
#  57: 0.035130516576930025,
#  58: 0.03569071445188183,
#  59: 0.03596615599414522,
#  60: 0.03601601854641482,
#  61: 0.03648279155442342,
#  62: 0.03469529050993117,
#  63: 0.03652263795770574,
#  64: 0.03597410100176422,
#  65: 0.03695588855526068,
#  66: 0.036573891212247446,
#  67: 0.03696078170540586,
#  68: 0.03762600001989192,
#  69: 0.0369926999733572,
#  70: 0.036820363139793144,
#  71: 0.03722587024006991,
#  72: 0.03711360730883296,
#  73: 0.03734343178269825,
#  74: 0.037937098689178876,
#  75: 0.03749180692526444,
#  76: 0.037801637416241755,
#  77: 0.03793343199998345,
#  78: 0.037392358141359806,
#  79: 0.03743368450446359,
#  80: 0.03851382751297905,
#  81: 0.038053457890554365,
#  82: 0.037791722796574244,
#  83: 0.03806584613812383,
#  84: 0.03754964323645536,
#  85: 0.03801727744766533,
#  86: 0.03795117916066985,
#  87: 0.03785106445036817,
#  88: 0.037130283603613944,
#  89: 0.03704022761182917,
#  90: 0.0376329102218489,
#  91: 0.036953487807058996,
#  92: 0.03703214040408758,
#  93: 0.03666299874177648,
#  94: 0.03754833876340382,
#  95: 0.03715517130010223,
#  96: 0.037360694817417335,
#  97: 0.03644325313098815,
#  98: 0.036906594821019774,
#  99: 0.03666805103943998}

# %%
doc_clustering = kmeans(nb_cluster)["clustering"]

# %%
# Allows to get list of documents number
# return [dou numbers]
# params : partition_number , cluster number
def get_doc(part, clust):
    docs = []
    for i in range(0,len(doc_clustering)):
        if doc_clustering[i][0] == part and doc_clustering[i][1] == clust:
            docs.append(i)
    return docs

# %%
# Get the partitions variable
# Here partitions[part][cluster] = list of docs numbe
partitions = []
for i in range(0, len(limits)):
    clusters = []
    for j in range(0, nb_clusters):
        clusters.append(get_doc(i,j))
    partitions.append(clusters)

# %%
partitions
# Out:
# [[[6, 47, 50, 96, 102],
#   [10, 15, 33, 70, 87],
#   [7, 67, 97, 112],
#   [31, 74, 79, 103, 109],
#   [12, 41, 92, 108],
#   [35, 43, 44, 53, 80],
#   [9, 23, 38, 49, 57, 78, 94, 98],
#   [0, 25, 26, 76, 77, 81, 105],
#   [3, 4, 62, 63, 68],
#   [22, 27, 37, 55, 86, 110],
#   [14, 48, 54, 82, 84, 100],
#   [19, 34, 42, 56, 83, 88, 113],
#   [39, 40, 52, 58, 65, 72, 91, 106],
#   [1, 59, 60, 69, 89],
#   [8, 13, 24, 45, 64, 90],
#   [18, 73],
#   [16, 17, 32, 66, 71, 101],
#   [11, 20, 21, 36, 46, 93, 99],
#   [2, 28, 29, 51, 95, 104],
#   [5, 30, 61, 75, 85, 107, 111],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []],
#  [[148, 177, 238, 278],
#   [158, 169, 214, 215, 251, 264, 293],
#   [125,
#    128,
#    129,
#    138,
#    146,
#    157,
#    162,
#    171,
#    192,
#    204,
#    231,
#    255,
#    257,
#    259,
#    262,
#    274,
#    279,
#    286,
#    300],
#   [121, 145, 200, 203, 210, 218, 236, 239, 296],
#   [118, 167, 175, 185, 189, 190, 201, 207, 248, 249, 292, 297],
#   [153, 155, 156, 186, 209, 232, 268, 281],
#   [168, 174, 194, 197, 199, 224, 225, 229, 230, 250, 269],
#   [144, 191, 246, 271],
#   [160, 206, 217, 227, 233, 272, 277],
#   [130, 170, 208, 260, 263, 275, 282, 284],
#   [137, 195, 222, 223, 240],
#   [115, 123, 149, 176, 253, 280, 299],
#   [124, 142, 228, 234, 242, 245, 276],
#   [119, 122, 134, 205, 219, 221, 226, 237, 247, 256, 265, 267, 270, 273],
#   [116, 117, 126, 127, 131, 161, 164, 166, 294],
#   [135, 136, 141, 150, 181, 193, 198, 202, 241, 243, 252, 290],
#   [152, 163, 165, 178, 180, 184, 187, 212, 213, 287, 298],
#   [120, 132, 139, 140, 154, 172, 182, 183, 196, 216, 235, 254, 261, 285, 291],
#   [133, 151, 159, 179, 220, 283, 288, 295],
#   [114, 143, 147, 173, 188, 211, 244, 258, 266, 289],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []],
#  [[302, 355, 361, 365, 416, 447, 449],
#   [356, 390, 392, 408, 417, 455],
#   [321, 394, 415, 424, 437],
#   [328, 329, 340, 371, 388, 393, 400, 405, 422, 429, 438, 441, 442],
#   [322, 334, 339, 342, 344, 352, 367, 381, 382, 384, 402, 411, 426, 454, 462],
#   [311, 312, 320, 372, 398, 419, 423, 427, 428, 431, 443],
#   [336, 345, 409, 414],
#   [314, 338, 368, 375, 376, 401, 461],
#   [305, 354, 380, 463],
#   [310, 331, 387, 395, 435, 458, 465],
#   [308, 349, 359, 436, 440, 451, 467],
#   [315, 318, 325, 333, 347, 373, 386, 421, 439, 460, 464],
#   [301, 313, 319, 366, 396, 425, 430, 445, 450],
#   [337, 350, 383, 391, 432, 452],
#   [303,
#    304,
#    306,
#    341,
#    353,
#    362,
#    370,
#    374,
#    399,
#    406,
#    407,
#    418,
#    434,
#    444,
#    453,
#    456],
#   [309, 316, 317, 326, 327, 335, 369, 379, 404, 413, 433, 459],
#   [324, 348, 351, 385, 420],
#   [307, 332, 343, 346, 360, 364, 397, 446, 466],
#   [330, 357, 358, 389, 403, 412, 448],
#   [323, 363, 377, 378, 410, 457],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []],
#  [[482,
#    483,
#    506,
#    517,
#    534,
#    553,
#    558,
#    560,
#    576,
#    578,
#    581,
#    584,
#    596,
#    601,
#    605,
#    606,
#    610,
#    622,
#    625,
#    656,
#    674,
#    675,
#    678,
#    680,
#    682,
#    683,
#    684,
#    687,
#    691],
#   [468, 484, 499, 513, 515, 518, 538, 554, 572, 594, 632],
#   [575, 583, 585, 586, 638, 658, 667],
#   [472, 501, 537, 551, 609, 613, 635, 688],
#   [471, 477, 481, 514, 579, 608, 636, 637, 645, 654, 665, 668],
#   [476, 521, 527, 547, 555, 589, 597, 623, 639, 669],
#   [479, 488, 532, 533, 573, 574, 604, 631, 640, 655, 681],
#   [469, 487, 490, 531, 548, 549, 557, 593, 618, 624, 646, 647],
#   [474, 493, 503, 511, 539, 679],
#   [470, 498, 516, 526, 528, 563, 571, 590, 615, 620, 628, 690],
#   [504, 591, 598, 650, 653, 661],
#   [473, 546, 564, 567, 614, 619, 641, 660, 676],
#   [492, 497, 505, 541, 545, 626, 630, 643, 652, 670],
#   [478,
#    485,
#    486,
#    502,
#    509,
#    520,
#    535,
#    540,
#    544,
#    552,
#    561,
#    595,
#    600,
#    607,
#    629,
#    633,
#    649,
#    651,
#    685,
#    686,
#    689,
#    693],
#   [489, 496, 529, 530, 568, 592, 644],
#   [524, 536, 582, 627, 662, 671],
#   [475, 507, 510, 519, 543, 550, 570, 580, 599, 642, 673],
#   [491,
#    494,
#    495,
#    508,
#    512,
#    522,
#    525,
#    542,
#    559,
#    588,
#    616,
#    621,
#    634,
#    659,
#    663,
#    664,
#    666],
#   [480, 523, 556, 565, 566, 569, 603, 611, 612, 617, 672],
#   [500, 562, 577, 587, 602, 648, 657, 677, 692],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []],
#  [[708, 718, 734, 757, 877, 954, 990],
#   [703, 719, 720, 780, 800, 851, 855, 938, 977],
#   [714,
#    743,
#    759,
#    771,
#    829,
#    830,
#    837,
#    841,
#    844,
#    846,
#    892,
#    895,
#    899,
#    913,
#    932,
#    933,
#    950,
#    961,
#    965,
#    986,
#    989],
#   [707,
#    725,
#    749,
#    767,
#    782,
#    798,
#    823,
#    834,
#    876,
#    879,
#    881,
#    912,
#    915,
#    929,
#    939,
#    955],
#   [713, 739, 797, 836, 874, 880, 935, 936, 966],
#   [710,
#    726,
#    728,
#    729,
#    731,
#    737,
#    755,
#    760,
#    778,
#    787,
#    790,
#    793,
#    809,
#    814,
#    820,
#    854,
#    867,
#    884,
#    900,
#    906,
#    922,
#    945,
#    949,
#    980],
#   [700, 709, 785, 794, 833, 840, 920, 956, 987],
#   [724, 753, 786, 827, 845, 850, 887, 889, 910, 914, 984, 988],
#   [696, 733, 773, 779, 818, 821, 828, 832, 853, 868, 946, 951],
#   [698,
#    735,
#    741,
#    803,
#    842,
#    848,
#    852,
#    859,
#    864,
#    902,
#    903,
#    904,
#    905,
#    908,
#    918,
#    953],
#   [826, 869, 871, 890, 898, 934, 970],
#   [697,
#    704,
#    715,
#    727,
#    730,
#    736,
#    738,
#    758,
#    789,
#    804,
#    808,
#    815,
#    857,
#    858,
#    861,
#    882,
#    909,
#    921,
#    925,
#    927,
#    931,
#    947,
#    962,
#    964],
#   [766, 795, 796, 831, 930, 940],
#   [748,
#    752,
#    763,
#    777,
#    791,
#    807,
#    811,
#    812,
#    860,
#    865,
#    886,
#    888,
#    937,
#    943,
#    952,
#    960,
#    968,
#    969,
#    971,
#    979],
#   [694,
#    705,
#    711,
#    744,
#    745,
#    762,
#    774,
#    775,
#    802,
#    810,
#    856,
#    896,
#    917,
#    919,
#    926,
#    928,
#    958,
#    972],
#   [699,
#    701,
#    717,
#    721,
#    722,
#    732,
#    742,
#    751,
#    769,
#    770,
#    781,
#    783,
#    792,
#    799,
#    817,
#    835,
#    862,
#    870,
#    875,
#    885,
#    894,
#    911,
#    916,
#    923,
#    924,
#    944,
#    957,
#    959,
#    974,
#    982,
#    983,
#    985],
#   [695, 716, 740, 776, 784, 847, 863, 878, 967, 978, 981],
#   [746, 756, 765, 768, 822, 824, 825, 866, 891, 942, 973, 975],
#   [702,
#    706,
#    723,
#    747,
#    754,
#    761,
#    772,
#    805,
#    806,
#    819,
#    838,
#    839,
#    843,
#    849,
#    873,
#    883,
#    893,
#    897,
#    907,
#    941,
#    948,
#    963,
#    976],
#   [712, 750, 764, 788, 801, 813, 816, 872, 901],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []]]

# %% [markdown]
# # Khi²

# %%
# tf_of_your_word = tf[numDoc][strWord]
tf = []
for doc in usable:
    tf_doc = {}
    for word in vectorizer.get_feature_names():
        tf_doc[word] = doc.count(word)
    tf.append(tf_doc)

# %%
# Number total of words
# nb_total_word[numPartition]
nb_total_word = []
nb = 0

for numDoc in range(0, len(usable)):
    for word in vectorizer.get_feature_names():
        nb += tf[numDoc][word]
    if numDoc+1 in limits:
        nb_total_word.append(nb)
        nb=0

# %%
nb_total_word
# Out:
# [10917, 17349, 16649, 21289, 28637]

# %%
tf[0]
# Out:
# {'foret': 0,
#  'montr linteret': 0,
#  'qualite recommandation': 0,
#  'risquer': 0,
#  'conçu': 0,
#  'travail rechercher': 0,
#  'consister': 0,
#  'moteur': 0,
#  'dedie': 1,
#  'manipulation': 0,
#  'document': 0,
#  'docu': 0,
#  'donneer textuel': 0,
#  'significatif': 0,
#  'presenter resultat': 0,
#  'resultant': 0,
#  'mesurer similarit': 0,
#  'resoudre probleme': 0,
#  'caracteristiquer': 0,
#  'assurer': 0,
#  'emergent': 0,
#  'stochastique': 0,
#  'spatiotemporel': 0,
#  'amont': 0,
#  'publication': 0,
#  'linteret methode': 0,
#  'dinform': 0,
#  'article introduire': 0,
#  'letude': 0,
#  'repartition': 0,
#  'meilleure': 0,
#  'resultat experimentaux': 0,
#  'lobjectif travail': 0,
#  'issu': 0,
#  'dappariemer': 0,
#  'conjoint': 0,
#  'recemment': 0,
#  'systematiqu': 0,
#  'partir baser': 0,
#  'utilisable': 0,
#  'article presenton': 0,
#  'decrir': 0,
#  'didentifier': 0,
#  'priser compter': 0,
#  'fouiller': 0,
#  'tester': 0,
#  'factorisation': 0,
#  'fonctionnalite': 0,
#  'jouer role': 0,
#  'detablir': 0,
#  'conference': 0,
#  'ditemset': 0,
#  'lavantage': 0,
#  'iteratif': 0,
#  'dexperimentation': 0,
#  'proposee': 0,
#  'fouiller donneer': 0,
#  'distribuer': 0,
#  'patient': 0,
#  'efficacite': 0,
#  'collecter': 0,
#  'correspondant': 0,
#  'historique': 0,
#  'retrouver': 0,
#  'context': 0,
#  'ainsiqu': 0,
#  'organisation': 0,
#  'second': 0,
#  'enregistrement': 0,
#  'concerner': 0,
#  'dizaine': 0,
#  'presentation': 0,
#  'message': 1,
#  'regl dassoci': 0,
#  'guidee': 0,
#  'supervis': 0,
#  'dater stream': 0,
#  'systeme recommandation': 0,
#  'ascendant': 0,
#  'lapprentissage supervis': 0,
#  'problem': 0,
#  'naturellement': 0,
#  'ressourc': 0,
#  'classer': 0,
#  'fouiller grand': 0,
#  'fondee': 0,
#  'complementair': 0,
#  'approche': 0,
#  'temps reponse': 0,
#  'public': 0,
#  'evolution': 0,
#  'representation': 0,
#  'reduiser': 0,
#  'presentons': 0,
#  'qualitatif': 0,
#  'limplementation': 0,
#  'iii': 0,
#  'enjeu': 0,
#  'calcul similarite': 0,
#  'compacter': 0,
#  'propagation': 0,
#  'papier': 0,
#  'population': 0,
#  'papier present': 0,
#  'perspectif': 0,
#  'permettre dextraire': 0,
#  'topologie': 0,
#  'classification supervise': 0,
#  'regard': 0,
#  'dameliorer performance': 0,
#  'necessiter': 0,
#  'dattributs': 0,
#  'orient': 0,
#  'facilement': 0,
#  'contenir': 0,
#  'structuration': 0,
#  'semantiqu partir': 0,
#  'seuil': 0,
#  'cours': 0,
#  'nonsupervis': 0,
#  'espacer': 0,
#  'propose': 0,
#  'devaluer': 0,
#  'linformatiqu': 0,
#  'question important': 0,
#  'sousensemble': 0,
#  'ruer': 0,
#  'resultat': 0,
#  'lapproch': 0,
#  'grâce algorithme': 0,
#  'respecter': 0,
#  'enjeu majeur': 0,
#  'protocole': 0,
#  'predicteur': 0,
#  'habituellement': 0,
#  'decision': 0,
#  'limage': 0,
#  'variante': 0,
#  'indispensable': 0,
#  'appliquee': 0,
#  'dopinion': 0,
#  'plutot': 0,
#  'connexion': 0,
#  'probleme': 0,
#  'actif': 0,
#  'visualis': 0,
#  'profit': 0,
#  'nair': 0,
#  'premiere': 0,
#  'decriver': 0,
#  'aleatoir': 0,
#  'cognitif': 0,
#  'methode original': 0,
#  'dutilisation': 0,
#  'denrichir': 0,
#  'obtenu': 0,
#  'court': 0,
#  'cadrer article': 0,
#  'lapplication': 0,
#  'guider': 0,
#  'definir': 0,
#  'dabord': 0,
#  'pair': 0,
#  'correct': 0,
#  'flexible': 0,
#  'lensembl': 0,
#  'consommation': 0,
#  'stream': 0,
#  'durer processus': 0,
#  'lespace representation': 0,
#  'affiner': 0,
#  'priser decision': 0,
#  'automatique': 0,
#  'continu': 0,
#  'precedent': 0,
#  'approprier': 0,
#  'lafc': 0,
#  'etape': 0,
#  'variabilite': 0,
#  'taxonomie': 0,
#  'lenrichissement': 0,
#  'groupement': 0,
#  'meneer': 0,
#  'lanalyse': 1,
#  'version': 0,
#  'type': 0,
#  'petit': 0,
#  'travail recent': 0,
#  'requet': 0,
#  'entrainer': 0,
#  'baser technique': 0,
#  'medical': 0,
#  'nom': 0,
#  'processus': 0,
#  'fonction croyance': 0,
#  'olap': 0,
#  'partir corpu': 0,
#  'modalite': 0,
#  'carte': 0,
#  'dentre': 0,
#  'lerreur': 0,
#  'adn': 0,
#  'placer': 0,
#  'dinformation': 0,
#  'induit': 0,
#  'fiable': 0,
#  'developper': 0,
#  'segmenter': 0,
#  'beneficier': 0,
#  'ditems': 0,
#  'contenir document': 0,
#  'wikipedia': 0,
#  'varieer': 0,
#  'textuel': 0,
#  'consist': 0,
#  'lexpression': 0,
#  'ameliore': 0,
#  'essentiellement': 0,
#  'loi': 0,
#  'machiner': 0,
#  'optimisation': 0,
#  'decisionnel': 0,
#  'predictif': 0,
#  'demarch': 0,
#  'regler': 0,
#  'necessitent': 0,
#  'sousgraphe': 0,
#  'gain': 0,
#  'regl dassociation': 0,
#  'dapprendre': 0,
#  'defi': 0,
#  'represente': 0,
#  'feature': 0,
#  'montrer faisabilite': 0,
#  'client': 0,
#  'volum': 0,
#  'dimension': 0,
#  'action': 0,
#  'rappel': 0,
#  'manquant': 0,
#  'reconnaitre': 0,
#  'efficacement': 0,
#  'nombre': 0,
#  'mieux comprendre': 0,
#  'moyenner': 0,
#  'biomedical': 0,
#  'projection': 0,
#  'lhypothese': 0,
#  'informatif': 0,
#  'riche': 0,
#  'sappuyer': 0,
#  'cube': 0,
#  'donnees': 0,
#  'evolutiv': 0,
#  'permettre representer': 0,
#  'poser': 0,
#  'frequente': 0,
#  'parcimonieux': 0,
#  'stockeer': 0,
#  'developpe': 0,
#  'approximatif': 0,
#  'selectionde': 0,
#  'present': 0,
#  'sant': 0,
#  'index': 0,
#  'amelior': 0,
#  'reveler': 0,
#  'topographique': 0,
#  'problematique': 0,
#  'pedagogiqu': 0,
#  'dintroduir': 0,
#  'adaptee': 0,
#  'particularite': 0,
#  'important': 0,
#  'nexist': 0,
#  'bioinformatique': 0,
#  'performance': 0,
#  'dedonnee': 0,
#  'echantillonnage': 0,
#  'multimedia': 0,
#  'cellule': 0,
#  'pouvoir extraire': 0,
#  'etudie': 0,
#  'encompte': 0,
#  'adaptatif': 0,
#  'preciser': 0,
#  'nouvel operateur': 0,
#  'dexplorer': 0,
#  'savoir': 0,
#  'daid decision': 0,
#  'dechantillonnage': 0,
#  'tableau contingence': 0,
#  'semantiquement': 0,
#  'lextraction partir': 0,
#  'motif ensembliste': 0,
#  'cadrer classification': 0,
#  'limitee': 0,
#  'genetiqu': 0,
#  'utiliser modele': 0,
#  'situation': 0,
#  'danalyser': 0,
#  'lechelle': 0,
#  'capturer': 0,
#  'montrer': 0,
#  'transform': 0,
#  'permettre lextraction': 0,
#  'voisinage': 0,
#  'mem': 1,
#  'graphe': 0,
#  'text': 0,
#  'pouvoir utiliser': 0,
#  'valide': 0,
#  'negativ': 0,
#  'methodologie': 0,
#  'voir': 0,
#  'article traire': 0,
#  'lautre': 0,
#  'presenton': 0,
#  'interaction': 0,
#  'informatique': 0,
#  'dissimilarite': 0,
#  'limportance': 0,
#  'caractere': 0,
#  'encourageant': 0,
#  'permettre': 1,
#  'correlation': 0,
#  'maximal': 0,
#  'preser': 0,
#  'consequent': 0,
#  'papier presenter': 0,
#  'factoriel correspondance afc': 0,
#  'reseaux': 0,
#  'page web': 0,
#  'miser': 0,
#  'nouvel algorithme': 0,
#  'rapport': 0,
#  'presenter methode': 0,
#  'jouer': 0,
#  'obtenir montrer': 0,
#  'observee': 0,
#  'present methode': 0,
#  'chain': 0,
#  'grand ensembl': 0,
#  'detection changement': 0,
#  'collaboratif': 0,
#  'contenu': 0,
#  'echelle': 0,
#  'bayesienn': 0,
#  'point dinteret': 0,
#  'offrir': 0,
#  'choix': 0,
#  'exploiter': 0,
#  'composant': 0,
#  'theoriqu': 0,
#  'coupler': 0,
#  'homogen': 0,
#  'mobile': 0,
#  'reell': 0,
#  'orienter': 0,
#  'owl': 0,
#  'carte topologique': 0,
#  'fonctionner': 0,
#  'interessant': 0,
#  'frequence': 0,
#  'traditionnel': 0,
#  'permettre determiner': 0,
#  'multiagent': 0,
#  'utilise': 0,
#  'lecart': 0,
#  'sil': 0,
#  'corpu': 0,
#  'caracteristique': 1,
#  'formel': 0,
#  'culturel': 0,
#  'lanalyse formel concept': 0,
#  'tâche classification': 0,
#  'virtuel': 0,
#  'methode efficace': 0,
#  'contrainte': 0,
#  'cuber': 0,
#  'serveur': 0,
#  'ferme': 0,
#  'traiter': 0,
#  'specifiquement': 0,
#  'particuliere': 0,
#  'uniquement': 0,
#  'partir document': 0,
#  'decrire': 0,
#  'reduir': 0,
#  'classification': 0,
#  'coupl': 0,
#  'limiter': 0,
#  'utiliser technique': 0,
#  'convier': 0,
#  'elev': 0,
#  'bruitees': 0,
#  'construit partir': 0,
#  'projet': 0,
#  'situer': 0,
#  'flou': 0,
#  'associer': 0,
#  'instance': 0,
#  'lineair': 0,
#  'probleme majeur': 0,
#  'couvrir': 0,
#  'quantifier': 0,
#  'ensemble donneer': 0,
#  'combinatoire': 0,
#  'volee': 0,
#  'pallier': 0,
#  'prevention': 0,
#  'dimag': 0,
#  'condition': 0,
#  'localiser': 0,
#  'participatif': 0,
#  'quon': 0,
#  'environnement': 0,
#  'processus fouiller': 0,
#  'disponible': 0,
#  'compact': 0,
#  'mesurer dissimilarite': 0,
#  'bayesien': 0,
#  'axer': 0,
#  'flot donneer': 0,
#  'entreprise': 0,
#  'domaine lapprentissage': 0,
#  'system recommandation': 0,
#  'nouvelleapproche': 0,
#  'ressource': 0,
#  'choisir': 0,
#  'generatif': 0,
#  'evidence': 0,
#  'benchmark': 0,
#  'lexploration': 0,
#  'maintenir': 0,
#  'estimation': 0,
#  'mesurer dinteret': 0,
#  'question': 0,
#  'formel concept': 0,
#  'attribut': 0,
#  'lapprentissage automatique': 0,
#  'detection': 0,
#  'depender': 0,
#  'formalisme': 0,
#  'communautair': 0,
#  'liste': 0,
#  'occurrence': 0,
#  'nondisjoint': 0,
#  'reseaux social': 0,
#  'partir ensembl': 0,
#  'mecanism': 0,
#  'candidat': 2,
#  'presenter nouvel algorithme': 0,
#  'estimation densite': 0,
#  'lancer': 0,
#  'integrant': 0,
#  'referentiel': 0,
#  'procedur': 0,
#  'naïf': 0,
#  'comparaison': 1,
#  'neuron': 0,
#  'maniere': 0,
#  'voisin': 0,
#  'automatiquement': 0,
#  'paradigme': 0,
#  'dapprentissage supervis': 0,
#  'referent': 0,
#  'evaluation': 0,
#  'dexploration': 0,
#  'illustrer': 0,
#  'dassoci': 0,
#  'ligne colonne': 0,
#  'comparer': 0,
#  'meilleur resultat': 0,
#  'fondamental': 0,
#  'nature': 0,
#  'utilisateur': 0,
#  'rapidement': 0,
#  'interet': 0,
#  'technique': 0,
#  'generation': 0,
#  'jeu donneer': 0,
#  'delagage': 0,
#  'oriente': 0,
#  'detre': 0,
#  'communautaire': 0,
#  'manqu': 0,
#  'donneer luci': 0,
#  'croiser': 0,
#  'repondre': 0,
#  'lintroduction': 0,
#  'vaste': 0,
#  'etiquetage': 0,
#  'usage': 1,
#  'intervalle': 0,
#  'prendre compter': 0,
#  'avantage': 0,
#  'decrit': 0,
#  'dependanc': 0,
#  'metadonnee': 0,
#  'decis': 0,
#  'achat': 0,
#  'classement': 0,
#  'effectu': 0,
#  'graph': 0,
#  'coefficient': 0,
#  'lemergence': 0,
#  'factoriel': 0,
#  'conferenc': 0,
#  'decoupage': 0,
#  'croyance': 0,
#  'definis': 0,
#  'industriel': 0,
#  'coûteux': 0,
#  'dautre partir': 0,
#  'terme qualite': 0,
#  'principe': 0,
#  'mene': 0,
#  'parallel': 0,
#  'etude experimental': 0,
#  'opinion': 0,
#  'regression': 0,
#  'knowledge': 0,
#  'construction dontologie': 0,
#  'associe': 0,
#  'collection': 0,
#  'grammaire': 0,
#  'indiquer': 0,
#  'nettement': 0,
#  'eviter': 0,
#  'intuitif': 0,
#  'garantir': 0,
#  'surl': 0,
#  'souhaiter': 0,
#  'produit': 0,
#  'dobtenir': 0,
#  'reconnaissance': 0,
#  'devaluation': 0,
#  'ontologie': 0,
#  'decouvert': 0,
#  'decouverte': 0,
#  'zone': 0,
#  'stocker': 0,
#  'lentrepot': 0,
#  'consider': 0,
#  'paire': 0,
#  'montrer linteret': 0,
#  'presenter': 0,
#  'quell': 0,
#  'structur': 0,
#  'classification automatique': 0,
#  'provenir': 0,
#  'period': 0,
#  'comparatif': 0,
#  'systeme dapprentissage': 0,
#  'proposees': 0,
#  'densembl': 0,
#  'modele prediction': 0,
#  'extraction regl': 0,
#  'sig': 0,
#  'nouvel': 0,
#  'lorganisation': 0,
#  'terminologique': 0,
#  'tabl': 0,
#  'theorie fonction': 0,
#  'developpement': 0,
#  'ponderation': 0,
#  'modelisation': 0,
#  'reseau social': 0,
#  'specification': 0,
#  'capteur': 0,
#  'dautre': 0,
#  'lheure actuel': 0,
#  'preliminair': 0,
#  'phase': 0,
#  'entreprendre': 0,
#  'poids': 0,
#  'reposer lutilisation': 0,
#  'primordial': 0,
#  'evalue': 0,
#  'definition': 0,
#  'developpemer': 0,
#  'procedure': 0,
#  'lontologie': 0,
#  'perception': 0,
#  'dapplication': 0,
#  'reseaux neuron': 0,
#  'phenomene': 0,
#  'pouvoir aider': 0,
#  'applicatif': 0,
#  'perte dinformation': 0,
#  'recevoir': 0,
#  'pourtant': 0,
#  'classificateur': 0,
#  'reduire': 0,
#  'diffusion': 0,
#  'munir': 0,
#  'linformation': 0,
#  'dexploiter': 0,
#  'evalu': 0,
#  'propriete': 0,
#  'liees': 0,
#  'limite': 0,
#  'constituer': 0,
#  'plateforme': 2,
#  'lacquisition': 0,
#  'former regl': 0,
#  'metier': 0,
#  'populaire': 0,
#  'chercheur': 0,
#  'realisee': 0,
#  'generee': 0,
#  'modification': 0,
#  'partir base': 0,
#  'role': 0,
#  'objet': 0,
#  'processus dextraction': 0,
#  'mining': 0,
#  'stockee': 0,
#  'comportemer': 0,
#  'cadrer theoriqu': 0,
#  'dontologie': 0,
#  'simple': 0,
#  'dameliorer': 0,
#  'methode fouiller': 0,
#  'descriptif': 0,
#  'linguistique': 0,
#  'instant': 0,
#  'intensif': 0,
#  'filtrage': 0,
#  'algorithme': 0,
#  'foret aleatoir': 0,
#  'sequence': 0,
#  'lutilisation': 0,
#  'usuel': 0,
#  'categoriell': 0,
#  'discretisation': 0,
#  'potentiel': 0,
#  'groupe': 0,
#  'eclairage': 0,
#  'correspondre': 0,
#  'conserver': 0,
#  'differenter': 0,
#  'principalement': 0,
#  'sparql': 0,
#  'finalement': 0,
#  'etat': 0,
#  'dispositif': 0,
#  'lexploitation': 0,
#  'experimentation montrer': 0,
#  'luci': 0,
#  'comparer resultat': 0,
#  'proximite': 0,
#  'alternatif': 0,
#  'lapprentissage': 0,
#  'dextraire motif': 0,
#  'personnalisation': 0,
#  'recouvrant': 0,
#  'quadratique': 0,
#  'dechantillon': 0,
#  'construire': 0,
#  'modele conceptuel': 0,
#  'jeu synthetiqu': 0,
#  'lextraction regl': 0,
#  'realiser': 0,
#  'agent': 0,
#  'financier': 0,
#  'considere': 0,
#  'lapproche propose': 0,
#  'formaliser': 0,
#  'texte': 0,
#  'didentification': 0,
#  'erreur': 0,
#  'resoudre': 0,
#  'parametre': 0,
#  'futur': 0,
#  'initial': 0,
#  'optimal': 0,
#  'reposer': 0,
#  'heterogen': 0,
#  'grand quantite': 0,
#  'source': 0,
#  'minoritaire': 0,
#  'collection document': 0,
#  'augmenter': 0,
#  'dexpression': 0,
#  'born': 0,
#  'lanalyste': 0,
#  'extrait': 0,
#  'million': 0,
#  'grand nombre': 0,
#  'tâcher important': 0,
#  'sinteresse': 0,
#  'presentees': 0,
#  'caracterisation': 0,
#  'papier presente': 0,
#  'innovant': 0,
#  'detectiond': 0,
#  'cadrer travail': 0,
#  'calcul': 0,
#  'delement': 0,
#  'genre': 0,
#  'induire': 0,
#  'article nouvel': 0,
#  'français': 0,
#  'complexe': 0,
#  'social': 0,
#  'base relationnel': 0,
#  'site': 1,
#  'trajectoire': 0,
#  'score': 0,
#  'deduire': 0,
#  'espace': 0,
#  'svm': 0,
#  'doutils': 0,
#  'dissimilarit': 0,
#  'explicatif': 0,
#  'interess': 0,
#  'compromis': 0,
#  'experimentalement': 0,
#  'voire': 0,
#  'online': 0,
#  'combinaison': 0,
#  'chaine': 0,
#  'couleur': 0,
#  'pallier probleme': 0,
#  'letiquetage': 0,
#  'modele': 0,
#  'lun': 0,
#  'lumiere': 0,
#  'similarite': 0,
#  'interrogation': 0,
#  'mouvement': 0,
#  'mond': 0,
#  'conception': 0,
#  'grapher': 0,
#  'maintenance': 0,
#  'specialis': 0,
#  'outrer': 0,
#  'rdf': 0,
#  'convergence': 0,
#  'acce': 0,
#  'performer': 0,
#  'prendre': 0,
#  'mapping': 0,
#  'simultanement': 0,
#  'apporter': 0,
#  'lapproch propose': 0,
#  'colonne': 0,
#  'associee': 0,
#  'moment': 0,
#  'developpee': 0,
#  'faire partir': 0,
#  'quantitatif': 0,
#  'mobilite': 0,
#  'ensemble regl': 0,
#  'libre': 0,
#  'presence': 0,
#  'verification': 0,
#  'model': 0,
#  'motif': 0,
#  'article methodologie': 0,
#  'servir': 0,
#  'decisionnell': 0,
#  'article methode original': 0,
#  'ressortir': 0,
#  'informationnel': 0,
#  'technologi': 0,
#  'veiller': 0,
#  'dedition': 0,
#  'classification supervisee': 0,
#  'permettre traiter': 0,
#  'difficulte': 0,
#  'granularite': 0,
#  'twitter': 0,
#  'structure': 0,
#  'reell issu': 0,
#  'association': 0,
#  'dapprentissage': 0,
#  'obtenir resultat': 0,
#  'segment': 0,
#  'gestion': 0,
#  'refleter': 0,
#  'proportion': 0,
#  'daid': 0,
#  'quantite': 0,
#  'large': 0,
#  'estim': 0,
#  'tirer': 0,
#  'specifiqu': 1,
#  'faire appel': 0,
#  'surune': 0,
#  'corpus': 0,
#  'laid': 0,
#  'lexemple': 0,
#  'aider': 0,
#  'extraire motif': 0,
#  'concepteur': 0,
#  'ala': 0,
#  'implementation': 0,
#  'descripteur': 0,
#  'propos': 0,
#  'continuer': 0,
#  'objectif': 1,
#  'applicable': 0,
#  'entite': 0,
#  'cesser': 0,
#  'bayesien naïf': 0,
#  'categoriel': 0,
#  'autoorganisatrice': 0,
#  'utile': 0,
#  'similarit': 0,
#  'miser placer': 0,
#  'croissance': 0,
#  'spectral': 0,
#  'scenario': 0,
#  'partir': 0,
#  'degager': 0,
#  'linteret': 0,
#  'actuel': 0,
#  'problematiqu': 0,
#  'changement': 0,
#  'lart': 0,
#  'biais': 0,
#  'faire lobjet': 0,
#  'hierarchie': 0,
#  'synthes': 0,
#  'utilisation': 0,
#  'partitionnement': 0,
#  'empirique': 0,
#  'levolution': 0,
#  'lier': 0,
#  'controle': 0,
#  'phraser': 0,
#  'iterativ': 0,
#  'sappui': 0,
#  'vivre': 0,
#  'associeer': 0,
#  'griller': 0,
#  'dorigine': 0,
#  'documentaire': 0,
#  'quun': 0,
#  'determine': 0,
#  'grand base donneer': 0,
#  'efficace': 0,
#  'organiser': 0,
#  'methode reposer': 0,
#  'calculee': 0,
#  'pertinence': 0,
#  'dagregation': 0,
#  'sinscrit': 0,
#  'sadapter': 0,
#  'semantique': 0,
#  'flux': 0,
#  'modelise': 0,
#  'pratiquer': 0,
#  'lefficacite': 0,
#  'relatif': 0,
#  'dobjets': 0,
#  'construir': 0,
#  'biclustering': 0,
#  'lespace': 0,
#  'comprendre': 0,
#  'constater': 0,
#  'echell': 0,
#  'lintegration': 0,
#  'generalist': 0,
#  'letat lart': 0,
#  'web': 0,
#  'defaut': 0,
#  'baser relationnel': 0,
#  'matrice': 0,
#  'symbolique': 0,
#  'protein': 0,
#  'majorite': 0,
#  'cartographie': 0,
#  'traiter probleme': 0,
#  'utilisee': 0,
#  'national': 0,
#  'modifier': 0,
#  'concept': 0,
#  'niveau': 0,
#  'limpact': 0,
#  'classifier': 0,
#  'couverture': 0,
#  'conditionnel': 0,
#  'ensembl mesure': 0,
#  'dinteraction': 0,
#  'gros': 0,
#  'ontologie domaine': 0,
#  'annotation semantiqu': 0,
#  'reduction': 0,
#  'terrain': 0,
#  'anne': 0,
#  'article permettre': 0,
#  'kmoyenne': 0,
#  'assister': 0,
#  'luire permettre': 0,
#  'satellit': 0,
#  'maximum': 0,
#  'danalyse': 0,
#  'nousproposon': 0,
#  'interface': 0,
#  'noyau': 0,
#  'detat': 0,
#  'gerer': 0,
#  'distance': 0,
#  'appliquees': 0,
#  'modele predictif': 0,
#  'formalisation': 0,
#  'condensees': 0,
#  'dinternet': 0,
#  'presente': 0,
#  'apprendre': 0,
#  'automat': 0,
#  'performance predictiv': 0,
#  'temporel': 0,
#  'correspondance': 0,
#  'decd': 0,
#  'illustree': 0,
#  'partir texte': 0,
#  'using': 0,
#  'manipuler': 0,
#  'ordonne': 0,
#  'cle': 0,
#  'visualisation grand': 0,
#  'voter': 0,
#  'base': 0,
#  'experience': 0,
#  'mixte': 0,
#  'experience meneer': 0,
#  'etde': 0,
#  'laclassification': 0,
#  'booleenn': 0,
#  'flouer': 0,
#  'choix mesurer': 0,
#  'savere': 0,
#  'lheure': 0,
#  'donneer article': 0,
#  'exister': 0,
#  'sortir': 0,
#  'prediction': 0,
#  'traire': 0,
#  'relationnel': 0,
#  'contribution': 0,
#  'transformer': 0,
#  'pouvoir prendre': 0,
#  'decideur': 0,
#  'complementarite': 0,
#  'trace': 0,
#  'loriginalite': 0,
#  'qualitativement': 0,
#  'superieur': 0,
#  'flot': 0,
#  'mal': 0,
#  'densite': 0,
#  'ignorer': 0,
#  'lalignement': 0,
#  'courir': 0,
#  'mise': 0,
#  'extraction motif': 0,
#  'identifier': 0,
#  'dattribut': 0,
#  'cadrer': 0,
#  'confirmer': 0,
#  'recente': 0,
#  'dintegration': 0,
#  'mecanisme': 0,
#  'multilabel': 0,
#  'correspondance afc': 0,
#  'structurer sousjacent': 0,
#  'perspective': 0,
#  'hierarchiqu': 0,
#  'famille': 0,
#  'largement': 0,
#  'elevee': 0,
#  'learning': 0,
#  'centaine': 0,
#  'metriqu': 0,
#  'markov': 0,
#  'specifier': 0,
#  'laugmentation': 0,
#  'categorie': 0,
#  'panel': 0,
#  'sens': 0,
#  'difference': 0,
#  'temps reel': 1,
#  'stockage': 0,
#  'graphe conceptuel': 0,
#  'tou': 0,
#  'proposon': 0,
#  'nombre classe': 0,
#  'traiter grand': 0,
#  'proposonsune': 0,
#  'tailler': 0,
#  'dacquisition': 0,
#  'numeriqu': 0,
#  'phrase': 0,
#  'dextrair': 0,
#  'specialite': 0,
#  ...}

# %%
# nb_word[num_partition][word]
nb_word = []

word_in_this_parti = {}
for word in vectorizer.get_feature_names():
    word_in_this_parti[word] = 0

for numDoc in range(0, len(usable)):
    for word in vectorizer.get_feature_names():
        word_in_this_parti[word] += tf[numDoc][word]
    if numDoc+1 in limits:
        nb_word.append(word_in_this_parti)
        word_in_this_parti = {}
        for word in vectorizer.get_feature_names():
            word_in_this_parti[word] = 0

# %%
len(nb_word)
# Out:
# 5

# %%
# nb_word_by_cluster[numPartition][numCluster]
nb_word_by_cluster = []
for parti in partitions:
    nb_word_clus = []
    for cluster in parti:
        nb = 0
        for numDoc in cluster:
            for word in vectorizer.get_feature_names():
                nb += tf[numDoc][word]
        nb_word_clus.append(nb)
    nb_word_by_cluster.append(nb_word_clus)

# %%
# value_of_khi2 = khi2[numPartition][numCluster][word]
khi2 = []

for numParti in range(0, len(partitions)):
    khi2parti = []
    for numCluster in range(0, len(partitions[numParti])):
        khi2cluster = {}
        
        for word in vectorizer.get_feature_names():
            if nb_word_by_cluster[numParti][numCluster] == 0:
                khi2cluster[word] = 0
            else:
                word_in_this_parti[word] = 0
                E = nb_word[numParti][word]
                E =+ nb_word_by_cluster[numParti][numCluster]
                E = E/ nb_total_word[numParti]
                N = 0
                for numDoc in partitions[numParti][numCluster]:
                    N += tf[numDoc][word]
                khi2cluster[word] = (pow(N - E, 2)/E)        
        khi2parti.append(khi2cluster)
    khi2.append(khi2parti)

# %%
# list of your labels = labels[numPartition][numCluster]
labels = []

for numPartition in range(0, len(nb_word_by_cluster)):
    label_clus = []
    for numCluster in range(0, len(nb_word_by_cluster[numPartition])):
        label_clus.append(Counter(khi2[numPartition][numCluster]).most_common(5))
    labels.append(label_clus)

# %%
# Some clusters can be empty
labels
# Out:
# [[[('model', 4618.224768892248),
#    ('mode', 4618.224768892248),
#    ('modele', 3532.341241438005),
#    ('information', 1453.3978138173727),
#    ('format', 1453.3978138173727)],
#   [('concept', 3916.292868920033),
#    ('treillis', 3335.119791996956),
#    ('similarit', 2800.600561227725),
#    ('similarite', 2312.7351766123406),
#    ('mesure', 1871.5236381508018)],
#   [('label', 32077.453971091305),
#    ('relation', 9435.684740322078),
#    ('classification', 2604.3169518605428),
#    ('multilabel', 2107.7039710913114),
#    ('classification multilabel', 1663.5765672451573)],
#   [('communaut', 7570.226985612394),
#    ('commun', 7570.226985612394),
#    ('mesure', 3535.7713871567953),
#    ('graph', 2087.5764064618143),
#    ('graphe', 1689.1459045313125)],
#   [('campagne', 6291.00881310522),
#    ('fin', 5527.336867403862),
#    ('prediction', 1196.296143421962),
#    ('present', 1196.296143421962),
#    ('semantiqu', 877.2079081278442)],
#   [('base', 2107.7039710913114),
#    ('recherche', 2107.7039710913114),
#    ('mode', 1271.9347403220804),
#    ('model', 932.7784903220805),
#    ('utilisateur', 932.7784903220805)],
#   [('temp', 5154.476639219174),
#    ('cluster', 3650.2197222231275),
#    ('clustering', 3206.3343467290565),
#    ('analys', 2047.279010760677),
#    ('temporel', 1718.4608289424953)],
#   [('evenement', 3515.2626949428395),
#    ('motif', 2993.414326420767),
#    ('action', 2513.4738273804596),
#    ('extraction', 2513.4738273804596),
#    ('temp', 1679.3164377451428)],
#   [('structur', 2876.507211914658),
#    ('text', 1994.2562894054329),
#    ('texte', 1613.5570274128129),
#    ('apprentissage', 1273.1418982615219),
#    ('issu', 713.1640384829241)],
#   [('docu', 2952.1939026888886),
#    ('them', 2952.1939026888886),
#    ('document', 2543.6660475356853),
#    ('information', 2543.6660475356853),
#    ('format', 2543.6660475356853)],
#   [('rdf', 9627.577298418446),
#    ('web', 5888.858705453623),
#    ('format', 4084.501921534023),
#    ('sparql', 3556.1953888707067),
#    ('voir', 1808.6979014335207)],
#   [('apprentissage', 3070.6292100956466),
#    ('system', 2129.0622809617885),
#    ('systeme', 1722.7492888358038),
#    ('question', 1359.4166116704496),
#    ('passage', 1359.4166116704496)],
#   [('partir', 2351.6136075722243),
#    ('tir', 2351.6136075722243),
#    ('permettre', 1386.9009787062453),
#    ('precis', 884.4422158196475),
#    ('model', 675.4177312835651)],
#   [('tabl', 3177.7720633023073),
#    ('coclustering', 3177.7720633023073),
#    ('clustering', 3177.7720633023073),
#    ('cluster', 3177.7720633023073),
#    ('table', 2668.385097925525)],
#   [('format', 1601.6049587949838),
#    ('formation', 1601.6049587949838),
#    ('text', 1263.6983653883901),
#    ('context', 965.7807829708076),
#    ('information', 965.7807829708076)],
#   [('motif', 7196.361025142018),
#    ('lon', 3801.9839759616907),
#    ('utilisateur', 2909.14791038792),
#    ('lutilisateur', 2135.6233202239855),
#    ('echantillon', 2135.6233202239855)],
#   [('present', 987.7961055481967),
#    ('jeu', 987.7961055481967),
#    ('donneer', 987.7961055481967),
#    ('reference', 724.0264426268483),
#    ('motif', 724.0264426268483)],
#   [('reseau', 9611.340737757751),
#    ('lie', 6015.879908264665),
#    ('reseaux', 5397.4052538867845),
#    ('lien', 4812.469770015817),
#    ('cluster', 1057.3130879881671)],
#   [('recommandation', 12963.734477027965),
#    ('utilisateur', 929.496381789869),
#    ('model', 681.1947944882817),
#    ('semantiqu', 681.1947944882817),
#    ('mode', 681.1947944882817)],
#   [('calcul', 2347.173853141992),
#    ('log', 2347.173853141992),
#    ('present', 1970.4543961284176),
#    ('presenter', 1037.8887852686892),
#    ('presente', 1037.8887852686892)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)]],
#  [[('sant', 1875.7741268134737),
#    ('message', 1198.9002137699956),
#    ('ligne', 1198.9002137699956),
#    ('analys', 1198.9002137699956),
#    ('voter', 672.8871702917347)],
#   [('reseau', 17885.644891667067),
#    ('reseaux', 8845.71297677345),
#    ('commun', 8845.71297677345),
#    ('communaut', 7937.198083156428),
#    ('model', 4795.308721454298)],
#   [('motif', 39771.86146481502),
#    ('action', 5852.732450117135),
#    ('graph', 3737.7868866985186),
#    ('permettre', 2695.4804087453344),
#    ('extraction', 2695.4804087453344)],
#   [('cluster', 13928.298555407357),
#    ('clustering', 2914.0258281346296),
#    ('etl', 1174.9936603024616),
#    ('papier', 861.5572966660981),
#    ('present', 861.5572966660981)],
#   [('detection', 12012.934525733846),
#    ('system', 2989.2823518208047),
#    ('cle', 2989.2823518208047),
#    ('text', 2575.645262202348),
#    ('article', 2575.645262202348)],
#   [('requet', 8858.331771889525),
#    ('skyline', 4802.159896889524),
#    ('requete', 4802.159896889524),
#    ('nom', 4138.78631734407),
#    ('point', 2444.387169616797)],
#   [('log', 11012.140343905417),
#    ('document', 5870.541287301644),
#    ('docu', 5870.541287301644),
#    ('ontolog', 5870.541287301644),
#    ('text', 5266.962985414852)],
#   [('numeriqu', 3265.825888576234),
#    ('risque', 3265.825888576234),
#    ('voir', 3265.825888576234),
#    ('mal', 2643.524752212598),
#    ('risquer', 2086.939524939871)],
#   [('prediction', 8102.361141884226),
#    ('modele', 3157.5039990270834),
#    ('model', 3157.5039990270834),
#    ('mode', 3157.5039990270834),
#    ('action', 1542.993010016095)],
#   [('noyau', 7070.336364581685),
#    ('groupe', 5582.8926224830775),
#    ('classification', 3680.7219524451502),
#    ('temp', 2631.9381344931912),
#    ('semantiqu', 1387.7573506752394)],
#   [('present', 5636.320575892503),
#    ('represent', 3769.80844651245),
#    ('temp', 2976.840791525926),
#    ('temporel', 2976.840791525926),
#    ('presentation', 2277.3987430084057)],
#   [('visualis', 5538.549678254981),
#    ('visualisation', 4822.830705359118),
#    ('cluster', 2454.933415772812),
#    ('graph', 1986.7037438755226),
#    ('analys', 1986.7037438755226)],
#   [('classifieur', 5106.260911822613),
#    ('ponder', 3831.91354340156),
#    ('naïf', 3263.222753927876),
#    ('model', 2740.1872276120866),
#    ('mode', 2740.1872276120866)],
#   [('lie', 6260.301441442057),
#    ('social', 4594.280848361333),
#    ('reseau', 4096.103747867099),
#    ('voir', 3626.508195972535),
#    ('pouvoir', 3626.508195972535)],
#   [('egc', 12595.393086461745),
#    ('them', 9518.719532742736),
#    ('thematiqu', 7706.570772412158),
#    ('conferenc', 3417.1658137344707),
#    ('defi', 2869.5418467923223)],
#   [('recommandation', 13616.390461803963),
#    ('utilisateur', 10939.55541025757),
#    ('action', 4665.087743903306),
#    ('system', 4665.087743903306),
#    ('extraction', 3628.472936030765)],
#   [('graph', 7314.703215048973),
#    ('graphe', 5368.940715048972),
#    ('qualit', 2793.2724458182033),
#    ('qualite', 2793.2724458182033),
#    ('partition', 2793.2724458182033)],
#   [('log', 9077.791745047987),
#    ('cluster', 6018.835066347627),
#    ('clustering', 4484.0935501021395),
#    ('ontolog', 4484.0935501021395),
#    ('base', 4022.618459849432)],
#   [('log', 6530.726910113055),
#    ('topolog', 5823.363592356046),
#    ('topologique', 5156.535321328009),
#    ('logique', 5156.535321328009),
#    ('mesure', 4530.242097028943)],
#   [('log', 8472.198821076487),
#    ('donneer', 2947.668395112998),
#    ('fouill', 2509.785027973039),
#    ('logique', 2509.785027973039),
#    ('mapping', 2107.0923302042765)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)]],
#  [[('methode', 3067.807566419178),
#    ('selection', 3067.807566419178),
#    ('caracteristiqu', 2050.3965234743923),
#    ('caracter', 2050.3965234743923),
#    ('present', 1237.267689118564)],
#   [('image', 7052.286733156588),
#    ('classification', 4117.900871595467),
#    ('dimag', 3506.903817103567),
#    ('present', 2432.029001197823),
#    ('dimage', 1553.3132427294877)],
#   [('mesure', 12269.82916727221),
#    ('nom', 2474.766320691801),
#    ('log', 2474.766320691801),
#    ('topolog', 1953.599962096606),
#    ('semantiqu', 1953.599962096606)],
#   [('social', 12152.054138217805),
#    ('reseau', 11353.490976033618),
#    ('format', 5941.944113767929),
#    ('information', 4860.434741314792),
#    ('formation', 4860.434741314792)],
#   [('text', 5756.015419071488),
#    ('rechercher', 5756.015419071488),
#    ('format', 5756.015419071488),
#    ('recherche', 5756.015419071488),
#    ('information', 4794.855998781633)],
#   [('motif', 24741.79886596953),
#    ('action', 6767.665307220581),
#    ('temp', 5589.487792427682),
#    ('extraction', 5589.487792427682),
#    ('temporel', 4033.324647879922)],
#   [('cart', 15031.831558658881),
#    ('carte', 15031.831558658881),
#    ('cognitif', 4630.580162010838),
#    ('criter', 1662.2226201113965),
#    ('concept', 1662.2226201113965)],
#   [('lie', 8027.233007705658),
#    ('lien', 7158.209091412683),
#    ('client', 7158.209091412683),
#    ('detection', 1997.8383888715764),
#    ('cle', 1576.769629529274)],
#   [('tabl', 1540.779661259588),
#    ('present', 1540.779661259588),
#    ('intervall', 1540.779661259588),
#    ('second', 1068.3262933839403),
#    ('discretisation', 1068.3262933839403)],
#   [('semantiqu', 8485.801053476875),
#    ('ligne', 2112.4787785953586),
#    ('log', 2112.4787785953586),
#    ('integr', 1667.3492367312197),
#    ('projet', 1274.8231703805088)],
#   [('sequenc', 11894.800540616063),
#    ('sequence', 10733.160755669825),
#    ('mesure', 3588.3005406160646),
#    ('model', 2963.72527179886),
#    ('mode', 2963.72527179886)],
#   [('log', 33389.926422544144),
#    ('ontolog', 27710.482529793397),
#    ('ontologie', 17938.788388780486),
#    ('present', 4200.57686941604),
#    ('domaine', 2356.8509508460297)],
#   [('graph', 22882.42241729425),
#    ('graphe', 11019.870289634673),
#    ('sit', 2526.5415662304167),
#    ('fouill', 1751.2266726133955),
#    ('algorithme', 1751.2266726133955)],
#   [('visualis', 4841.994924412264),
#    ('utilisateur', 4123.882467664859),
#    ('visualisation', 2860.484543789427),
#    ('log', 2315.1990766613994),
#    ('olap', 2315.1990766613994)],
#   [('concept', 11604.033075579595),
#    ('analys', 6038.329612376132),
#    ('relation', 5141.409698956219),
#    ('analyse', 3931.167815839335),
#    ('present', 2883.0915171380366)],
#   [('reseau', 13444.33470380242),
#    ('log', 5429.175240315091),
#    ('apprentissage', 2403.6782209410235),
#    ('tir', 2403.6782209410235),
#    ('system', 2403.6782209410235)],
#   [('detection', 4494.907954314983),
#    ('model', 3005.72409781274),
#    ('apprentissage', 3005.72409781274),
#    ('distribution', 3005.72409781274),
#    ('mode', 3005.72409781274)],
#   [('cluster', 4299.902051931015),
#    ('classification', 3155.6951553792906),
#    ('supervis', 2649.8344126737206),
#    ('supervise', 2188.1354736816784),
#    ('classification supervise', 1397.2230068381768)],
#   [('topolog', 7873.536564594247),
#    ('log', 7873.536564594247),
#    ('topologique', 6217.51896928633),
#    ('logique', 6217.51896928633),
#    ('model', 4099.6729282306105)],
#   [('regl', 45238.316699034316),
#    ('regle', 20087.273489157767),
#    ('action', 4316.139229898507),
#    ('extraction', 4316.139229898507),
#    ('extraction regl', 2063.1639212565324)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)]],
#  [[('classification', 23484.896120951453),
#    ('concept', 12127.898509214845),
#    ('methode', 5638.636482602768),
#    ('tir', 4858.190218529074),
#    ('model', 4489.757260494273)],
#   [('regl', 18292.635246306578),
#    ('associ', 8116.754020252936),
#    ('regle', 5859.268388069028),
#    ('association', 5859.268388069028),
#    ('dassoci', 5188.340227149487)],
#   [('model', 9700.140590378667),
#    ('mode', 9700.140590378667),
#    ('log', 7423.176304664381),
#    ('ontologie', 5450.340590378667),
#    ('ontolog', 5450.340590378667)],
#   [('analys', 8910.386410438667),
#    ('analyse', 5384.025839751249),
#    ('olap', 2218.6237645242713),
#    ('model', 1751.2165012298478),
#    ('present', 1751.2165012298478)],
#   [('cart', 13215.874630980466),
#    ('carte', 12177.833753612571),
#    ('docu', 9318.415009843877),
#    ('document', 8450.176724699311),
#    ('structur', 6100.165757600607)],
#   [('image', 9067.63750228269),
#    ('segmentation', 6546.280283031355),
#    ('segment', 6546.280283031355),
#    ('classification', 2733.0909782185213),
#    ('etape', 2256.942315116917)],
#   [('base', 6309.62235638058),
#    ('action', 5626.143975515815),
#    ('model', 3810.729992075154),
#    ('mode', 3810.729992075154),
#    ('fouill', 3283.9323839794774)],
#   [('evalu', 6686.890299166113),
#    ('decis', 4638.688544780147),
#    ('evaluation', 4038.952677333753),
#    ('decision', 2963.9780184643573),
#    ('arbre', 2963.9780184643573)],
#   [('dependanc', 9646.84143326259),
#    ('dependance', 7242.388908010065),
#    ('fonctionnel', 4280.831332252489),
#    ('fonction', 4280.831332252489),
#    ('apprentissage', 1536.314160535317)],
#   [('motif', 46300.96425098586),
#    ('sequentiel', 11552.275270553311),
#    ('motif sequentiel', 11552.275270553311),
#    ('action', 10567.658380748986),
#    ('extraction', 7067.687217000274)],
#   [('image', 12430.464949501027),
#    ('dimag', 10269.48189865357),
#    ('rechercher', 8314.687709791584),
#    ('recherche', 8314.687709791584),
#    ('afc', 5023.665918024029)],
#   [('system', 8500.716171694676),
#    ('adapt', 6713.06765684319),
#    ('detection', 3770.1171617936848),
#    ('concept', 2614.8151815956644),
#    ('present', 2116.207508328338)],
#   [('item', 45592.79352925396),
#    ('itemset', 34643.01214702547),
#    ('frequent', 4299.892259860457),
#    ('ditemset', 3611.275898788524),
#    ('ditems', 3611.275898788524)],
#   [('semantiqu', 20835.07795512048),
#    ('log', 18254.56393642889),
#    ('ontolog', 12206.941328507217),
#    ('ontologie', 10251.738391257551),
#    ('present', 6852.950674301607)],
#   [('reseau', 20771.151605749666),
#    ('reseaux', 7056.3128960722515),
#    ('social', 7056.3128960722515),
#    ('log', 4351.489466530656),
#    ('analys', 2909.716970775138)],
#   [('preference', 4638.445974143683),
#    ('reference', 4638.445974143683),
#    ('utilisateur', 2965.413151386571),
#    ('present', 2268.6494752377744),
#    ('voir', 1665.0542892421506)],
#   [('graph', 8955.07212425549),
#    ('present', 8955.07212425549),
#    ('forme', 4727.865137355926),
#    ('temp', 4727.865137355926),
#    ('analys', 3616.2843513297244)],
#   [('flux', 12782.241173930073),
#    ('donneer', 6027.898215768611),
#    ('resum', 4978.11153338794),
#    ('requet', 4978.11153338794),
#    ('cube', 4490.853430854056)],
#   [('groupe', 9323.341818820292),
#    ('methode', 6355.840986873537),
#    ('cluster', 3955.102218154735),
#    ('nom', 3443.4740983544025),
#    ('clustering', 2967.268607505817)],
#   [('fin', 4551.442772892666),
#    ('humain', 3876.311729635668),
#    ('sit', 3876.311729635668),
#    ('corpu', 3255.3511698392304),
#    ('defini', 3255.3511698392304)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)]],
#  [[('fonction', 11387.137683346937),
#    ('entrepot', 7512.4227300759085),
#    ('distribu', 3595.1018578017656),
#    ('fin', 3595.1018578017656),
#    ('distribution', 2838.8012347488057)],
#   [('graph', 10296.311981641333),
#    ('present', 9182.170556251578),
#    ('visualis', 7145.226235538882),
#    ('represent', 6222.4233402159425),
#    ('visualisation', 5363.399954915274)],
#   [('log', 33112.96048558584),
#    ('text', 27709.243950152773),
#    ('ontolog', 10904.792506583217),
#    ('ontologie', 8610.812979024162),
#    ('texte', 8610.812979024162)],
#   [('docu', 56240.759651475695),
#    ('document', 54282.746931911795),
#    ('xml', 31985.41622325038),
#    ('structur', 16606.838391633177),
#    ('format', 13542.72997249326)],
#   [('model', 14850.62041392716),
#    ('mode', 14850.62041392716),
#    ('modele', 8613.161687512065),
#    ('lalgorithm', 6590.958857323386),
#    ('present', 4838.916404493198)],
#   [('motif', 76632.80339068246),
#    ('action', 9736.10099615567),
#    ('extraction', 9095.918175935221),
#    ('present', 8477.504264874788),
#    ('base', 7880.859262974371)],
#   [('ensembl', 18950.165590897763),
#    ('svm', 13364.526525080355),
#    ('grand', 9813.701684316024),
#    ('donneer', 7750.487246948721),
#    ('algorithme', 5111.6687756111405)],
#   [('log', 8839.734969098632),
#    ('concept', 7156.593883827313),
#    ('model', 5651.046597005609),
#    ('mode', 5651.046597005609),
#    ('terme', 5651.046597005609)],
#   [('regl', 5507.392410709334),
#    ('fouill', 2269.606414654108),
#    ('present', 2269.606414654108),
#    ('mesure', 2269.606414654108),
#    ('bayesien', 2269.606414654108)],
#   [('mode', 15809.551273683279),
#    ('model', 12486.173614108811),
#    ('system', 12486.173614108811),
#    ('outil', 8664.30127368328),
#    ('present', 7014.492763044982)],
#   [('agregation', 6470.204538784831),
#    ('base', 4629.1360824089925),
#    ('baser', 3823.9186327445627),
#    ('regl', 3823.9186327445627),
#    ('donneer', 3823.9186327445627)],
#   [('web', 39484.91870441287),
#    ('sit', 17211.816852561024),
#    ('log', 17211.816852561024),
#    ('site', 9843.289074783248),
#    ('tir', 5526.3847537955935)],
#   [('apprentissage', 7570.36150291986),
#    ('model', 4253.836641041406),
#    ('mode', 4253.836641041406),
#    ('dapprentissage', 3359.282313232935),
#    ('taux', 2570.2049651666366)],
#   [('log', 7274.074585942475),
#    ('analys', 6008.007004105093),
#    ('format', 6008.007004105093),
#    ('document', 4862.898239585558),
#    ('docu', 4862.898239585558)],
#   [('cluster', 17579.1807570312),
#    ('apprentissage', 7302.874987800433),
#    ('tir', 6588.9499878004335),
#    ('partir', 5911.7390903645355),
#    ('clustering', 5911.7390903645355)],
#   [('classification', 24935.0238865803),
#    ('base', 10416.68976893324),
#    ('present', 9793.007415992062),
#    ('methode', 6455.200357168533),
#    ('resultat', 5496.612121874416)],
#   [('graph', 10932.067107673713),
#    ('present', 6990.136073190954),
#    ('symbolique', 6990.136073190954),
#    ('utilise', 5348.331475489805),
#    ('utiliser', 4609.7194065242875)],
#   [('graph', 13143.770287831672),
#    ('graphe', 6100.697975747942),
#    ('rechercher', 6100.697975747942),
#    ('docu', 6100.697975747942),
#    ('recherche', 6100.697975747942)],
#   [('regl', 163013.32454855548),
#    ('regle', 104291.75687614166),
#    ('associ', 14201.206876141667),
#    ('dassoci', 8292.310324417533),
#    ('association', 7061.956876141669)],
#   [('mode', 7489.7593209357265),
#    ('model', 6632.649320935724),
#    ('video', 6632.649320935724),
#    ('modele', 4373.722957299361),
#    ('present', 3724.882048208452)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)],
#   [('risquer', 0),
#    ('consister', 0),
#    ('dedie', 0),
#    ('document', 0),
#    ('efficacite', 0)]]]

# %% [markdown]
# # Diachronic Analysis

# %%
def inter(listA, listB):
    return np.intersect1d(listA, listB)
    
# cluster_t and cluster_s must be in two different partitions
def proba(num_cluster_t, num_cluster_s, num_partition_T, num_partition_S):
    total_inter = 0
    total_t = 0
    for f in range(0, len(labels[num_partition_T][num_cluster_t])):
        for f_s in labels[num_partition_S][num_cluster_s]:
            if labels[num_partition_T][num_cluster_t][f][0] == f_s[0]:
                total_inter += labels[num_partition_T][num_cluster_t][f][1]
                break
        total_t += labels[num_partition_T][num_cluster_t][f][1]
    if total_t == 0:
        return 0
    return total_inter / total_t
    

def P_A(num_cluster_s, num_partition_T, num_partition_S):
    # first, we have to know what are the cluster which got the label
    total = 0
    nb_computation = 0
    for label_s in labels[num_partition_S][num_cluster_s]:
        for num_cluster_t in range(0, len(partitions[num_partition_T])):
            if label_s in labels[num_partition_T][num_cluster_t]:
                total += proba(num_cluster_t, num_cluster_s, num_partition_T, num_partition_S)
                nb_computation += 1
    if nb_computation == 0:
        return 0
    return total / nb_computation

# Define a coeficient for the activity 
def activity(num_partition_S, num_partition_T):
    res = 0
    for num_cluster_s in range(0, len(partitions[num_partition_S])):
        res += P_A(num_cluster_s, num_partition_T, num_partition_S)
    return res / len(partitions[num_partition_S])

# Ecart-type, but it isn't very usefull xD
sigma_t = 0.01
sigma_s = 0.01

# Our Graal
# Does cluster_t is similar to cluster_s?
def similar(num_cluster_t, num_cluster_s, num_partition_T, num_partition_S):
    cond1 = proba(num_cluster_t, num_cluster_s, num_partition_T, num_partition_S) > P_A(num_cluster_s, num_partition_T, num_partition_S)
    cond2 = proba(num_cluster_t, num_cluster_s, num_partition_T, num_partition_S) > activity(num_partition_S, num_partition_T) + sigma_s
    
    cond1 = proba(num_cluster_t, num_cluster_s, num_partition_T, num_partition_S) > P_A(num_cluster_s, num_partition_T, num_partition_S)
    cond2 = proba(num_cluster_t, num_cluster_s, num_partition_T, num_partition_S) > activity(num_partition_T, num_partition_S) + sigma_t
    return cond1 and cond2 and cond3 and cond4

# %%
similar(3, 3, 0, 1)
# Out:
# False

# %%
print(labels[0][1])
labels[0][1][0][1]
# Out:
# [('concept', 3916.292868920033), ('treillis', 3335.119791996956), ('similarit', 2800.600561227725), ('similarite', 2312.7351766123406), ('mesure', 1871.5236381508018)]
# 3916.292868920033
