# %%
import nltk
import pandas as pd
import random
import numpy as np
import string
import math

from nltk import ngrams
from nltk.corpus import stopwords
from nltk.stem.snowball import FrenchStemmer
from nltk.tokenize import word_tokenize

from numpy import array
from collections import Counter
from scipy.sparse import csr_matrix

from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
from gensim import corpora, models, utils
from gensim.test.utils import common_corpus, common_dictionary, get_tmpfile
from gensim.models import LsiModel
from gensim.corpora import Dictionary

import re

# %%
# Use spacy lib
# On https://spacy.io/

import spacy
nlp = spacy.load('fr')

# %%
##############
# Parameters #
##############

min_gram = 1
max_gram = 3

# To create ours partitions, we must first know the years which will be the limits
limit_years = [2007, 2010, 2014]

# Ignore words that appear at a frequency less than max_frequ in the corpus
max_frequ = 0.8

# Ignore words appearing less than min_appear in the whole corpus
min_appear = 5

# Number of clusters by partitions
nb_clusters = 5

# %%
# Datas preprocessing methods.

# Lemmatisation without poncutations

stemmer = nltk.stem.snowball.FrenchStemmer()
fstw = stopwords.words('french')

# French Stop Words, extraits depuis le fichier stopwords-fr.txt + stopwords french de nltk
sourceFST = [x.replace('\n', '') for x in open('stopwords-fr.txt', mode="r", encoding="utf-8").readlines()]+fstw
sourceFST += [x.replace('\n', '') for x in open('perso_words-fr.txt', mode="r", encoding="utf-8").readlines()]

# Based on ration of french and english stopwords
def isEnglish(article):
    total_fsw = len([x for x in article.split() if x in sourceFST])
    total_esw = len([x for x in article.split() if x in stopwords.words('english')])
    ratio = 100
    if total_fsw != 0:
        ratio = total_esw/total_fsw
    return ratio > 1 and total_esw > 3

def lemmatize(article):
    arti_lower = article.lower()
    arti_2words = re.sub(" [0-z][0-z] ", " ", arti_lower) # word of length < 2
    arti_e = re.sub("(é|è|ê)", "e", arti_2words)
    arti_o = re.sub("à", "a", arti_e)
    arti_i = re.sub("ô", "o", arti_o)
    artiregex = re.sub("î", "i", arti_i)
    output = []
    outPonc = artiregex.translate(artiregex.maketrans("","", string.punctuation))
    outLem = nlp(outPonc)
    for token in outLem:
        if token.lemma_ not in sourceFST and [x for x in token.lemma_ if x not in "0123456789"] != []:
            output.append(token.lemma_)
    res = ' '.join(output)
    return res

# %%
# Data Reading
data = pd.read_csv('export_articles_EGC_2004_2018.csv', sep='\t', header=0)

# %%
# Let's process our corpus, and determine a limit to split it in partitions

# usable[] correspond to our corpus processed
# limits[] let us know when to delimit partitions
limits = []
usable = []

prev_year = data['year'][0]
numArti = 0
for i in range(0, len(data['abstract']), 1):
    #if not null, empty, or whatever (so if there is a abstract):
    if not isinstance(data['abstract'][i], float) and not isEnglish(data['abstract'][i]):
        text = data['abstract'][i]
        if not isinstance(data['title'][i], float):
            text += " "+data['title'][i]

        numArti+=1
        usable.append(re.sub(" [0-z][0-z] ", " ", stemmer.stem(lemmatize(text))))
        year = data['year'][i]
        if year != prev_year:
            prev_year = year
            if year in limit_years:
                limits.append(numArti)
limits.append(numArti)

# %%
# Post-process word removal
post_words = [x.replace('\n', '') for x in open('post_process_words-fr.txt', mode="r", encoding="utf-8").readlines()]

for i in range(0, len(usable)):
    arti = usable[i].split()
    res = []
    for word in arti:
        if word not in post_words:
            res.append(word)
    usable[i] = ' '.join(res)

# %%
# Display pre-processed datas

vectorizer = TfidfVectorizer(stop_words=sourceFST, use_idf=True, ngram_range=(min_gram, max_gram), max_df=max_frequ, min_df=min_appear)
tfidf = vectorizer.fit_transform(usable)

print("nombre d'articles =", len(usable))
print("nombre de mots =", len(tfidf.toarray()[0]))
print("limits =", limits)

usable[0]
# Out:
# nombre d'articles = 991
# nombre de mots = 2385
# limits = [223, 468, 694, 991]
# 'plateforme objectif permettre citoyen euxmemer tweet politique devenement specifiqu francepour cas lelection presidentiell ideo2017 analyser quasitemps reel message candidat fournir principal caracteristiqueslusage lexiqu politique comparaison entrer candidat ideo2017 plateforme citoyen dediee lanalyse tweet evenement polit'

# %%
# Creation of partitions_tfidf[], which give us the TFIDF of each cluster of each partition
# partitions_tfidf[num_partition][num_doc][num_word]
# Beware, num_doc can't be equals to 1091 (max). You have partitions, so every doc aren't in every partitions
# num_word can be found via vectorizer.get_feature_name()
partitions_tfidf = []
beg = 0
for l in limits:
    last = l
    partitions_tfidf.append([list(x) for x in list(tfidf.toarray())[beg:last]])
    beg = l

# %%
vectorizer.get_feature_names()
# Out:
# ['acce',
#  'accessible',
#  'achat',
#  'acquisition',
#  'acquérir',
#  'acteur',
#  'actif',
#  'action',
#  'activite',
#  'actuel',
#  'actuellement',
#  'adapt',
#  'adaptatif',
#  'adaptation',
#  'adapte',
#  'adaptee',
#  'adapter',
#  'adequat',
#  'adn',
#  'adopter',
#  'afc',
#  'affiner',
#  'agent',
#  'agregation',
#  'aid',
#  'aider',
#  'ainsiqu',
#  'ajoutee',
#  'ajouter',
#  'ala',
#  'aleatoir',
#  'algebriqu',
#  'algorithm',
#  'algorithm classification',
#  'algorithm dapprentissage',
#  'algorithm dextraction',
#  'algorithm efficace',
#  'algorithme',
#  'algorithme dapprentissage',
#  'algorithme dextraction',
#  'algorithme fouiller',
#  'algorithme incremental',
#  'algorithmique',
#  'alignement',
#  'alternatif',
#  'amelior',
#  'amelioration',
#  'ameliore',
#  'amelioree',
#  'ameliorer',
#  'ameliorer qualite',
#  'amene',
#  'amont',
#  'analys',
#  'analyse',
#  'analyser',
#  'analyser donnee',
#  'analyser factoriel',
#  'analyser semantiqu',
#  'analytique',
#  'anne',
#  'annees',
#  'annot',
#  'annotation',
#  'annotation semantiqu',
#  'annoter',
#  'anormal',
#  'anr',
#  'apartir',
#  'apparer',
#  'appartenir',
#  'appel',
#  'appele',
#  'appelee',
#  'appeler',
#  'applicable',
#  'applicatif',
#  'application',
#  'application donnee',
#  'application reell',
#  'appliqu',
#  'applique',
#  'appliquee',
#  'appliquees',
#  'appliquer',
#  'apport',
#  'apporter',
#  'apprehender',
#  'apprendre',
#  'apprentissage',
#  'apprentissage automatique',
#  'apprentissage supervis',
#  'approche',
#  'approche existant',
#  'appropriee',
#  'approprier',
#  'approximatif',
#  'approximation',
#  'apr',
#  'aprer',
#  'arbitraire',
#  'arborescent',
#  'arbre',
#  'arbre decision',
#  'architecturer',
#  'article',
#  'article decrit',
#  'article etuder',
#  'article etudie',
#  'article interesser',
#  'article introduire',
#  'article method',
#  'article methode',
#  'article montrer',
#  'article present',
#  'article present method',
#  'article present methode',
#  'article presenter',
#  'article presenter method',
#  'article presenton',
#  'article proposer',
#  'article proposer method',
#  'article proposer methode',
#  'article proposer methodologie',
#  'article traire',
#  'articlenou',
#  'artificiel',
#  'ascendant',
#  'ascendant hierarchiqu',
#  'aspect',
#  'assister',
#  'associ',
#  'association',
#  'associe',
#  'associee',
#  'associeer',
#  'associees',
#  'associer',
#  'assurer',
#  'attaquer',
#  'atteindre',
#  'attention',
#  'attribu',
#  'attribut',
#  'atypique',
#  'augmenter',
#  'automat',
#  'automate',
#  'automatique',
#  'automatiquement',
#  'automatiser',
#  'autoorganisatrice',
#  'autour',
#  'avancee',
#  'avantage',
#  'axe',
#  'axer',
#  'axiome',
#  'baptis',
#  'base',
#  'base donnee',
#  'base donnee relationnel',
#  'base donneer',
#  'baseesur',
#  'baser',
#  'baser connaissance',
#  'baser dapprentissage',
#  'baser donne',
#  'baser donneer',
#  'baser modele',
#  'baser technique',
#  'batch',
#  'bayesien',
#  'bayesien naïf',
#  'bayesienn',
#  'benchmark',
#  'beneficier',
#  'besoin',
#  'biais',
#  'bibliographique',
#  'biclustering',
#  'binaire',
#  'bioinformatique',
#  'biologique',
#  'biomedical',
#  'bloc',
#  'block',
#  'booleenn',
#  'boosting',
#  'born',
#  'bruitees',
#  'brut',
#  'cadrer',
#  'cadrer article',
#  'cadrer classification',
#  'cadrer general',
#  'cadrer lanalyse',
#  'cadrer projet',
#  'cadrer rechercher',
#  'cadrer theoriqu',
#  'cadrer travail',
#  'calcul',
#  'calcul similarite',
#  'calculee',
#  'calculer',
#  'campagne',
#  'cancer',
#  'candidat',
#  'capable',
#  'capacite',
#  'capteur',
#  'capturer',
#  'caracter',
#  'caractere',
#  'caracterisation',
#  'caracterise',
#  'caracteriseer',
#  'caracteriser',
#  'caracteristiqu',
#  'caracteristique',
#  'caracteristiquer',
#  'cart',
#  'carte',
#  'carte autoorganisatrice',
#  'carte topologique',
#  'cartographie',
#  'cartographique',
#  'cas',
#  'cas donnee',
#  'categorie',
#  'categoriel',
#  'categoriell',
#  'categorisation',
#  'causer',
#  'celer',
#  'celer proposer',
#  'cell',
#  'celleci',
#  'cellesci',
#  'cellule',
#  'celuici',
#  'centaine',
#  'central',
#  'centree',
#  'centrer',
#  'cesser',
#  'cestadir',
#  'chain',
#  'chaine',
#  'chaine markov',
#  'challenge',
#  'champ',
#  'changement',
#  'changer',
#  'charger',
#  'chemin',
#  'chercher',
#  'chercheur',
#  'choisir',
#  'choix',
#  'choix mesurer',
#  'chronique',
#  'cibl',
#  'cibler',
#  'clairement',
#  'classe',
#  'classement',
#  'classer',
#  'classificateur',
#  'classification',
#  'classification automatique',
#  'classification croise',
#  'classification document',
#  'classification donnee',
#  'classification hierarchiqu',
#  'classification multilabel',
#  'classification supervise',
#  'classification supervisee',
#  'classifier',
#  'classifieur',
#  'classifieur bayesien',
#  'classifieur bayesien naïf',
#  'classique',
#  'cle',
#  'clef',
#  'client',
#  'cluster',
#  'clustering',
#  'coclustering',
#  'codage',
#  'coefficient',
#  'coeur',
#  'cognitif',
#  'coherence',
#  'collaboratif',
#  'collaboration',
#  'collecter',
#  'collectif',
#  'collection',
#  'collection document',
#  'colonne',
#  'combin',
#  'combinaison',
#  'combinatoire',
#  'combiner',
#  'commencer',
#  'commercial',
#  'commun',
#  'communaut',
#  'communautair',
#  'communautaire',
#  'communaute',
#  'communication',
#  'compact',
#  'compacter',
#  'comparaison',
#  'comparaison entrer',
#  'comparatif',
#  'comparee',
#  'comparer',
#  'comparer resultat',
#  'compatible',
#  'competence',
#  'complementair',
#  'complementarite',
#  'complet',
#  'completer',
#  'complex',
#  'complexe',
#  'complexit',
#  'complexite',
#  'comportement',
#  'comportemer',
#  'comporter',
#  'composant',
#  'compose',
#  'composer',
#  'comprehension',
#  'comprendre',
#  'compromis',
#  'compromis entrer',
#  'compter',
#  'concentrer',
#  'concept',
#  'concept treillis',
#  'concepteur',
#  'conception',
#  'conceptuel',
#  'concerner',
#  'concevoir',
#  'concis',
#  'conclure',
#  'conclusion',
#  'concret',
#  'condensee',
#  'condensees',
#  'condition',
#  'conditionnel',
#  'conduire',
#  'conferenc',
#  'conference',
#  'confiance',
#  'configuration',
#  'confirmer',
#  'conflit',
#  'confronter',
#  'conjoint',
#  'conjointement',
#  'connaiss',
#  'connaissance',
#  'connaissance baser',
#  'connaissance domaine',
#  'connaissance expert',
#  'connaissance partir',
#  'connaissance partir donnee',
#  'connaissance priori',
#  'connaissancer',
#  'connaître',
#  'connexion',
#  'connu',
#  'consequent',
#  'conserver',
#  'consider',
#  'considere',
#  'consideree',
#  'considerer',
#  'consist',
#  'consister',
#  'consommation',
#  'constant',
#  'constater',
#  'constituer',
#  'construction',
#  'construction automatique',
#  'construction darbr',
#  'construction dontologie',
#  'construir',
#  'construire',
#  'construire partir',
#  'construit',
#  'construit partir',
#  'contenir',
#  'contenir document',
#  'contenu',
#  'context',
#  'contexte',
#  'contextuel',
#  'contingence',
#  'continu',
#  'continuer',
#  'contraindre',
#  'contraint',
#  'contrainte',
#  'contrairement',
#  'contribuer',
#  'contribution',
#  'controle',
#  'controler',
#  'convergence',
#  'convier',
#  'conçu',
#  'cooperativ',
#  'corpu',
#  'corpus',
#  'correct',
#  'correctement',
#  'correlation',
#  'correlation entrer',
#  'correspondance',
#  'correspondance afc',
#  'correspondance entrer',
#  'correspondant',
#  'correspondre',
#  'couleur',
#  'coupl',
#  'couple',
#  'coupler',
#  'courir',
#  'courir temps',
#  'cours',
#  'court',
#  'couverture',
#  'couvrir',
#  'coût',
#  'coûteux',
#  'creation',
#  'cree',
#  'creer',
#  'criter',
#  'critere',
#  'critere devaluation',
#  'croise',
#  'croisee',
#  'croiser',
#  'croissance',
#  'croyance',
#  'croître',
#  'cube',
#  'cuber',
#  'culturel',
#  'cycle',
#  'dabord',
#  'daccelerer',
#  'dacquisition',
#  'dadapter',
#  'dagregation',
#  'daid',
#  'daid decision',
#  'daider',
#  'dalgorithme',
#  'dalignemer',
#  'dameliorer',
#  'dameliorer performance',
#  'danalyse',
#  'danalyser',
#  'dannotation',
#  'danscet',
#  'danscet article',
#  'danscet article proposer',
#  'dansl',
#  'dansun',
#  'dappariemer',
#  'dapparition',
#  'dappartenance',
#  'dapplication',
#  'dapporter',
#  'dapprendre',
#  'dapprentissage',
#  'dapprentissage automatique',
#  'dapprentissage supervis',
#  'darbr',
#  'darbr decision',
#  'darticl',
#  'dassoci',
#  'dassociation',
#  'dater',
#  'dater mining',
#  'dater stream',
#  'dattribut',
#  'dattributs',
#  'daugmenter',
#  'dautre',
#  'dautre partir',
#  'debut',
#  'decd',
#  'decennie',
#  'dechantillon',
#  'dechantillonnage',
#  'decider',
#  'decideur',
#  'decis',
#  'decision',
#  'decisionnel',
#  'decisionnell',
#  'decomposition',
#  'decoupage',
#  'decouvert',
#  'decouverte',
#  'decouverte motif',
#  'decouvrir',
#  'decouvrir motif',
#  'decrir',
#  'decrire',
#  'decrit',
#  'decrite',
#  'decrivant',
#  'decriver',
#  'decrivons',
#  'dedie',
#  'dediee',
#  'dedition',
#  'dedonnee',
#  'deduire',
#  'defaut',
#  'deffectuer',
#  'defi',
#  'defi egc',
#  'defini',
#  'definie',
#  'definier',
#  'definir',
#  'definis',
#  'definisser',
#  'definissons',
#  'definit',
#  'definition',
#  'degager',
#  'degr',
#  'degre',
#  'delagage',
#  'delement',
#  'demander',
#  'demarch',
#  'demonstration',
#  'denrichir',
#  'dense',
#  'densembl',
#  'densite',
#  'dentiter',
#  'dentre',
#  'dentrepris',
#  'depart',
#  'dependanc',
#  'dependance',
#  'dependance fonctionnel',
#  'depender',
#  'deper',
#  'dequivalence',
#  'derive',
#  'derreur',
#  'descripteur',
#  'descriptif',
#  'description',
#  'desdonnee',
#  'desequilibre',
#  'destimer',
#  'detablir',
#  'detailler',
#  'detat',
#  'detecter',
#  'detection',
#  'detection changement',
#  'detectiond',
#  'detendre',
#  'determination',
#  'determine',
#  'determiner',
#  'detr',
#  'detre',
#  'detude',
#  'detudier',
#  'deuxieme',
#  'devaluation',
#  'devaluer',
#  'devaluer qualite',
#  'developp',
#  'developpe',
#  'developpee',
#  'developpement',
#  'developpemer',
#  'developper',
#  'devenement',
#  'devenir',
#  'devenir plaire',
#  'devoir',
#  'devoir permettre',
#  'devolution',
#  'dexecution',
#  'dexempl',
#  'dexperience',
#  'dexperimentation',
#  'dexploiter',
#  'dexploration',
#  'dexplorer',
#  'dexpression',
#  'dexprimer',
#  'dextraction',
#  'dextraction connaissance',
#  'dextraction connaissance partir',
#  'dextraction motif',
#  'dextrair',
#  'dextraire',
#  'dheuristiqu',
#  'diagnostic',
#  'dictionnair',
#  'didentification',
#  'didentifier',
#  'difference',
#  'differenter',
#  'difficile',
#  'difficilement',
#  'difficult',
#  'difficulte',
#  'diffusion',
#  'dimag',
#  'dimage',
#  'dimager',
#  'dimension',
#  'dincertitude',
#  'dindexation',
#  'dindice',
#  'dindividus',
#  'dinduction',
#  'dinference',
#  'dinferer',
#  'dinfluence',
#  'dinform',
#  'dinformation',
#  'dintegration',
#  'dintegrer',
#  'dinteraction',
#  'dinteraction entrer',
#  'dinteret',
#  'dinternet',
#  'dinterpretation',
#  'dinterrogation',
#  'dintroduir',
#  'direct',
#  'direction',
#  'discret',
#  'discretisation',
#  'discriminant',
#  'discriminanter',
#  'discrimination',
#  'discriminer',
#  'discussion',
#  'discuter',
#  'disponible',
#  'disposer',
#  'dispositif',
#  'disposition',
#  'dissimilarit',
#  'dissimilarite',
#  'dissimilarite entrer',
#  'distance',
#  'distancer',
#  'distancer entrer',
#  'distinct',
#  'distinguer',
#  'distribu',
#  'distribuer',
#  'distribution',
#  'ditems',
#  'ditemset',
#  'ditemset frequent',
#  'diversite',
#  'diviser',
#  'dizaine',
#  'dobjet',
#  'dobjets',
#  'dobtenir',
#  'docu',
#  'document',
#  'document textuel',
#  'document xml',
#  'documentaire',
#  'doffr',
#  'domaine',
#  'domaine dapplication',
#  'domaine fouiller',
#  'domaine lapprentissage',
#  'donne',
#  'donnee',
#  'donnee article',
#  'donnee artificiel',
#  'donnee baser',
#  'donnee cluster',
#  'donnee disponible',
#  'donnee geographiqu',
#  'donnee grand',
#  'donnee issu',
#  'donnee massif',
#  'donnee multidimensionnel',
#  'donnee numeriqu',
#  'donnee permettre',
#  'donnee plaire',
#  'donnee pouvoir',
#  'donnee presenter',
#  'donnee qualitatif',
#  'donnee reel',
#  'donnee reell',
#  'donnee reell issu',
#  'donnee reell montrer',
#  'donnee relationnel',
#  'donnee sequentiell',
#  'donnee simuleer',
#  'donnee symbolique',
#  'donnee synthetiqu',
#  'donnee textuel',
#  'donnee visualisation',
#  'donneer',
#  'donneer article',
#  'donneer luci',
#  'donneer plaire',
#  'donneer reell',
#  'donneer textuel',
#  'donnees',
#  'donner',
#  'donner resultat',
#  'dontologie',
#  'dontologie partir',
#  'dontologier',
#  'dopinion',
#  'doptimisation',
#  'dordre',
#  'dorigine',
#  'doter',
#  'doutil',
#  'doutils',
#  'duree',
#  'durer',
#  'durer processus',
#  'dusage',
#  'dutilisateur',
#  'dutilisation',
#  'dutiliser',
#  'dynam',
#  'dynamique',
#  'ecd',
#  'echantillon',
#  'echantillonnage',
#  'echell',
#  'echelle',
#  'eclairage',
#  'economiqu',
#  'effectu',
#  'efficace',
#  'efficacement',
#  'efficacite',
#  'effort',
#  'egc',
#  'element',
#  'elev',
#  'eleve',
#  'elevee',
#  'emergent',
#  'empirique',
#  'empiriquement',
#  'employer',
#  'encompte',
#  'encourageant',
#  'encourageant prometteur',
#  'engendrer',
#  'enjeu',
#  'enjeu majeur',
#  'enregistrement',
#  'enrichir',
#  'enrichissement',
#  'ensembl',
#  'ensembl donnee',
#  'ensembl donneer',
#  'ensembl mesure',
#  'ensemble',
#  'ensemble donnee',
#  'ensemble donneer',
#  'ensemble regl',
#  'ensembliste',
#  'entite',
#  'entrainer',
#  'entrepot',
#  'entrepot donnee',
#  'entreprendre',
#  'entreprise',
#  'entrer',
#  'entrer attribut',
#  'entrer classe',
#  'entrer concept',
#  'entrer donnee',
#  'entrer ensemble',
#  'entrer groupe',
#  'entrer individu',
#  'entrer objet',
#  'entrer ontologie',
#  'entrer variable',
#  'environnement',
#  'envisageable',
#  'equivalent',
#  'erreur',
#  'espac',
#  'espace',
#  'espacer',
#  'essentiel',
#  'essentiellement',
#  'estim',
#  'estimateur',
#  'estimation',
#  'estimation densite',
#  'estimee',
#  'estimer',
#  'etablie',
#  'etablir',
#  'etablisser',
#  'etape',
#  'etat',
#  'etde',
#  'etendu',
#  'eter',
#  'etiquetage',
#  'etiquete',
#  'etl',
#  'etle',
#  'etroitement',
#  'etude',
#  'etude comparatif',
#  'etude experimental',
#  'etuder',
#  'etudie',
#  'etudiee',
#  'etudier',
#  'euclidien',
#  'evalu',
#  'evaluation',
#  'evalue',
#  'evaluee',
#  'evaluees',
#  'evaluer',
#  'evenement',
#  'evidence',
#  'eviter',
#  'evoluer',
#  'evolution',
#  'evolutiv',
#  'exact',
#  'examiner',
#  'exemple',
#  'exhaustif',
#  'exhiber',
#  'existant',
#  'exister',
#  'exister entrer',
#  'experience',
#  'experience meneer',
#  'experience montrer',
#  'experiment',
#  'experimental',
#  'experimentalement',
#  'experimentation',
#  'experimentation jeu',
#  'experimentation jeu donnee',
#  'experimentation menee',
#  'experimentation montrer',
#  'experimentaux',
#  'experimentaux montrer',
#  'expert',
#  'expert domaine',
#  'explicatif',
#  'expliciter',
#  'expliquer',
#  'exploitable',
#  'exploitation',
#  'exploiter',
#  'exploration',
#  'exploratoire',
#  'explorer',
#  'exponentiel',
#  'exposer',
#  'expression',
#  'exprimeer',
#  'exprimer',
#  'extension',
#  'extraction',
#  'extraction connaissance',
#  'extraction motif',
#  'extraction regl',
#  'extraire',
#  'extraire connaissance',
#  'extraire motif',
#  'extrait',
#  'extraite',
#  'face',
#  'facile',
#  'facilement',
#  'faciliter',
#  'facteur',
#  'factoriel',
#  'factoriel correspondance',
#  'factoriel correspondance afc',
#  'factorisation',
#  'faible',
#  'faire',
#  'faire appel',
#  'faire face',
#  'faire lobjet',
#  'faire partir',
#  'faisabilite',
#  'famille',
#  'favoriser',
#  'feature',
#  'ferme',
#  'ferme frequent',
#  'fiabilite',
#  'fiable',
#  'fichier',
#  'filtrage',
#  'filtrer',
#  'fin',
#  'final',
#  'finalement',
#  'financier',
#  'fixe',
#  'fixer',
#  'flexible',
#  'flot',
#  'flot donneer',
#  'flou',
#  'flouer',
#  'flux',
#  'flux donne',
#  'flux donnee',
#  'flux donneer',
#  'focaliser',
#  'fonction',
#  'fonction croyance',
#  'fonctionnalite',
#  'fonctionnel',
#  'fonctionnement',
#  'fonctionner',
#  'fond',
#  'fondamental',
#  'fondee',
#  'fondre',
#  'foret',
#  'foret aleatoir',
#  'formalisation',
#  'formaliser',
#  'formalisme',
#  'format',
#  'formation',
#  'forme',
#  'formel',
#  'formel concept',
#  'former',
#  'former regl',
#  'formulation',
#  'formuler',
#  'fort',
#  'fortement',
#  'fouill',
#  'fouill donneer',
#  'fouiller',
#  'fouiller donne',
#  'fouiller donnee',
#  'fouiller donneer',
#  'fouiller grand',
#  'fouiller texter',
#  'fournir',
#  'framework',
#  'france',
#  'français',
#  'frequence',
#  'frequent',
#  'frequente',
#  'fusion',
#  'futur',
#  'gain',
#  'galoi',
#  'garantir',
#  'gen',
#  'gene',
#  'gener',
#  ...]

# %% [markdown]
# # KMeans & Silhouette Score

# %%
# Applying KMeans on tfidf
# the labels_ give assignment of doc to the cluster number

# %%
# doc_clustering is a dictionnary 
# it looks like -> { doc_number : [partition_number, cluster_number] }
# This is used to reassign doc number to their respective partition and and cluster
doc_clustering = {}

km = KMeans(n_clusters=nb_clusters)

# Silhouette score mean
silhouette_mean = 0

numDoc = 0
for i in range(0, len(limits)):
    dash = km.fit(partitions_tfidf[i])
    
    # Silhouette
    silhouette_mean += silhouette_score(partitions_tfidf[i], dash.labels_)
    
    previousBound = 0
    if i > 0:
        previousBound = limits[i-1]
    for numDocItern in range(0, limits[i]-previousBound):
        doc_clustering[numDoc] = [i, dash.labels_[numDocItern]]
        numDoc+=1
        
silhouette_mean = silhouette_mean / len(limits)

# %%
# We want silhouette scores to be high
silhouette_mean
# Out:
# 0.008628204345838686

# %%
doc_clustering
# Out:
# {0: [0, 1],
#  1: [0, 3],
#  2: [0, 2],
#  3: [0, 3],
#  4: [0, 3],
#  5: [0, 1],
#  6: [0, 1],
#  7: [0, 4],
#  8: [0, 3],
#  9: [0, 1],
#  10: [0, 3],
#  11: [0, 1],
#  12: [0, 0],
#  13: [0, 0],
#  14: [0, 4],
#  15: [0, 0],
#  16: [0, 0],
#  17: [0, 0],
#  18: [0, 3],
#  19: [0, 0],
#  20: [0, 1],
#  21: [0, 1],
#  22: [0, 1],
#  23: [0, 2],
#  24: [0, 0],
#  25: [0, 4],
#  26: [0, 2],
#  27: [0, 0],
#  28: [0, 2],
#  29: [0, 2],
#  30: [0, 1],
#  31: [0, 1],
#  32: [0, 1],
#  33: [0, 3],
#  34: [0, 3],
#  35: [0, 0],
#  36: [0, 1],
#  37: [0, 0],
#  38: [0, 2],
#  39: [0, 3],
#  40: [0, 2],
#  41: [0, 1],
#  42: [0, 0],
#  43: [0, 0],
#  44: [0, 0],
#  45: [0, 1],
#  46: [0, 1],
#  47: [0, 1],
#  48: [0, 0],
#  49: [0, 2],
#  50: [0, 3],
#  51: [0, 2],
#  52: [0, 0],
#  53: [0, 0],
#  54: [0, 0],
#  55: [0, 1],
#  56: [0, 1],
#  57: [0, 2],
#  58: [0, 1],
#  59: [0, 3],
#  60: [0, 3],
#  61: [0, 2],
#  62: [0, 4],
#  63: [0, 4],
#  64: [0, 0],
#  65: [0, 3],
#  66: [0, 3],
#  67: [0, 4],
#  68: [0, 3],
#  69: [0, 3],
#  70: [0, 0],
#  71: [0, 1],
#  72: [0, 0],
#  73: [0, 2],
#  74: [0, 2],
#  75: [0, 0],
#  76: [0, 2],
#  77: [0, 4],
#  78: [0, 3],
#  79: [0, 4],
#  80: [0, 1],
#  81: [0, 1],
#  82: [0, 0],
#  83: [0, 1],
#  84: [0, 0],
#  85: [0, 3],
#  86: [0, 0],
#  87: [0, 3],
#  88: [0, 1],
#  89: [0, 3],
#  90: [0, 0],
#  91: [0, 0],
#  92: [0, 1],
#  93: [0, 1],
#  94: [0, 0],
#  95: [0, 2],
#  96: [0, 0],
#  97: [0, 4],
#  98: [0, 1],
#  99: [0, 1],
#  100: [0, 0],
#  101: [0, 3],
#  102: [0, 3],
#  103: [0, 1],
#  104: [0, 2],
#  105: [0, 2],
#  106: [0, 3],
#  107: [0, 3],
#  108: [0, 3],
#  109: [0, 3],
#  110: [0, 0],
#  111: [0, 0],
#  112: [0, 4],
#  113: [0, 0],
#  114: [0, 1],
#  115: [0, 3],
#  116: [0, 0],
#  117: [0, 0],
#  118: [0, 4],
#  119: [0, 1],
#  120: [0, 1],
#  121: [0, 1],
#  122: [0, 1],
#  123: [0, 1],
#  124: [0, 4],
#  125: [0, 3],
#  126: [0, 0],
#  127: [0, 1],
#  128: [0, 3],
#  129: [0, 3],
#  130: [0, 1],
#  131: [0, 0],
#  132: [0, 0],
#  133: [0, 3],
#  134: [0, 1],
#  135: [0, 0],
#  136: [0, 0],
#  137: [0, 2],
#  138: [0, 3],
#  139: [0, 3],
#  140: [0, 1],
#  141: [0, 2],
#  142: [0, 3],
#  143: [0, 0],
#  144: [0, 0],
#  145: [0, 0],
#  146: [0, 0],
#  147: [0, 2],
#  148: [0, 0],
#  149: [0, 1],
#  150: [0, 2],
#  151: [0, 3],
#  152: [0, 4],
#  153: [0, 1],
#  154: [0, 3],
#  155: [0, 3],
#  156: [0, 0],
#  157: [0, 2],
#  158: [0, 1],
#  159: [0, 3],
#  160: [0, 0],
#  161: [0, 0],
#  162: [0, 0],
#  163: [0, 0],
#  164: [0, 0],
#  165: [0, 1],
#  166: [0, 0],
#  167: [0, 0],
#  168: [0, 0],
#  169: [0, 4],
#  170: [0, 3],
#  171: [0, 2],
#  172: [0, 4],
#  173: [0, 0],
#  174: [0, 0],
#  175: [0, 0],
#  176: [0, 1],
#  177: [0, 0],
#  178: [0, 0],
#  179: [0, 3],
#  180: [0, 3],
#  181: [0, 4],
#  182: [0, 3],
#  183: [0, 0],
#  184: [0, 1],
#  185: [0, 2],
#  186: [0, 2],
#  187: [0, 1],
#  188: [0, 3],
#  189: [0, 3],
#  190: [0, 0],
#  191: [0, 4],
#  192: [0, 3],
#  193: [0, 2],
#  194: [0, 0],
#  195: [0, 2],
#  196: [0, 1],
#  197: [0, 4],
#  198: [0, 2],
#  199: [0, 0],
#  200: [0, 0],
#  201: [0, 1],
#  202: [0, 3],
#  203: [0, 1],
#  204: [0, 3],
#  205: [0, 1],
#  206: [0, 3],
#  207: [0, 3],
#  208: [0, 2],
#  209: [0, 2],
#  210: [0, 3],
#  211: [0, 3],
#  212: [0, 1],
#  213: [0, 1],
#  214: [0, 1],
#  215: [0, 1],
#  216: [0, 1],
#  217: [0, 0],
#  218: [0, 2],
#  219: [0, 1],
#  220: [0, 4],
#  221: [0, 4],
#  222: [0, 2],
#  223: [1, 0],
#  224: [1, 0],
#  225: [1, 0],
#  226: [1, 0],
#  227: [1, 1],
#  228: [1, 4],
#  229: [1, 1],
#  230: [1, 4],
#  231: [1, 3],
#  232: [1, 4],
#  233: [1, 4],
#  234: [1, 4],
#  235: [1, 4],
#  236: [1, 4],
#  237: [1, 3],
#  238: [1, 1],
#  239: [1, 4],
#  240: [1, 2],
#  241: [1, 0],
#  242: [1, 1],
#  243: [1, 3],
#  244: [1, 0],
#  245: [1, 4],
#  246: [1, 1],
#  247: [1, 0],
#  248: [1, 1],
#  249: [1, 4],
#  250: [1, 0],
#  251: [1, 1],
#  252: [1, 0],
#  253: [1, 0],
#  254: [1, 4],
#  255: [1, 3],
#  256: [1, 0],
#  257: [1, 3],
#  258: [1, 0],
#  259: [1, 3],
#  260: [1, 0],
#  261: [1, 0],
#  262: [1, 3],
#  263: [1, 2],
#  264: [1, 0],
#  265: [1, 4],
#  266: [1, 0],
#  267: [1, 0],
#  268: [1, 2],
#  269: [1, 4],
#  270: [1, 1],
#  271: [1, 3],
#  272: [1, 2],
#  273: [1, 0],
#  274: [1, 3],
#  275: [1, 4],
#  276: [1, 1],
#  277: [1, 4],
#  278: [1, 0],
#  279: [1, 0],
#  280: [1, 0],
#  281: [1, 0],
#  282: [1, 4],
#  283: [1, 4],
#  284: [1, 4],
#  285: [1, 4],
#  286: [1, 3],
#  287: [1, 0],
#  288: [1, 4],
#  289: [1, 0],
#  290: [1, 2],
#  291: [1, 4],
#  292: [1, 0],
#  293: [1, 3],
#  294: [1, 0],
#  295: [1, 4],
#  296: [1, 2],
#  297: [1, 4],
#  298: [1, 4],
#  299: [1, 0],
#  300: [1, 3],
#  301: [1, 0],
#  302: [1, 4],
#  303: [1, 0],
#  304: [1, 1],
#  305: [1, 4],
#  306: [1, 4],
#  307: [1, 1],
#  308: [1, 4],
#  309: [1, 4],
#  310: [1, 1],
#  311: [1, 4],
#  312: [1, 3],
#  313: [1, 3],
#  314: [1, 1],
#  315: [1, 2],
#  316: [1, 0],
#  317: [1, 1],
#  318: [1, 1],
#  319: [1, 3],
#  320: [1, 3],
#  321: [1, 4],
#  322: [1, 0],
#  323: [1, 1],
#  324: [1, 1],
#  325: [1, 4],
#  326: [1, 1],
#  327: [1, 0],
#  328: [1, 0],
#  329: [1, 0],
#  330: [1, 2],
#  331: [1, 0],
#  332: [1, 4],
#  333: [1, 1],
#  334: [1, 0],
#  335: [1, 0],
#  336: [1, 4],
#  337: [1, 4],
#  338: [1, 0],
#  339: [1, 4],
#  340: [1, 2],
#  341: [1, 1],
#  342: [1, 0],
#  343: [1, 4],
#  344: [1, 2],
#  345: [1, 4],
#  346: [1, 4],
#  347: [1, 1],
#  348: [1, 1],
#  349: [1, 2],
#  350: [1, 0],
#  351: [1, 1],
#  352: [1, 0],
#  353: [1, 3],
#  354: [1, 1],
#  355: [1, 4],
#  356: [1, 4],
#  357: [1, 2],
#  358: [1, 4],
#  359: [1, 4],
#  360: [1, 4],
#  361: [1, 4],
#  362: [1, 4],
#  363: [1, 1],
#  364: [1, 1],
#  365: [1, 1],
#  366: [1, 1],
#  367: [1, 2],
#  368: [1, 0],
#  369: [1, 3],
#  370: [1, 1],
#  371: [1, 1],
#  372: [1, 0],
#  373: [1, 0],
#  374: [1, 0],
#  375: [1, 2],
#  376: [1, 2],
#  377: [1, 1],
#  378: [1, 1],
#  379: [1, 0],
#  380: [1, 1],
#  381: [1, 0],
#  382: [1, 0],
#  383: [1, 0],
#  384: [1, 0],
#  385: [1, 1],
#  386: [1, 0],
#  387: [1, 2],
#  388: [1, 0],
#  389: [1, 1],
#  390: [1, 4],
#  391: [1, 0],
#  392: [1, 4],
#  393: [1, 2],
#  394: [1, 2],
#  395: [1, 0],
#  396: [1, 4],
#  397: [1, 2],
#  398: [1, 3],
#  399: [1, 1],
#  400: [1, 0],
#  401: [1, 1],
#  402: [1, 1],
#  403: [1, 1],
#  404: [1, 1],
#  405: [1, 0],
#  406: [1, 1],
#  407: [1, 4],
#  408: [1, 0],
#  409: [1, 2],
#  410: [1, 1],
#  411: [1, 0],
#  412: [1, 1],
#  413: [1, 0],
#  414: [1, 0],
#  415: [1, 0],
#  416: [1, 1],
#  417: [1, 4],
#  418: [1, 2],
#  419: [1, 3],
#  420: [1, 1],
#  421: [1, 2],
#  422: [1, 0],
#  423: [1, 3],
#  424: [1, 2],
#  425: [1, 4],
#  426: [1, 0],
#  427: [1, 3],
#  428: [1, 3],
#  429: [1, 0],
#  430: [1, 1],
#  431: [1, 3],
#  432: [1, 0],
#  433: [1, 1],
#  434: [1, 4],
#  435: [1, 2],
#  436: [1, 4],
#  437: [1, 0],
#  438: [1, 0],
#  439: [1, 1],
#  440: [1, 3],
#  441: [1, 1],
#  442: [1, 2],
#  443: [1, 3],
#  444: [1, 4],
#  445: [1, 3],
#  446: [1, 0],
#  447: [1, 4],
#  448: [1, 1],
#  449: [1, 0],
#  450: [1, 2],
#  451: [1, 2],
#  452: [1, 0],
#  453: [1, 1],
#  454: [1, 0],
#  455: [1, 1],
#  456: [1, 1],
#  457: [1, 1],
#  458: [1, 0],
#  459: [1, 0],
#  460: [1, 2],
#  461: [1, 0],
#  462: [1, 4],
#  463: [1, 4],
#  464: [1, 0],
#  465: [1, 1],
#  466: [1, 1],
#  467: [1, 0],
#  468: [2, 3],
#  469: [2, 2],
#  470: [2, 3],
#  471: [2, 3],
#  472: [2, 1],
#  473: [2, 4],
#  474: [2, 2],
#  475: [2, 1],
#  476: [2, 2],
#  477: [2, 3],
#  478: [2, 4],
#  479: [2, 1],
#  480: [2, 4],
#  481: [2, 0],
#  482: [2, 4],
#  483: [2, 2],
#  484: [2, 3],
#  485: [2, 2],
#  486: [2, 1],
#  487: [2, 1],
#  488: [2, 0],
#  489: [2, 2],
#  490: [2, 2],
#  491: [2, 1],
#  492: [2, 3],
#  493: [2, 4],
#  494: [2, 4],
#  495: [2, 1],
#  496: [2, 1],
#  497: [2, 3],
#  498: [2, 3],
#  499: [2, 4],
#  500: [2, 4],
#  501: [2, 0],
#  502: [2, 1],
#  503: [2, 3],
#  504: [2, 3],
#  505: [2, 0],
#  506: [2, 2],
#  507: [2, 1],
#  508: [2, 3],
#  509: [2, 1],
#  510: [2, 0],
#  511: [2, 4],
#  512: [2, 1],
#  513: [2, 4],
#  514: [2, 0],
#  515: [2, 4],
#  516: [2, 3],
#  517: [2, 1],
#  518: [2, 4],
#  519: [2, 1],
#  520: [2, 1],
#  521: [2, 3],
#  522: [2, 3],
#  523: [2, 3],
#  524: [2, 1],
#  525: [2, 1],
#  526: [2, 3],
#  527: [2, 0],
#  528: [2, 3],
#  529: [2, 1],
#  530: [2, 2],
#  531: [2, 2],
#  532: [2, 0],
#  533: [2, 3],
#  534: [2, 2],
#  535: [2, 2],
#  536: [2, 4],
#  537: [2, 4],
#  538: [2, 4],
#  539: [2, 2],
#  540: [2, 4],
#  541: [2, 3],
#  542: [2, 3],
#  543: [2, 3],
#  544: [2, 2],
#  545: [2, 1],
#  546: [2, 3],
#  547: [2, 3],
#  548: [2, 4],
#  549: [2, 2],
#  550: [2, 1],
#  551: [2, 3],
#  552: [2, 1],
#  553: [2, 0],
#  554: [2, 4],
#  555: [2, 0],
#  556: [2, 4],
#  557: [2, 3],
#  558: [2, 2],
#  559: [2, 3],
#  560: [2, 3],
#  561: [2, 1],
#  562: [2, 3],
#  563: [2, 3],
#  564: [2, 1],
#  565: [2, 4],
#  566: [2, 2],
#  567: [2, 3],
#  568: [2, 2],
#  569: [2, 0],
#  570: [2, 2],
#  571: [2, 3],
#  572: [2, 4],
#  573: [2, 3],
#  574: [2, 3],
#  575: [2, 4],
#  576: [2, 2],
#  577: [2, 4],
#  578: [2, 1],
#  579: [2, 0],
#  580: [2, 1],
#  581: [2, 2],
#  582: [2, 3],
#  583: [2, 1],
#  584: [2, 2],
#  585: [2, 2],
#  586: [2, 1],
#  587: [2, 1],
#  588: [2, 3],
#  589: [2, 0],
#  590: [2, 3],
#  591: [2, 3],
#  592: [2, 3],
#  593: [2, 3],
#  594: [2, 3],
#  595: [2, 1],
#  596: [2, 2],
#  597: [2, 2],
#  598: [2, 3],
#  599: [2, 1],
#  600: [2, 4],
#  601: [2, 2],
#  602: [2, 2],
#  603: [2, 2],
#  604: [2, 4],
#  605: [2, 2],
#  606: [2, 4],
#  607: [2, 4],
#  608: [2, 0],
#  609: [2, 1],
#  610: [2, 1],
#  611: [2, 2],
#  612: [2, 0],
#  613: [2, 1],
#  614: [2, 1],
#  615: [2, 3],
#  616: [2, 4],
#  617: [2, 3],
#  618: [2, 2],
#  619: [2, 3],
#  620: [2, 3],
#  621: [2, 3],
#  622: [2, 3],
#  623: [2, 4],
#  624: [2, 4],
#  625: [2, 2],
#  626: [2, 3],
#  627: [2, 4],
#  628: [2, 3],
#  629: [2, 3],
#  630: [2, 3],
#  631: [2, 2],
#  632: [2, 4],
#  633: [2, 1],
#  634: [2, 1],
#  635: [2, 1],
#  636: [2, 0],
#  637: [2, 4],
#  638: [2, 1],
#  639: [2, 0],
#  640: [2, 1],
#  641: [2, 1],
#  642: [2, 1],
#  643: [2, 3],
#  644: [2, 3],
#  645: [2, 0],
#  646: [2, 0],
#  647: [2, 1],
#  648: [2, 1],
#  649: [2, 1],
#  650: [2, 4],
#  651: [2, 4],
#  652: [2, 3],
#  653: [2, 3],
#  654: [2, 0],
#  655: [2, 3],
#  656: [2, 1],
#  657: [2, 1],
#  658: [2, 4],
#  659: [2, 1],
#  660: [2, 3],
#  661: [2, 3],
#  662: [2, 3],
#  663: [2, 3],
#  664: [2, 1],
#  665: [2, 0],
#  666: [2, 1],
#  667: [2, 0],
#  668: [2, 0],
#  669: [2, 2],
#  670: [2, 4],
#  671: [2, 4],
#  672: [2, 2],
#  673: [2, 3],
#  674: [2, 1],
#  675: [2, 1],
#  676: [2, 0],
#  677: [2, 3],
#  678: [2, 2],
#  679: [2, 4],
#  680: [2, 2],
#  681: [2, 1],
#  682: [2, 1],
#  683: [2, 2],
#  684: [2, 2],
#  685: [2, 4],
#  686: [2, 1],
#  687: [2, 2],
#  688: [2, 1],
#  689: [2, 4],
#  690: [2, 3],
#  691: [2, 4],
#  692: [2, 2],
#  693: [2, 4],
#  694: [3, 4],
#  695: [3, 4],
#  696: [3, 1],
#  697: [3, 2],
#  698: [3, 0],
#  699: [3, 1],
#  700: [3, 0],
#  701: [3, 1],
#  702: [3, 3],
#  703: [3, 1],
#  704: [3, 1],
#  705: [3, 2],
#  706: [3, 3],
#  707: [3, 4],
#  708: [3, 0],
#  709: [3, 1],
#  710: [3, 1],
#  711: [3, 1],
#  712: [3, 1],
#  713: [3, 0],
#  714: [3, 3],
#  715: [3, 0],
#  716: [3, 0],
#  717: [3, 1],
#  718: [3, 1],
#  719: [3, 0],
#  720: [3, 1],
#  721: [3, 0],
#  722: [3, 1],
#  723: [3, 4],
#  724: [3, 4],
#  725: [3, 4],
#  726: [3, 2],
#  727: [3, 4],
#  728: [3, 1],
#  729: [3, 1],
#  730: [3, 2],
#  731: [3, 1],
#  732: [3, 4],
#  733: [3, 2],
#  734: [3, 3],
#  735: [3, 2],
#  736: [3, 1],
#  737: [3, 3],
#  738: [3, 2],
#  739: [3, 2],
#  740: [3, 0],
#  741: [3, 0],
#  742: [3, 4],
#  743: [3, 3],
#  744: [3, 1],
#  745: [3, 1],
#  746: [3, 3],
#  747: [3, 3],
#  748: [3, 4],
#  749: [3, 4],
#  750: [3, 1],
#  751: [3, 1],
#  752: [3, 1],
#  753: [3, 4],
#  754: [3, 3],
#  755: [3, 1],
#  756: [3, 4],
#  757: [3, 2],
#  758: [3, 2],
#  759: [3, 0],
#  760: [3, 1],
#  761: [3, 3],
#  762: [3, 1],
#  763: [3, 2],
#  764: [3, 1],
#  765: [3, 2],
#  766: [3, 1],
#  767: [3, 4],
#  768: [3, 0],
#  769: [3, 1],
#  770: [3, 1],
#  771: [3, 0],
#  772: [3, 3],
#  773: [3, 4],
#  774: [3, 1],
#  775: [3, 0],
#  776: [3, 0],
#  777: [3, 2],
#  778: [3, 1],
#  779: [3, 3],
#  780: [3, 3],
#  781: [3, 0],
#  782: [3, 4],
#  783: [3, 1],
#  784: [3, 0],
#  785: [3, 1],
#  786: [3, 2],
#  787: [3, 1],
#  788: [3, 0],
#  789: [3, 4],
#  790: [3, 1],
#  791: [3, 0],
#  792: [3, 0],
#  793: [3, 1],
#  794: [3, 0],
#  795: [3, 0],
#  796: [3, 2],
#  797: [3, 1],
#  798: [3, 4],
#  799: [3, 0],
#  800: [3, 0],
#  801: [3, 4],
#  802: [3, 2],
#  803: [3, 0],
#  804: [3, 4],
#  805: [3, 3],
#  806: [3, 3],
#  807: [3, 0],
#  808: [3, 4],
#  809: [3, 1],
#  810: [3, 1],
#  811: [3, 2],
#  812: [3, 4],
#  813: [3, 0],
#  814: [3, 1],
#  815: [3, 4],
#  816: [3, 2],
#  817: [3, 1],
#  818: [3, 2],
#  819: [3, 3],
#  820: [3, 1],
#  821: [3, 3],
#  822: [3, 0],
#  823: [3, 4],
#  824: [3, 0],
#  825: [3, 3],
#  826: [3, 3],
#  827: [3, 1],
#  828: [3, 3],
#  829: [3, 2],
#  830: [3, 0],
#  831: [3, 1],
#  832: [3, 1],
#  833: [3, 1],
#  834: [3, 4],
#  835: [3, 0],
#  836: [3, 2],
#  837: [3, 2],
#  838: [3, 3],
#  839: [3, 3],
#  840: [3, 1],
#  841: [3, 2],
#  842: [3, 2],
#  843: [3, 3],
#  844: [3, 2],
#  845: [3, 1],
#  846: [3, 4],
#  847: [3, 0],
#  848: [3, 0],
#  849: [3, 3],
#  850: [3, 2],
#  851: [3, 4],
#  852: [3, 0],
#  853: [3, 3],
#  854: [3, 1],
#  855: [3, 2],
#  856: [3, 0],
#  857: [3, 2],
#  858: [3, 1],
#  859: [3, 0],
#  860: [3, 2],
#  861: [3, 0],
#  862: [3, 3],
#  863: [3, 0],
#  864: [3, 0],
#  865: [3, 4],
#  866: [3, 0],
#  867: [3, 1],
#  868: [3, 1],
#  869: [3, 1],
#  870: [3, 3],
#  871: [3, 0],
#  872: [3, 0],
#  873: [3, 3],
#  874: [3, 1],
#  875: [3, 1],
#  876: [3, 4],
#  877: [3, 2],
#  878: [3, 0],
#  879: [3, 4],
#  880: [3, 1],
#  881: [3, 4],
#  882: [3, 4],
#  883: [3, 3],
#  884: [3, 1],
#  885: [3, 2],
#  886: [3, 2],
#  887: [3, 4],
#  888: [3, 3],
#  889: [3, 2],
#  890: [3, 3],
#  891: [3, 3],
#  892: [3, 3],
#  893: [3, 3],
#  894: [3, 0],
#  895: [3, 2],
#  896: [3, 2],
#  897: [3, 2],
#  898: [3, 0],
#  899: [3, 3],
#  900: [3, 1],
#  901: [3, 0],
#  902: [3, 2],
#  903: [3, 2],
#  904: [3, 0],
#  905: [3, 0],
#  906: [3, 1],
#  907: [3, 3],
#  908: [3, 0],
#  909: [3, 2],
#  910: [3, 2],
#  911: [3, 2],
#  912: [3, 4],
#  913: [3, 4],
#  914: [3, 4],
#  915: [3, 4],
#  916: [3, 1],
#  917: [3, 1],
#  918: [3, 0],
#  919: [3, 1],
#  920: [3, 1],
#  921: [3, 2],
#  922: [3, 1],
#  923: [3, 3],
#  924: [3, 1],
#  925: [3, 0],
#  926: [3, 1],
#  927: [3, 4],
#  928: [3, 1],
#  929: [3, 4],
#  930: [3, 1],
#  931: [3, 0],
#  932: [3, 2],
#  933: [3, 3],
#  934: [3, 0],
#  935: [3, 1],
#  936: [3, 1],
#  937: [3, 2],
#  938: [3, 0],
#  939: [3, 4],
#  940: [3, 0],
#  941: [3, 3],
#  942: [3, 4],
#  943: [3, 2],
#  944: [3, 0],
#  945: [3, 1],
#  946: [3, 0],
#  947: [3, 1],
#  948: [3, 3],
#  949: [3, 1],
#  950: [3, 0],
#  951: [3, 2],
#  952: [3, 2],
#  953: [3, 0],
#  954: [3, 1],
#  955: [3, 4],
#  956: [3, 1],
#  957: [3, 1],
#  958: [3, 2],
#  959: [3, 0],
#  960: [3, 1],
#  961: [3, 2],
#  962: [3, 4],
#  963: [3, 3],
#  964: [3, 1],
#  965: [3, 3],
#  966: [3, 2],
#  967: [3, 0],
#  968: [3, 4],
#  969: [3, 0],
#  970: [3, 3],
#  971: [3, 0],
#  972: [3, 1],
#  973: [3, 4],
#  974: [3, 3],
#  975: [3, 3],
#  976: [3, 3],
#  977: [3, 0],
#  978: [3, 1],
#  979: [3, 2],
#  980: [3, 1],
#  981: [3, 1],
#  982: [3, 1],
#  983: [3, 1],
#  984: [3, 4],
#  985: [3, 3],
#  986: [3, 2],
#  987: [3, 3],
#  988: [3, 2],
#  989: [3, 2],
#  990: [3, 1]}

# %%
# Allows to get list of documents number
# return [dou numbers]
# params : partition_number , cluster number
def get_doc(part, clust):
    docs = []
    for i in range(0,len(doc_clustering)):
        if doc_clustering[i][0] == part and doc_clustering[i][1] == clust:
            docs.append(i)
    return docs

# %%
# Get the partitions variable
# Here partitions[part][cluster] = list of docs numbe
partitions = []
for i in range(0, len(limits)):
    clusters = []
    for j in range(0, nb_clusters):
        clusters.append(get_doc(i,j))
    partitions.append(clusters)

# %%
partitions
# Out:
# [[[12,
#    13,
#    15,
#    16,
#    17,
#    19,
#    24,
#    27,
#    35,
#    37,
#    42,
#    43,
#    44,
#    48,
#    52,
#    53,
#    54,
#    64,
#    70,
#    72,
#    75,
#    82,
#    84,
#    86,
#    90,
#    91,
#    94,
#    96,
#    100,
#    110,
#    111,
#    113,
#    116,
#    117,
#    126,
#    131,
#    132,
#    135,
#    136,
#    143,
#    144,
#    145,
#    146,
#    148,
#    156,
#    160,
#    161,
#    162,
#    163,
#    164,
#    166,
#    167,
#    168,
#    173,
#    174,
#    175,
#    177,
#    178,
#    183,
#    190,
#    194,
#    199,
#    200,
#    217],
#   [0,
#    5,
#    6,
#    9,
#    11,
#    20,
#    21,
#    22,
#    30,
#    31,
#    32,
#    36,
#    41,
#    45,
#    46,
#    47,
#    55,
#    56,
#    58,
#    71,
#    80,
#    81,
#    83,
#    88,
#    92,
#    93,
#    98,
#    99,
#    103,
#    114,
#    119,
#    120,
#    121,
#    122,
#    123,
#    127,
#    130,
#    134,
#    140,
#    149,
#    153,
#    158,
#    165,
#    176,
#    184,
#    187,
#    196,
#    201,
#    203,
#    205,
#    212,
#    213,
#    214,
#    215,
#    216,
#    219],
#   [2,
#    23,
#    26,
#    28,
#    29,
#    38,
#    40,
#    49,
#    51,
#    57,
#    61,
#    73,
#    74,
#    76,
#    95,
#    104,
#    105,
#    137,
#    141,
#    147,
#    150,
#    157,
#    171,
#    185,
#    186,
#    193,
#    195,
#    198,
#    208,
#    209,
#    218,
#    222],
#   [1,
#    3,
#    4,
#    8,
#    10,
#    18,
#    33,
#    34,
#    39,
#    50,
#    59,
#    60,
#    65,
#    66,
#    68,
#    69,
#    78,
#    85,
#    87,
#    89,
#    101,
#    102,
#    106,
#    107,
#    108,
#    109,
#    115,
#    125,
#    128,
#    129,
#    133,
#    138,
#    139,
#    142,
#    151,
#    154,
#    155,
#    159,
#    170,
#    179,
#    180,
#    182,
#    188,
#    189,
#    192,
#    202,
#    204,
#    206,
#    207,
#    210,
#    211],
#   [7,
#    14,
#    25,
#    62,
#    63,
#    67,
#    77,
#    79,
#    97,
#    112,
#    118,
#    124,
#    152,
#    169,
#    172,
#    181,
#    191,
#    197,
#    220,
#    221]],
#  [[223,
#    224,
#    225,
#    226,
#    241,
#    244,
#    247,
#    250,
#    252,
#    253,
#    256,
#    258,
#    260,
#    261,
#    264,
#    266,
#    267,
#    273,
#    278,
#    279,
#    280,
#    281,
#    287,
#    289,
#    292,
#    294,
#    299,
#    301,
#    303,
#    316,
#    322,
#    327,
#    328,
#    329,
#    331,
#    334,
#    335,
#    338,
#    342,
#    350,
#    352,
#    368,
#    372,
#    373,
#    374,
#    379,
#    381,
#    382,
#    383,
#    384,
#    386,
#    388,
#    391,
#    395,
#    400,
#    405,
#    408,
#    411,
#    413,
#    414,
#    415,
#    422,
#    426,
#    429,
#    432,
#    437,
#    438,
#    446,
#    449,
#    452,
#    454,
#    458,
#    459,
#    461,
#    464,
#    467],
#   [227,
#    229,
#    238,
#    242,
#    246,
#    248,
#    251,
#    270,
#    276,
#    304,
#    307,
#    310,
#    314,
#    317,
#    318,
#    323,
#    324,
#    326,
#    333,
#    341,
#    347,
#    348,
#    351,
#    354,
#    363,
#    364,
#    365,
#    366,
#    370,
#    371,
#    377,
#    378,
#    380,
#    385,
#    389,
#    399,
#    401,
#    402,
#    403,
#    404,
#    406,
#    410,
#    412,
#    416,
#    420,
#    430,
#    433,
#    439,
#    441,
#    448,
#    453,
#    455,
#    456,
#    457,
#    465,
#    466],
#   [240,
#    263,
#    268,
#    272,
#    290,
#    296,
#    315,
#    330,
#    340,
#    344,
#    349,
#    357,
#    367,
#    375,
#    376,
#    387,
#    393,
#    394,
#    397,
#    409,
#    418,
#    421,
#    424,
#    435,
#    442,
#    450,
#    451,
#    460],
#   [231,
#    237,
#    243,
#    255,
#    257,
#    259,
#    262,
#    271,
#    274,
#    286,
#    293,
#    300,
#    312,
#    313,
#    319,
#    320,
#    353,
#    369,
#    398,
#    419,
#    423,
#    427,
#    428,
#    431,
#    440,
#    443,
#    445],
#   [228,
#    230,
#    232,
#    233,
#    234,
#    235,
#    236,
#    239,
#    245,
#    249,
#    254,
#    265,
#    269,
#    275,
#    277,
#    282,
#    283,
#    284,
#    285,
#    288,
#    291,
#    295,
#    297,
#    298,
#    302,
#    305,
#    306,
#    308,
#    309,
#    311,
#    321,
#    325,
#    332,
#    336,
#    337,
#    339,
#    343,
#    345,
#    346,
#    355,
#    356,
#    358,
#    359,
#    360,
#    361,
#    362,
#    390,
#    392,
#    396,
#    407,
#    417,
#    425,
#    434,
#    436,
#    444,
#    447,
#    462,
#    463]],
#  [[481,
#    488,
#    501,
#    505,
#    510,
#    514,
#    527,
#    532,
#    553,
#    555,
#    569,
#    579,
#    589,
#    608,
#    612,
#    636,
#    639,
#    645,
#    646,
#    654,
#    665,
#    667,
#    668,
#    676],
#   [472,
#    475,
#    479,
#    486,
#    487,
#    491,
#    495,
#    496,
#    502,
#    507,
#    509,
#    512,
#    517,
#    519,
#    520,
#    524,
#    525,
#    529,
#    545,
#    550,
#    552,
#    561,
#    564,
#    578,
#    580,
#    583,
#    586,
#    587,
#    595,
#    599,
#    609,
#    610,
#    613,
#    614,
#    633,
#    634,
#    635,
#    638,
#    640,
#    641,
#    642,
#    647,
#    648,
#    649,
#    656,
#    657,
#    659,
#    664,
#    666,
#    674,
#    675,
#    681,
#    682,
#    686,
#    688],
#   [469,
#    474,
#    476,
#    483,
#    485,
#    489,
#    490,
#    506,
#    530,
#    531,
#    534,
#    535,
#    539,
#    544,
#    549,
#    558,
#    566,
#    568,
#    570,
#    576,
#    581,
#    584,
#    585,
#    596,
#    597,
#    601,
#    602,
#    603,
#    605,
#    611,
#    618,
#    625,
#    631,
#    669,
#    672,
#    678,
#    680,
#    683,
#    684,
#    687,
#    692],
#   [468,
#    470,
#    471,
#    477,
#    484,
#    492,
#    497,
#    498,
#    503,
#    504,
#    508,
#    516,
#    521,
#    522,
#    523,
#    526,
#    528,
#    533,
#    541,
#    542,
#    543,
#    546,
#    547,
#    551,
#    557,
#    559,
#    560,
#    562,
#    563,
#    567,
#    571,
#    573,
#    574,
#    582,
#    588,
#    590,
#    591,
#    592,
#    593,
#    594,
#    598,
#    615,
#    617,
#    619,
#    620,
#    621,
#    622,
#    626,
#    628,
#    629,
#    630,
#    643,
#    644,
#    652,
#    653,
#    655,
#    660,
#    661,
#    662,
#    663,
#    673,
#    677,
#    690],
#   [473,
#    478,
#    480,
#    482,
#    493,
#    494,
#    499,
#    500,
#    511,
#    513,
#    515,
#    518,
#    536,
#    537,
#    538,
#    540,
#    548,
#    554,
#    556,
#    565,
#    572,
#    575,
#    577,
#    600,
#    604,
#    606,
#    607,
#    616,
#    623,
#    624,
#    627,
#    632,
#    637,
#    650,
#    651,
#    658,
#    670,
#    671,
#    679,
#    685,
#    689,
#    691,
#    693]],
#  [[698,
#    700,
#    708,
#    713,
#    715,
#    716,
#    719,
#    721,
#    740,
#    741,
#    759,
#    768,
#    771,
#    775,
#    776,
#    781,
#    784,
#    788,
#    791,
#    792,
#    794,
#    795,
#    799,
#    800,
#    803,
#    807,
#    813,
#    822,
#    824,
#    830,
#    835,
#    847,
#    848,
#    852,
#    856,
#    859,
#    861,
#    863,
#    864,
#    866,
#    871,
#    872,
#    878,
#    894,
#    898,
#    901,
#    904,
#    905,
#    908,
#    918,
#    925,
#    931,
#    934,
#    938,
#    940,
#    944,
#    946,
#    950,
#    953,
#    959,
#    967,
#    969,
#    971,
#    977],
#   [696,
#    699,
#    701,
#    703,
#    704,
#    709,
#    710,
#    711,
#    712,
#    717,
#    718,
#    720,
#    722,
#    728,
#    729,
#    731,
#    736,
#    744,
#    745,
#    750,
#    751,
#    752,
#    755,
#    760,
#    762,
#    764,
#    766,
#    769,
#    770,
#    774,
#    778,
#    783,
#    785,
#    787,
#    790,
#    793,
#    797,
#    809,
#    810,
#    814,
#    817,
#    820,
#    827,
#    831,
#    832,
#    833,
#    840,
#    845,
#    854,
#    858,
#    867,
#    868,
#    869,
#    874,
#    875,
#    880,
#    884,
#    900,
#    906,
#    916,
#    917,
#    919,
#    920,
#    922,
#    924,
#    926,
#    928,
#    930,
#    935,
#    936,
#    945,
#    947,
#    949,
#    954,
#    956,
#    957,
#    960,
#    964,
#    972,
#    978,
#    980,
#    981,
#    982,
#    983,
#    990],
#   [697,
#    705,
#    726,
#    730,
#    733,
#    735,
#    738,
#    739,
#    757,
#    758,
#    763,
#    765,
#    777,
#    786,
#    796,
#    802,
#    811,
#    816,
#    818,
#    829,
#    836,
#    837,
#    841,
#    842,
#    844,
#    850,
#    855,
#    857,
#    860,
#    877,
#    885,
#    886,
#    889,
#    895,
#    896,
#    897,
#    902,
#    903,
#    909,
#    910,
#    911,
#    921,
#    932,
#    937,
#    943,
#    951,
#    952,
#    958,
#    961,
#    966,
#    979,
#    986,
#    988,
#    989],
#   [702,
#    706,
#    714,
#    734,
#    737,
#    743,
#    746,
#    747,
#    754,
#    761,
#    772,
#    779,
#    780,
#    805,
#    806,
#    819,
#    821,
#    825,
#    826,
#    828,
#    838,
#    839,
#    843,
#    849,
#    853,
#    862,
#    870,
#    873,
#    883,
#    888,
#    890,
#    891,
#    892,
#    893,
#    899,
#    907,
#    923,
#    933,
#    941,
#    948,
#    963,
#    965,
#    970,
#    974,
#    975,
#    976,
#    985,
#    987],
#   [694,
#    695,
#    707,
#    723,
#    724,
#    725,
#    727,
#    732,
#    742,
#    748,
#    749,
#    753,
#    756,
#    767,
#    773,
#    782,
#    789,
#    798,
#    801,
#    804,
#    808,
#    812,
#    815,
#    823,
#    834,
#    846,
#    851,
#    865,
#    876,
#    879,
#    881,
#    882,
#    887,
#    912,
#    913,
#    914,
#    915,
#    927,
#    929,
#    939,
#    942,
#    955,
#    962,
#    968,
#    973,
#    984]]]

# %% [markdown]
# # Khi²

# %%
# tf_of_your_word = tf[numDoc][strWord]
tf = []
for doc in usable:
    tf_doc = {}
    for word in vectorizer.get_feature_names():
        tf_doc[word] = doc.count(word)
    tf.append(tf_doc)

# %%
# Number total of words
# nb_total_word[numPartition]
nb_total_word = []
nb = 0

for numDoc in range(0, len(usable)):
    for word in vectorizer.get_feature_names():
        nb += tf[numDoc][word]
    if numDoc+1 in limits:
        nb_total_word.append(nb)
        nb=0

# %%
nb_total_word
# Out:
# [25297, 28077, 25286, 34465]

# %%
tf[0]
# Out:
# {'simultanement': 0,
#  'linteret lapproch': 0,
#  'luire permettre': 0,
#  'enjeu majeur': 0,
#  'extension': 0,
#  'sappuie': 0,
#  'lespace representation': 0,
#  'guidee': 0,
#  'panel': 0,
#  'perspectif': 0,
#  'laver': 0,
#  'dinform': 0,
#  'attribu': 0,
#  'particulierement': 0,
#  'permettre mettre': 0,
#  'industriel': 0,
#  'factorisation': 0,
#  'cube': 0,
#  'reduir': 0,
#  'traiter': 0,
#  'creation': 0,
#  'utiliser technique': 0,
#  'classifieur bayesien': 0,
#  'nest': 0,
#  'pourtant': 0,
#  'complementair': 0,
#  'futur': 0,
#  'meilleure': 0,
#  'taille': 0,
#  'statique': 0,
#  'vecteur': 0,
#  'explicatif': 0,
#  'adaptee': 0,
#  'table': 0,
#  'amont': 0,
#  'vaste marge': 0,
#  'resolution': 0,
#  'mining': 0,
#  'generalise': 0,
#  'multiagent': 0,
#  'precedemment': 0,
#  'baser technique': 0,
#  'temps calcul': 0,
#  'score': 0,
#  'lexical': 0,
#  'autoorganisatrice': 0,
#  'sousensemble': 0,
#  'annot': 0,
#  'nouvel': 0,
#  'permettre utilisateur': 0,
#  'continu': 0,
#  'caracteristiquer': 0,
#  'partiel': 0,
#  'bioinformatique': 0,
#  'article proposer': 0,
#  'chercher': 0,
#  'ensembliste': 0,
#  'inclure': 0,
#  'construir': 0,
#  'ferme frequent': 0,
#  'priser compter': 0,
#  'etude comparatif': 0,
#  'pretraitemer': 0,
#  'notion': 0,
#  'perspective': 0,
#  'sil': 0,
#  'dindice': 0,
#  'recemment': 0,
#  'processus dextraction': 0,
#  'dautre': 0,
#  'montr linteret': 0,
#  'construction automatique': 0,
#  'utilisee': 0,
#  'presenton algorithm': 0,
#  'source': 0,
#  'prototyp': 0,
#  'mass': 0,
#  'ensemble donnee': 0,
#  'generalist': 0,
#  'necessit': 0,
#  'examiner': 0,
#  'implementation': 0,
#  'posseder': 0,
#  'fouill donneer': 0,
#  'pouvoir prendre': 0,
#  'structurer': 0,
#  'brut': 0,
#  'cellule': 0,
#  'poids': 0,
#  'developpemer': 0,
#  'linfluence': 0,
#  'appele': 0,
#  'quune': 0,
#  'elevee': 0,
#  'evaluees': 0,
#  'amene': 0,
#  'devenement': 1,
#  'adapte': 0,
#  'completer': 0,
#  'construit': 0,
#  'populaire': 0,
#  'matrice': 0,
#  'decomposition': 0,
#  'delement': 0,
#  'dansl': 0,
#  'systeme gestion': 0,
#  'ameliorer qualite': 0,
#  'aleatoir': 0,
#  'partager': 0,
#  'dappartenance': 0,
#  'expliquer': 0,
#  'former regl': 0,
#  'generalisation': 0,
#  'machine': 0,
#  'vaste': 0,
#  'lien entrer': 0,
#  'lenvironnement': 0,
#  'adopter': 0,
#  'baser connaissance': 0,
#  'economiqu': 0,
#  'etablir': 0,
#  'connaissance partir donnee': 0,
#  'informatique': 0,
#  'fin': 0,
#  'selection modele': 0,
#  'concepteur': 0,
#  'concept': 0,
#  'evolutiv': 0,
#  'motif': 0,
#  'caracteristiqu': 1,
#  'obtenir': 0,
#  'operateur': 0,
#  'possibilite': 0,
#  'lespac': 0,
#  'lextraction connaissance': 0,
#  'comprehension': 0,
#  'presentee': 0,
#  'article': 0,
#  'resultat issu': 0,
#  'trouver': 0,
#  'apprentissage supervis': 0,
#  'coherence': 0,
#  'dentrepris': 0,
#  'similarite entrer': 0,
#  'quantite': 0,
#  'impossible': 0,
#  'montrer method': 0,
#  'entrer individu': 0,
#  'concerner': 0,
#  'problem classification': 0,
#  'important': 0,
#  'permettre visualiser': 0,
#  'serier': 0,
#  'conceptuel': 0,
#  'ensemble': 0,
#  'lidentification': 0,
#  'sant': 0,
#  'traduction': 0,
#  'ladequation': 0,
#  'detr': 0,
#  'etude': 0,
#  'cadrer general': 0,
#  'maximum': 0,
#  'leweb': 0,
#  'methode existant': 0,
#  'party': 0,
#  'volee': 0,
#  'neanmoin': 0,
#  'tableau donnee': 0,
#  'perte': 0,
#  'proposer methodologie': 0,
#  'expression': 0,
#  'theorie': 0,
#  'enjeu': 0,
#  'definie': 0,
#  'conduire': 0,
#  'lapprentissage automatique': 0,
#  'doutil': 0,
#  'adn': 0,
#  'calcul similarite': 0,
#  'historique': 0,
#  'semantiqu': 0,
#  'recente': 0,
#  'svm': 0,
#  'moyen': 0,
#  'plaire pertinent': 0,
#  'factoriel correspondance afc': 0,
#  'produire': 0,
#  'potentiel': 0,
#  'algorithme fouiller': 0,
#  'lechelle': 0,
#  'referentiel': 0,
#  'specification': 0,
#  'partir sequence': 0,
#  'jouer role': 0,
#  'efficacite': 0,
#  'dheuristiqu': 0,
#  'connaissance': 0,
#  'algorithme dextraction': 0,
#  'apprentissage': 0,
#  'decouvrir': 0,
#  'precision': 0,
#  'recommandation': 0,
#  'article proposer methodologie': 0,
#  'profil': 0,
#  'cours': 0,
#  'experience montrer': 0,
#  'prendre decision': 0,
#  'controler': 0,
#  'theorie fonction croyance': 0,
#  'dinternet': 0,
#  'devaluer qualite': 0,
#  'fiable': 0,
#  'arbre': 0,
#  'client': 0,
#  'method visualisation': 0,
#  'erreur': 0,
#  'lapproche': 0,
#  'appel': 0,
#  'devenir plaire': 0,
#  'meilleur': 0,
#  'dense': 0,
#  'activite': 0,
#  'benchmark': 0,
#  'them': 0,
#  'defi egc': 0,
#  'dexplorer': 0,
#  'algorithm classification': 0,
#  'doffr': 0,
#  'publier': 0,
#  'realisation': 0,
#  'souligner': 0,
#  'donnee reell issu': 0,
#  'lexploitation connaissance': 0,
#  'stochastique': 0,
#  'variable explicatif': 0,
#  'corpu': 0,
#  'iii': 0,
#  'donnee qualitatif': 0,
#  'positif': 0,
#  'danscet article proposer': 0,
#  'naïf': 0,
#  'construire partir': 0,
#  'permettre didentifier': 0,
#  'defaut': 0,
#  'categorisation': 0,
#  'terrain': 0,
#  'integre': 0,
#  'modele conceptuel': 0,
#  'grâce': 0,
#  'lextraction motif sequentiel': 0,
#  'travers': 0,
#  'decisionnell': 0,
#  'travail': 0,
#  'developp': 0,
#  'entrainer': 0,
#  'appliquee': 0,
#  'danalyse': 0,
#  'general': 0,
#  'etle': 0,
#  'technique': 0,
#  'veiller': 0,
#  'primordial': 0,
#  'extraction motif': 0,
#  'devolution': 0,
#  'formaliser': 0,
#  'machiner': 0,
#  'entrepot': 0,
#  'proposer detendre': 0,
#  'satellite': 0,
#  'articlenou': 0,
#  'mesure': 0,
#  'partir': 0,
#  'anne': 0,
#  'matier': 0,
#  'dextraction motif': 0,
#  'rechercheer': 0,
#  'proposer methode': 0,
#  'particularite': 0,
#  'ajouter': 0,
#  'carte autoorganisatrice': 0,
#  'ontolog': 0,
#  'venir': 0,
#  'laccer': 0,
#  'capacite': 0,
#  'decideur': 0,
#  'actuel': 0,
#  'estimation': 0,
#  'resultat obtenir': 0,
#  'celer': 0,
#  'ontologie': 0,
#  'decisionnel': 0,
#  'decider': 0,
#  'lheure actuel': 0,
#  'redondant': 0,
#  'ensembl': 0,
#  'propriet': 0,
#  'temps dexecution': 0,
#  'danscet': 0,
#  'positionner': 0,
#  'confiance': 0,
#  'servir': 0,
#  'proposon': 0,
#  'temps reel': 1,
#  'consommation': 0,
#  'modelisation': 0,
#  'dintegration': 0,
#  'connaissance expert': 0,
#  'base donneer': 0,
#  'cibl': 0,
#  'former': 0,
#  'personnalisation': 0,
#  'condensee': 0,
#  'systematiqu': 0,
#  'partir corpu': 0,
#  'partir texte': 0,
#  'connexion': 0,
#  'utilise': 0,
#  'architecturer': 0,
#  'propose': 0,
#  'nombre dindividus': 0,
#  'population': 0,
#  'structurer sousjacent': 0,
#  'classification': 0,
#  'ressortir': 0,
#  'supervis': 0,
#  'lalgorithm': 0,
#  'dansun': 0,
#  'documentaire': 0,
#  'letiquetage': 0,
#  'dimager': 0,
#  'evoluer': 0,
#  'svm support': 0,
#  'durer': 0,
#  'selection variable': 0,
#  'reference': 0,
#  'ordre': 0,
#  'couple': 0,
#  'egc': 0,
#  'lalgorithme': 0,
#  'frequence': 0,
#  'generer': 0,
#  'papier presente': 0,
#  'dinduction': 0,
#  'critere devaluation': 0,
#  'dinteraction': 0,
#  'linformation': 0,
#  'veill': 0,
#  'parametre': 0,
#  'boosting': 0,
#  'collectif': 0,
#  'dependance fonctionnel': 0,
#  'periode': 0,
#  'variante': 0,
#  'donnee artificiel': 0,
#  'groupement': 0,
#  'impliqu': 0,
#  'lanalyse formel': 0,
#  'poser': 0,
#  'effectu': 0,
#  'precision rappel': 0,
#  'larbr': 0,
#  'proposer representation': 0,
#  'comparer resultat': 0,
#  'description': 0,
#  'utiliser methode': 0,
#  'français': 0,
#  'majorite': 0,
#  'topologie': 0,
#  'preliminair': 0,
#  'cuber': 0,
#  'procedure': 0,
#  'permettre caracteriser': 0,
#  'resultat experimentaux montrer': 0,
#  'correspondance': 0,
#  'linterrogation': 0,
#  'comparer': 0,
#  'source dinformation': 0,
#  'lemergence': 0,
#  'evalue': 0,
#  'typer': 0,
#  'web': 0,
#  'production': 0,
#  'dadapter': 0,
#  'dindividus': 0,
#  'local': 0,
#  'sequentiel': 0,
#  'lanalys formel concept': 0,
#  'scientifique': 0,
#  'nousproposon': 0,
#  'cesser': 0,
#  'fouiller': 0,
#  'limplementation': 0,
#  'extraite': 0,
#  'difficulte': 0,
#  'proposer nouvel algorithme': 0,
#  'video': 0,
#  'quantitatif': 0,
#  'tenter': 0,
#  'lajout': 0,
#  'caracteriseer': 0,
#  'axer': 0,
#  'risque': 0,
#  'darbr': 0,
#  'reell issu': 0,
#  'typologie': 0,
#  'proximite': 0,
#  'etablisser': 0,
#  'generalement': 0,
#  'cognitif': 0,
#  'manipulation': 0,
#  'supplementair': 0,
#  'miser': 0,
#  'permettre': 1,
#  'sift': 0,
#  'proteine': 0,
#  'neuron': 0,
#  'regrouper': 0,
#  'phase': 0,
#  'reseau': 0,
#  'developpee': 0,
#  'passage lechelle': 0,
#  'method permettre': 0,
#  'grand echelle': 0,
#  'ainsiqu': 0,
#  'terminologie': 0,
#  'donnee geographiqu': 0,
#  'separateur vaste': 0,
#  'voter': 0,
#  'itemset': 0,
#  'prevision': 0,
#  'theorie fonction': 0,
#  'chain': 0,
#  'individuel': 0,
#  'propriete': 0,
#  'griller': 0,
#  'dictionnair': 0,
#  'similaire': 0,
#  'pouvoir utiliser': 0,
#  'contribution': 0,
#  'donnee baser': 0,
#  'method danalyse': 0,
#  'item': 1,
#  'decouvert': 0,
#  'integr': 0,
#  'dabord': 0,
#  'mal': 0,
#  'reseaux neuron': 0,
#  'permettre dobtenir': 0,
#  'utiliser algorithme': 0,
#  'probleme majeur': 0,
#  'structurer document': 0,
#  'besoin': 0,
#  'som': 0,
#  'celuici': 0,
#  'grand base donneer': 0,
#  'apr': 0,
#  'compatible': 0,
#  'induire': 0,
#  'stockage': 0,
#  'anormal': 0,
#  'preciser': 0,
#  'supervisee': 0,
#  'danalyser': 0,
#  'plaire important': 0,
#  'simplifier': 0,
#  'tâch': 0,
#  'gener': 0,
#  'teledetection': 0,
#  'regression': 0,
#  'darticl': 0,
#  'necessair': 0,
#  'mesurer dinteret': 0,
#  'internaute': 0,
#  'nouspresenton': 0,
#  'remedier': 0,
#  'donnee symbolique': 0,
#  'metadonne': 0,
#  'analyser donnee': 0,
#  'plaire particulierement': 0,
#  'malheureusement': 0,
#  'representent': 0,
#  'plaire complexe': 0,
#  'demonstration': 0,
#  'lindexation': 0,
#  'compacter': 0,
#  'indicateur': 0,
#  'linteret': 0,
#  'cadrer travail': 0,
#  'exposer': 0,
#  'recent': 0,
#  'descripteur': 0,
#  'permettre detecter': 0,
#  'presentation': 0,
#  'formalisation': 0,
#  'approprier': 0,
#  'deduire': 0,
#  'dedonnee': 0,
#  'interactif': 0,
#  'collection document': 0,
#  'etude experimental': 0,
#  'traduire': 0,
#  'determination': 0,
#  'deffectuer': 0,
#  'regle dassoci': 0,
#  'central': 0,
#  'lavantage': 0,
#  'sou contraint': 0,
#  'encourageant prometteur': 0,
#  'dater stream': 0,
#  'artificiel': 0,
#  'contexte': 0,
#  'entreprise': 0,
#  'satellit': 0,
#  'existant': 0,
#  'chercheur': 0,
#  'restreindre': 0,
#  'nexist': 0,
#  'caracteristique': 1,
#  'verification': 0,
#  'permettre partir': 0,
#  'consider': 0,
#  'lintegration': 0,
#  'method fouiller': 0,
#  'compromis entrer': 0,
#  'defi': 0,
#  'ligne': 0,
#  'experimentation': 0,
#  'lanalyse exploratoire': 0,
#  'flux donnee': 0,
#  'mesurer similarite entrer': 0,
#  'resume': 0,
#  'organisation': 0,
#  'lexperimentation': 0,
#  'twitter': 0,
#  'lumiere': 0,
#  'obtenir resultat': 0,
#  'classique': 0,
#  'web donnee': 0,
#  'preference': 0,
#  'reduite': 0,
#  'passage': 0,
#  'metier': 0,
#  'nommees': 0,
#  'criter': 0,
#  'graph voisinage': 0,
#  'optique': 0,
#  'localiser': 0,
#  'explorer': 0,
#  'possede': 0,
#  'programmation logique inductif': 0,
#  'rapide': 0,
#  'dattributs': 0,
#  'approximation': 0,
#  'reduiser': 0,
#  'desdonnee': 0,
#  'avancee': 0,
#  'cycle': 0,
#  'flot': 0,
#  'mecanisme': 0,
#  'faire partir': 0,
#  'problematique': 0,
#  'algorithme incremental': 0,
#  'temps': 1,
#  'correlation entrer': 0,
#  'fond': 0,
#  'donnee reel': 0,
#  'didentification': 0,
#  'volumineux': 0,
#  'projet': 0,
#  'classification supervise': 0,
#  'apartir': 0,
#  'eter': 0,
#  'creer': 0,
#  'facile': 0,
#  'masser': 0,
#  'trajectoire': 0,
#  'serie temporel': 0,
#  'propre': 0,
#  'retrouver': 0,
#  'cadrer projet': 0,
#  'format': 0,
#  'quantifier': 0,
#  'daugmenter': 0,
#  'serie': 0,
#  'concentrer': 0,
#  'dependance': 0,
#  'majeur': 0,
#  'lalignement': 0,
#  'choix': 0,
#  'entrer variable': 0,
#  'dizaine': 0,
#  'mond': 0,
#  'donneer luci': 0,
#  'dexpression': 0,
#  'taux derreur': 0,
#  'exploitable': 0,
#  'mettre disposition': 0,
#  'grand volume donnee': 0,
#  'gain': 0,
#  'ressource': 0,
#  'donnee pouvoir': 0,
#  'carte': 0,
#  'spatiotemporel': 0,
#  'detendre': 0,
#  'patron': 0,
#  'faisabilite': 0,
#  'representation connaissance': 0,
#  'modele proposer': 0,
#  'encompte': 0,
#  'exhaustif': 0,
#  'proposition': 0,
#  'million': 0,
#  'quadratique': 0,
#  'mettre oeuvrer': 0,
#  'site web': 0,
#  'biologique': 0,
#  'minimiser': 0,
#  'attaquer': 0,
#  'adaptatif': 0,
#  'correspondance afc': 0,
#  'service': 0,
#  'quils': 0,
#  'distinguer': 0,
#  'dameliorer performance': 0,
#  'construit partir': 0,
#  'gerer': 0,
#  'system': 0,
#  'resoudre probleme': 0,
#  'lutilisateur pouvoir': 0,
#  'empirique': 0,
#  'localement': 0,
#  'appartenir': 0,
#  'regard': 0,
#  'communautair': 0,
#  'baser donneer': 0,
#  'qualite regle': 0,
#  'system dinformation': 0,
#  'entrer': 1,
#  'composer': 0,
#  'donnee relationnel': 0,
#  'utiliser': 0,
#  'bruitees': 0,
#  'idee': 0,
#  'ferme': 0,
#  'detection changement': 0,
#  'dentiter': 0,
#  'extraction regl': 0,
#  'article introduire': 0,
#  'annoter': 0,
#  'entrepot donnee': 0,
#  'dannotation': 0,
#  'reconnaitre': 0,
#  'associeer': 0,
#  'contenir document': 0,
#  'petit': 0,
#  'delagage': 0,
#  'controle': 0,
#  'entreprendre': 0,
#  'agregation': 0,
#  'guid': 0,
#  'proposer modele': 0,
#  'base donnee': 0,
#  'article proposer method': 0,
#  'priser decision': 0,
#  'social': 0,
#  'correlation': 0,
#  'mesurer qualite': 0,
#  'surune': 0,
#  'decouverte': 0,
#  'signatur': 0,
#  'france': 1,
#  'experiment': 0,
#  'montrer lapproche': 0,
#  'projection': 0,
#  'regroupement': 0,
#  'adapt': 0,
#  'permettre determiner': 0,
#  'symbolique': 0,
#  'specifier': 0,
#  'extraire': 0,
#  'configuration': 0,
#  'parametr': 0,
#  'combiner': 0,
#  'cas donnee': 0,
#  'methode propose': 0,
#  'quell': 0,
#  'souhaiter': 0,
#  'limitee': 0,
#  'concept treillis': 0,
#  'innovant': 0,
#  'modelisee': 0,
#  'doter': 0,
#  'role': 0,
#  'specialite': 0,
#  'profit': 0,
#  'hierarchiqu': 0,
#  'lagregation': 0,
#  'laid': 0,
#  'bayesien': 0,
#  'domaine fouiller': 0,
#  'minoritaire': 0,
#  'savoir': 0,
#  'detecter': 0,
#  'logique': 0,
#  'cadrer': 0,
#  'atypique': 0,
#  'surla': 0,
#  'charger': 0,
#  'reseaux dynamique': 0,
#  'dissimilarit': 0,
#  'direct': 0,
#  'modele predictif': 0,
#  'ontologique': 0,
#  'actuellement': 0,
#  'impliquer': 0,
#  'croisee': 0,
#  'plutot': 0,
#  'calculee': 0,
#  'communication': 0,
#  'p2p': 0,
#  'generiqu': 0,
#  'proposee': 0,
#  'article etuder': 0,
#  'programmation logique': 0,
#  'dincertitude': 0,
#  'ressourc': 0,
#  'classifieur bayesien naïf': 0,
#  'consequent': 0,
#  'associe': 0,
#  'transform': 0,
#  'nondisjoint': 0,
#  'vision': 0,
#  'celer proposer': 0,
#  'developpe': 0,
#  'lhypothese': 0,
#  'compter': 0,
#  'generation': 0,
#  'virtuel': 0,
#  'lobjectif travail': 0,
#  'article presenter': 0,
#  'performance algorithme': 0,
#  'large': 0,
#  'dependanc': 0,
#  'menee': 0,
#  'limite': 0,
#  'foret': 0,
#  'aider': 0,
#  'cancer': 0,
#  'utilisateur': 0,
#  'classification hierarchiqu': 0,
#  'interesser': 0,
#  'dedition': 0,
#  'complexite': 0,
#  'lanalys': 1,
#  'moyenner': 0,
#  'perte dinformation': 0,
#  'poisson': 0,
#  'recommander': 0,
#  'categorie': 0,
#  'exemple': 0,
#  'significativement': 0,
#  'stocker': 0,
#  'exploratoire': 0,
#  'page': 0,
#  'dispositif': 0,
#  'baser donne': 0,
#  'plaire voisin': 0,
#  'varieer': 0,
#  'performance predictiv': 0,
#  'atteindre': 0,
#  'refleter': 0,
#  'discuter': 0,
#  'dutilisateur': 0,
#  'topologique': 0,
#  'associ': 0,
#  'lier': 0,
#  'permettre dameliorer': 0,
#  'heuristique': 0,
#  'favoriser': 0,
#  'probabilit': 0,
#  'celleci': 0,
#  'validee': 0,
#  'grand': 0,
#  'axe': 0,
#  'segment': 0,
#  'decrir': 0,
#  'fonctionnalite': 0,
#  'determiner': 0,
#  'donnee article': 0,
#  'application reell': 0,
#  'motif sequentiel': 0,
#  'appliquees': 0,
#  'degr': 0,
#  'reseaux bayesien': 0,
#  'changement': 0,
#  'litterature': 0,
#  'integration': 0,
#  'mesurer dissimilarite': 0,
#  'representeer': 0,
#  'parametrage': 0,
#  'ontologie domaine': 0,
#  'dechantillonnage': 0,
#  'synthes': 0,
#  'formuler': 0,
#  'caracter': 1,
#  'difference': 0,
#  'mem': 1,
#  'reell montrer': 0,
#  'loi': 0,
#  'definissons': 0,
#  'analytique': 0,
#  'final': 0,
#  'devenir': 0,
#  'evaluee': 0,
#  'daider': 0,
#  'metriqu': 0,
#  'dexecution': 0,
#  'survenir': 0,
#  'article decrit': 0,
#  'empiriquement': 0,
#  'permettre lextraction': 0,
#  'loriginalite': 0,
#  'sagit': 0,
#  'technologi': 0,
#  'separateur': 0,
#  'methode': 0,
#  'espacer': 0,
#  'mapping': 0,
#  'beneficier': 0,
#  'obtenir montrer': 0,
#  'faible': 0,
#  'pouvoir traiter': 0,
#  'habituellement': 0,
#  'variable': 0,
#  'evalu': 0,
#  'generee': 0,
#  'algorithm': 0,
#  'causer': 0,
#  'premiere': 0,
#  'resultat obtenir montrer': 0,
#  'efficacement': 0,
#  'amelioree': 0,
#  'observer': 0,
#  'liee': 0,
#  'gestion': 0,
#  'tot': 0,
#  'proposer mesurer': 0,
#  'etiquetage': 0,
#  'dordre': 0,
#  'diviser': 0,
#  'classificateur': 0,
#  'apprentissage automatique': 0,
#  'batch': 0,
#  'structurel': 0,
#  'arbre decision': 0,
#  'echelle': 0,
#  'lanalyse donnee': 0,
#  'sit': 1,
#  'traitement donnee': 0,
#  'transaction': 0,
#  'methode reposer': 0,
#  'lextractionde': 0,
#  'markov': 0,
#  'sommet': 0,
#  'zone': 0,
#  'etudiee': 0,
#  'moduler': 0,
#  'meilleur resultat': 0,
#  'kmean': 0,
#  'article methode': 0,
#  'solution': 0,
#  'monder': 0,
#  'lapprentissage': 0,
#  'densembl': 0,
#  'foret aleatoir': 0,
#  'recherche': 0,
#  'validite': 0,
#  'lelaboration': 0,
#  'resultat obtenu': 0,
#  'reponse': 0,
#  'cartographique': 0,
#  'estimation densite': 0,
#  'munir': 0,
#  'vie': 0,
#  'jour': 0,
#  'domaine': 0,
#  'coupler': 0,
#  'tailler': 0,
#  'manipuler': 0,
#  'prealabl': 0,
#  'point dinteret': 0,
#  'exploitation': 0,
#  'localisation': 0,
#  'modelise': 0,
#  'proposer article methode': 0,
#  'lexploitation': 0,
#  'melange': 0,
#  'differenter': 0,
#  'demander': 0,
#  'modele generatif': 0,
#  'predicteur': 0,
#  'moindre': 0,
#  'lextension': 0,
#  'rdf': 0,
#  'base donnee relationnel': 0,
#  'prometteur': 0,
#  'mettre lumiere': 0,
#  'utilisable': 0,
#  'regle': 0,
#  'pair': 0,
#  'born': 0,
#  'reconnaissance': 0,
#  'cooperativ': 0,
#  'affiner': 0,
#  'dontologie partir': 0,
#  'contraindre': 0,
#  'article present methode': 0,
#  'fixe': 0,
#  'expliciter': 0,
#  'moment': 0,
#  'sappuyer': 0,
#  'collection': 0,
#  'prealablement': 0,
#  'probleme dapprentissage': 0,
#  'requete': 0,
#  'difficile': 0,
#  'etudie': 0,
#  'pertinent': 0,
#  'guider': 0,
#  'impact': 0,
#  'mieux': 0,
#  'theme': 0,
#  'dexprimer': 0,
#  'dindexation': 0,
#  'extraire connaissance': 0,
#  'susciter': 0,
#  'systeme recommandation': 0,
#  'skyline': 0,
#  'jeu donneer': 0,
#  'point': 0,
#  'represent': 0,
#  'daid decision': 0,
#  'automat': 0,
#  'apparer': 0,
#  'paradigme': 0,
#  'naturellement': 0,
#  'typique': 0,
#  'classement': 0,
#  'robustesse': 0,
#  'combinaison': 0,
#  'saverer': 0,
#  'sest': 0,
#  'correct': 0,
#  'luire': 0,
#  'log': 0,
#  'devaluer': 0,
#  'initial': 0,
#  'fonction croyance': 0,
#  'partir donnee': 0,
#  'selectionner': 0,
#  'echantillonnage': 0,
#  'fort': 0,
#  'cadrer lanalyse': 0,
#  'web semantiqu': 0,
#  'finalement': 0,
#  'lancer': 0,
#  'parcours': 0,
#  'distance': 0,
#  'regl': 0,
#  'preparation': 0,
#  'pendre': 0,
#  'method classification': 0,
#  'dalgorithme': 0,
#  'dextraction connaissance partir': 0,
#  'groupe': 0,
#  'permettre dutiliser': 0,
#  'partition': 0,
#  'adequat': 0,
#  'resumer': 0,
#  'domaine dapplication': 0,
#  'robuste': 0,
#  'itemset frequent': 0,
#  'savere': 0,
#  'lidee': 0,
#  'nouvelleapproche': 0,
#  'encourageant': 0,
#  'heterogener': 0,
#  'flux donne': 0,
#  'defini': 0,
#  'lieu': 0,
#  'donneer plaire': 0,
#  'formel concept': 0,
#  'oriente': 0,
#  'eclairage': 0,
#  'objectif': 1,
#  'donnee textuel': 0,
#  'proposer papier': 0,
#  'proposer permettre': 0,
#  'concret': 0,
#  ...}

# %%
# nb_word[num_partition][word]
nb_word = []

word_in_this_parti = {}
for word in vectorizer.get_feature_names():
    word_in_this_parti[word] = 0

for numDoc in range(0, len(usable)):
    for word in vectorizer.get_feature_names():
        word_in_this_parti[word] += tf[numDoc][word]
    if numDoc+1 in limits:
        nb_word.append(word_in_this_parti)
        word_in_this_parti = {}
        for word in vectorizer.get_feature_names():
            word_in_this_parti[word] = 0

# %%
len(nb_word)
# Out:
# 4

# %%
# nb_word_by_cluster[numPartition][numCluster]
nb_word_by_cluster = []
for parti in partitions:
    nb_word_clus = []
    for cluster in parti:
        nb = 0
        for numDoc in cluster:
            for word in vectorizer.get_feature_names():
                nb += tf[numDoc][word]
        nb_word_clus.append(nb)
    nb_word_by_cluster.append(nb_word_clus)

# %%
# Expected values, if nothing were dependant
# exp[numPartition][numCluster][numWord]
#exp = []
#for numParti in range(0, len(partitions)):
#    exp_clus = []
#    for numCluster in range(0, len(partitions[numParti])):
#        exp_word = []
#        for numWord in range(0, vectorizer.get_feature_names()):
#            exp_word.append((nb_word[numParti][numWord] + nb_word_by_cluster[numPart][numCluster]) / nb_total_word[numParti])
#        exp_cluster.append(exp_word)
#    exp.append(exp_clus)

# %%
# value_of_khi2 = khi2[numPartition][numCluster][word]
khi2 = []

for numParti in range(0, len(partitions)):
    khi2parti = []
    for numCluster in range(0, len(partitions[numParti])):
        khi2cluster = {}
        
        for word in vectorizer.get_feature_names():
            word_in_this_parti[word] = 0
            E = nb_word[numParti][word]
            E =+ nb_word_by_cluster[numParti][numCluster]
            E = E/ nb_total_word[numParti]
            N = 0
            for numDoc in partitions[numParti][numCluster]:
                N += tf[numDoc][word]
            khi2cluster[word] = (pow(N - E, 2)/E)        
        khi2parti.append(khi2cluster)
    khi2.append(khi2parti)

# %%
# list of your labels = labels[numPartition][numCluster]
labels = []

for numPartition in range(0, len(nb_word_by_cluster)):
    label_clus = []
    for numCluster in range(0, len(nb_word_by_cluster[numPartition])):
        label_clus.append(Counter(khi2[numPartition][numCluster]).most_common(5))
    labels.append(label_clus)

# %%
labels
# Out:
# [[[('donne', 98401.95934959351),
#    ('donnee', 70560.29268292684),
#    ('utilis', 16601.959349593493),
#    ('mettre', 15203.709349593495),
#    ('format', 13009.959349593499)],
#   [('reseau', 19327.353717345428),
#    ('donne', 14043.822935315473),
#    ('utilis', 13561.770522669882),
#    ('vis', 13088.136412852911),
#    ('cluster', 12622.920605864558)],
#   [('donne', 34167.16353759565),
#    ('donnee', 27482.280546393307),
#    ('recommandation', 17713.893449619114),
#    ('utilis', 14932.54682205313),
#    ('temp', 13630.895209149905)],
#   [('donne', 64161.26523694975),
#    ('donnee', 55306.043264215186),
#    ('method', 15472.343985947347),
#    ('propos', 15472.343985947347),
#    ('propose', 12611.805734143016)],
#   [('label', 21795.462910454014),
#    ('relation', 19855.278817513892),
#    ('trer', 7589.184090078677),
#    ('mod', 4481.446824663127),
#    ('model', 4481.446824663127)]],
#  [[('utilis', 38054.779110319),
#    ('donne', 35305.33165735893),
#    ('log', 28275.86848617949),
#    ('donnee', 24770.19019338463),
#    ('format', 16096.97002358197)],
#   [('donne', 41962.90000271146),
#    ('donnee', 37019.376178596256),
#    ('log', 13378.269544614335),
#    ('poser', 11086.876101991384),
#    ('propos', 11086.876101991384)],
#   [('log', 15790.41496913707),
#    ('donne', 10953.93323836784),
#    ('propos', 9151.126507598608),
#    ('method', 8039.24573836784),
#    ('donnee', 7510.30246913707)],
#   [('motif', 64374.113554710864),
#    ('quen', 23998.250653774176),
#    ('action', 18266.148751985926),
#    ('donne', 14649.967940177808),
#    ('graph', 12671.530528880618)],
#   [('donne', 58710.79132938795),
#    ('donnee', 46979.73011149099),
#    ('classification', 31832.10937170744),
#    ('method', 18448.11970929426),
#    ('cluster', 11238.04960753364)]],
#  [[('donne', 10870.580135145825),
#    ('donnee', 9550.48216217285),
#    ('cart', 8315.809864875553),
#    ('carte', 7730.508344605283),
#    ('vis', 7730.508344605283)],
#   [('donne', 50090.12318617482),
#    ('donnee', 36123.63105589587),
#    ('log', 19722.166196927505),
#    ('present', 17555.026411981267),
#    ('gen', 16012.421456394544)],
#   [('method', 30704.70333622221),
#    ('classification', 28259.854405740927),
#    ('methode', 16933.43729344146),
#    ('vis', 12885.22561786214),
#    ('donne', 9854.792462781925)],
#   [('donne', 70827.42776811244),
#    ('donnee', 57524.73320744297),
#    ('action', 13432.682998237953),
#    ('algorithm', 12576.183137707967),
#    ('quen', 10175.962217205873)],
#   [('trer', 17448.11967262185),
#    ('regl', 11933.70711841991),
#    ('mod', 10483.007965002607),
#    ('entrer', 9568.086635248324),
#    ('quen', 9126.289402128357)]],
#  [[('donne', 42562.639591691055),
#    ('mod', 41630.36297045397),
#    ('mode', 33704.43081529447),
#    ('present', 30450.205264897584),
#    ('model', 29662.45762374138)],
#   [('donne', 226296.91916626014),
#    ('donnee', 191688.41350053778),
#    ('method', 32997.312461821995),
#    ('algorithm', 31699.518316401787),
#    ('present', 25601.085832926812)],
#   [('connaiss', 109227.31771398886),
#    ('connaissance', 101608.41808157715),
#    ('log', 46437.84688132143),
#    ('utilis', 13127.443652937232),
#    ('poser', 12595.145267129337)],
#   [('regl', 151758.64322579274),
#    ('donne', 86354.57081257235),
#    ('regle', 75471.82309624615),
#    ('donnee', 67790.58941413354),
#    ('associ', 21879.738890964654)],
#   [('docu', 74111.05027384327),
#    ('document', 71256.97710311157),
#    ('log', 18118.359216932695),
#    ('annot', 16043.85007059123),
#    ('format', 16043.85007059123)]]]
