# %%
import nltk
import pandas as pd
import random
import numpy as np
import string
import math

from nltk import ngrams
from nltk.corpus import stopwords
from nltk.stem.snowball import FrenchStemmer
from nltk.tokenize import word_tokenize

from numpy import array
from collections import Counter
from scipy.sparse import csr_matrix

from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
from gensim import corpora, models, utils
from gensim.test.utils import common_corpus, common_dictionary, get_tmpfile
from gensim.models import LsiModel
from gensim.corpora import Dictionary

import re

# %%
# Use spacy lib
# On https://spacy.io/

import spacy
nlp = spacy.load('fr')

# %%
##############
# Parameters #
##############

min_gram = 1
max_gram = 3

# To create ours partitions, we must first know the years which will be the limits
limit_years = [2007, 2010, 2014]

# Ignore words that appear at a frequency less than max_frequ in the corpus
max_frequ = 0.8

# Ignore words appearing less than min_appear in the whole corpus
min_appear = 5

# %%
# Datas preprocessing methods.

# Lemmatisation without poncutations

stemmer = nltk.stem.snowball.FrenchStemmer()
fstw = stopwords.words('french')

# French Stop Words, extraits depuis le fichier stopwords-fr.txt + stopwords french de nltk
sourceFST = [x.replace('\n', '') for x in open('stopwords-fr.txt', mode="r", encoding="utf-8").readlines()]+fstw
sourceFST += [x.replace('\n', '') for x in open('perso_words-fr.txt', mode="r", encoding="utf-8").readlines()]

# Based on ration of french and english stopwords
def isEnglish(article):
    total_fsw = len([x for x in article.split() if x in sourceFST])
    total_esw = len([x for x in article.split() if x in stopwords.words('english')])
    ratio = 100
    if total_fsw != 0:
        ratio = total_esw/total_fsw
    return ratio > 1 and total_esw > 3

def lemmatize(article):
    artiregex = re.sub(" [0-z][0-z] ", " ", article) # word of length < 2
    artiregex = artiregex.lower()
    artiregex = re.sub("(é|è|ê)", "e", artiregex)
    artiregex = re.sub("à", "a", artiregex)
    artiregex = re.sub("ô", "o", artiregex)
    artiregex = re.sub("î", "i", artiregex)
    output = []
    outPonc = artiregex.translate(artiregex.maketrans("","", string.punctuation))
    outLem = nlp(outPonc)
    for token in outLem:
        if token.lemma_ not in sourceFST and [x for x in token.lemma_ if x not in "0123456789"] != []:
            output.append(token.lemma_)
    res = ' '.join(output)
    return res

# %%
# Data Reading
data = pd.read_csv('export_articles_EGC_2004_2018.csv', sep='\t', header=0)

# %%
# Let's process our corpus, and determine a limit to split it in partitions

# usable[] correspond to our corpus processed
# limits[] let us know when to delimit partitions
limits = []
usable = []

prev_year = data['year'][0]
numArti = 0
for i in range(0, len(data['abstract']), 1):
    #if not null, empty, or whatever (so if there is a abstract):
    if not isinstance(data['abstract'][i], float) and not isEnglish(data['abstract'][i]):
        text = data['abstract'][i]
        if not isinstance(data['title'][i], float):
            text += " "+data['title'][i]

        numArti+=1
        usable.append(stemmer.stem(lemmatize(text)))
        year = data['year'][i]
        if year != prev_year:
            prev_year = year
            if year in limit_years:
                limits.append(numArti)
limits.append(numArti)

# %%
# Display pre-processed datas

vectorizer = TfidfVectorizer(stop_words=sourceFST, use_idf=True, ngram_range=(min_gram, max_gram), max_df=max_frequ, min_df=min_appear)
tfidf = vectorizer.fit_transform(usable)

print("nombre d'articles =", len(usable))
print("nombre de mots =", len(tfidf.toarray()[0]))
print("limits =", limits)

usable[0]
# Out:
# nombre d'articles = 991
# nombre de mots = 2410
# limits = [223, 468, 694, 991]
# 'plateforme objectif permettre citoyen euxmemer tweet politique devenement specifiqu francepour cas lelection presidentiell ideo2017 analyser quasitemps reel message candidat fournir principal caracteristiqueslusage lexiqu politique comparaison entrer candidat ideo2017   plateforme citoyen dediee lanalyse tweet evenement polit'

# %%
# Creation of partitions_tfidf[], which give us the TFIDF of each cluster of each partition
# partitions_tfidf[num_partition][num_doc][num_word]
# Beware, num_doc can't be equals to 1091 (max). You have partitions, so every doc aren't in every partitions
# num_word can be found via vectorizer.get_feature_name()
partitions_tfidf = []
beg = 0
for l in limits:
    last = l
    partitions_tfidf.append([list(x) for x in list(tfidf.toarray())[beg:last]])
    beg = l

# %%
vectorizer.get_feature_names()
# Out:
# ['3d',
#  'acce',
#  'accessible',
#  'achat',
#  'acquisition',
#  'acquérir',
#  'acteur',
#  'actif',
#  'action',
#  'activite',
#  'actuel',
#  'actuellement',
#  'adapt',
#  'adaptatif',
#  'adaptation',
#  'adapte',
#  'adaptee',
#  'adapter',
#  'adequat',
#  'adn',
#  'adopter',
#  'afc',
#  'affiner',
#  'agent',
#  'agregation',
#  'aid',
#  'aider',
#  'ainsiqu',
#  'ajoutee',
#  'ajouter',
#  'al',
#  'ala',
#  'aleatoir',
#  'algebriqu',
#  'algorithm',
#  'algorithm classification',
#  'algorithm dapprentissage',
#  'algorithm dextraction',
#  'algorithm efficace',
#  'algorithme',
#  'algorithme dapprentissage',
#  'algorithme dextraction',
#  'algorithme ete',
#  'algorithme fouiller',
#  'algorithme incremental',
#  'algorithmique',
#  'alignement',
#  'alternatif',
#  'amelior',
#  'amelioration',
#  'ameliore',
#  'amelioree',
#  'ameliorer',
#  'ameliorer qualite',
#  'amene',
#  'amont',
#  'an',
#  'analys',
#  'analyse',
#  'analyser',
#  'analyser donnee',
#  'analyser factoriel',
#  'analyser semantiqu',
#  'analytique',
#  'anne',
#  'annees',
#  'annot',
#  'annotation',
#  'annotation semantiqu',
#  'annoter',
#  'anormal',
#  'anr',
#  'apartir',
#  'apparer',
#  'appartenir',
#  'appel',
#  'appele',
#  'appelee',
#  'appeler',
#  'applicable',
#  'applicatif',
#  'application',
#  'application donnee',
#  'application reell',
#  'appliqu',
#  'applique',
#  'appliquee',
#  'appliquees',
#  'appliquer',
#  'apport',
#  'apporter',
#  'apprehender',
#  'apprendre',
#  'apprentissage',
#  'apprentissage automatique',
#  'apprentissage supervis',
#  'approche',
#  'approche existant',
#  'appropriee',
#  'approprier',
#  'approximatif',
#  'approximation',
#  'apr',
#  'aprer',
#  'arbitraire',
#  'arborescent',
#  'arbre',
#  'arbre decision',
#  'architecturer',
#  'article',
#  'article decrit',
#  'article etuder',
#  'article etudie',
#  'article interesser',
#  'article introduire',
#  'article method',
#  'article methode',
#  'article montrer',
#  'article present',
#  'article present method',
#  'article present methode',
#  'article presenter',
#  'article presenter method',
#  'article presenton',
#  'article proposer',
#  'article proposer method',
#  'article proposer methode',
#  'article proposer methodologie',
#  'article traire',
#  'articlenou',
#  'artificiel',
#  'ascendant',
#  'ascendant hierarchiqu',
#  'aspect',
#  'assister',
#  'associ',
#  'association',
#  'associe',
#  'associee',
#  'associeer',
#  'associees',
#  'associer',
#  'assurer',
#  'attaquer',
#  'atteindre',
#  'attention',
#  'attribu',
#  'attribut',
#  'atypique',
#  'augmenter',
#  'automat',
#  'automate',
#  'automatique',
#  'automatiquement',
#  'automatiser',
#  'autoorganisatrice',
#  'autour',
#  'avancee',
#  'avantage',
#  'axe',
#  'axer',
#  'axiome',
#  'baptis',
#  'base',
#  'base donnee',
#  'base donnee relationnel',
#  'base donneer',
#  'baseesur',
#  'baser',
#  'baser connaissance',
#  'baser dapprentissage',
#  'baser donne',
#  'baser donneer',
#  'baser modele',
#  'baser technique',
#  'batch',
#  'bayesien',
#  'bayesien naïf',
#  'bayesienn',
#  'benchmark',
#  'beneficier',
#  'besoin',
#  'biais',
#  'bibliographique',
#  'biclustering',
#  'binaire',
#  'bioinformatique',
#  'biologique',
#  'biomedical',
#  'bloc',
#  'block',
#  'booleenn',
#  'boosting',
#  'born',
#  'bruitees',
#  'brut',
#  'cadrer',
#  'cadrer article',
#  'cadrer classification',
#  'cadrer general',
#  'cadrer lanalyse',
#  'cadrer projet',
#  'cadrer rechercher',
#  'cadrer theoriqu',
#  'cadrer travail',
#  'calcul',
#  'calcul similarite',
#  'calculee',
#  'calculer',
#  'campagne',
#  'cancer',
#  'candidat',
#  'capable',
#  'capacite',
#  'capteur',
#  'capturer',
#  'caracter',
#  'caractere',
#  'caracterisation',
#  'caracterise',
#  'caracteriseer',
#  'caracteriser',
#  'caracteristiqu',
#  'caracteristique',
#  'caracteristiquer',
#  'cart',
#  'carte',
#  'carte autoorganisatrice',
#  'carte topologique',
#  'cartographie',
#  'cartographique',
#  'cas',
#  'cas donnee',
#  'categorie',
#  'categoriel',
#  'categoriell',
#  'categorisation',
#  'causer',
#  'celer',
#  'celer proposer',
#  'cell',
#  'celleci',
#  'cellesci',
#  'cellule',
#  'celuici',
#  'centaine',
#  'central',
#  'centree',
#  'centrer',
#  'cesser',
#  'cestadir',
#  'chain',
#  'chaine',
#  'chaine markov',
#  'challenge',
#  'champ',
#  'changement',
#  'changer',
#  'charger',
#  'chemin',
#  'chercher',
#  'chercheur',
#  'choisir',
#  'choix',
#  'choix mesurer',
#  'chronique',
#  'cibl',
#  'cibler',
#  'cl',
#  'clairement',
#  'classe',
#  'classement',
#  'classer',
#  'classificateur',
#  'classification',
#  'classification automatique',
#  'classification croise',
#  'classification document',
#  'classification donnee',
#  'classification hierarchiqu',
#  'classification multilabel',
#  'classification supervise',
#  'classification supervisee',
#  'classifier',
#  'classifieur',
#  'classifieur bayesien',
#  'classifieur bayesien naïf',
#  'classique',
#  'cle',
#  'clef',
#  'client',
#  'cluster',
#  'clustering',
#  'coclustering',
#  'codage',
#  'coefficient',
#  'coeur',
#  'cognitif',
#  'coherence',
#  'collaboratif',
#  'collaboration',
#  'collecter',
#  'collectif',
#  'collection',
#  'collection document',
#  'colonne',
#  'combin',
#  'combinaison',
#  'combinatoire',
#  'combiner',
#  'commencer',
#  'commercial',
#  'commun',
#  'communaut',
#  'communautair',
#  'communautaire',
#  'communaute',
#  'communication',
#  'compact',
#  'compacter',
#  'comparaison',
#  'comparaison entrer',
#  'comparatif',
#  'comparee',
#  'comparer',
#  'comparer resultat',
#  'compatible',
#  'competence',
#  'complementair',
#  'complementarite',
#  'complet',
#  'completer',
#  'complex',
#  'complexe',
#  'complexit',
#  'complexite',
#  'comportement',
#  'comportemer',
#  'comporter',
#  'composant',
#  'compose',
#  'composer',
#  'comprehension',
#  'comprendre',
#  'compromis',
#  'compromis entrer',
#  'compter',
#  'concentrer',
#  'concept',
#  'concept treillis',
#  'concepteur',
#  'conception',
#  'conceptuel',
#  'concerner',
#  'concevoir',
#  'concis',
#  'conclure',
#  'conclusion',
#  'concret',
#  'condensee',
#  'condensees',
#  'condition',
#  'conditionnel',
#  'conduire',
#  'conferenc',
#  'conference',
#  'confiance',
#  'configuration',
#  'confirmer',
#  'conflit',
#  'confronter',
#  'conjoint',
#  'conjointement',
#  'connaiss',
#  'connaissance',
#  'connaissance baser',
#  'connaissance domaine',
#  'connaissance expert',
#  'connaissance partir',
#  'connaissance partir donnee',
#  'connaissance priori',
#  'connaissancer',
#  'connaître',
#  'connexion',
#  'connu',
#  'consequent',
#  'conserver',
#  'consider',
#  'considere',
#  'consideree',
#  'considerer',
#  'consist',
#  'consister',
#  'consommation',
#  'constant',
#  'constater',
#  'constituer',
#  'construction',
#  'construction automatique',
#  'construction darbr',
#  'construction dontologie',
#  'construir',
#  'construire',
#  'construire partir',
#  'construit',
#  'construit partir',
#  'contenir',
#  'contenir document',
#  'contenu',
#  'context',
#  'contexte',
#  'contextuel',
#  'contingence',
#  'continu',
#  'continuer',
#  'contraindre',
#  'contraint',
#  'contrainte',
#  'contrairement',
#  'contribuer',
#  'contribution',
#  'controle',
#  'controler',
#  'convergence',
#  'convier',
#  'conçu',
#  'cooperativ',
#  'corpu',
#  'corpus',
#  'correct',
#  'correctement',
#  'correlation',
#  'correlation entrer',
#  'correspondance',
#  'correspondance afc',
#  'correspondance entrer',
#  'correspondant',
#  'correspondre',
#  'couleur',
#  'coupl',
#  'couple',
#  'coupler',
#  'courir',
#  'courir temps',
#  'cours',
#  'court',
#  'couverture',
#  'couvrir',
#  'coût',
#  'coûteux',
#  'creation',
#  'cree',
#  'creer',
#  'criter',
#  'critere',
#  'critere devaluation',
#  'croise',
#  'croisee',
#  'croiser',
#  'croissance',
#  'croyance',
#  'croître',
#  'cube',
#  'cuber',
#  'culturel',
#  'cycle',
#  'dabord',
#  'daccelerer',
#  'dacquisition',
#  'dadapter',
#  'dagregation',
#  'daid',
#  'daid decision',
#  'daider',
#  'dalgorithme',
#  'dalignemer',
#  'dameliorer',
#  'dameliorer performance',
#  'danalyse',
#  'danalyser',
#  'dannotation',
#  'danscet',
#  'danscet article',
#  'danscet article proposer',
#  'dansl',
#  'dansun',
#  'dappariemer',
#  'dapparition',
#  'dappartenance',
#  'dapplication',
#  'dapporter',
#  'dapprendre',
#  'dapprentissage',
#  'dapprentissage automatique',
#  'dapprentissage supervis',
#  'darbr',
#  'darbr decision',
#  'darticl',
#  'dassoci',
#  'dassociation',
#  'dater',
#  'dater mining',
#  'dater stream',
#  'dattribut',
#  'dattributs',
#  'daugmenter',
#  'dautre',
#  'dautre partir',
#  'debut',
#  'decd',
#  'decennie',
#  'dechantillon',
#  'dechantillonnage',
#  'decider',
#  'decideur',
#  'decis',
#  'decision',
#  'decisionnel',
#  'decisionnell',
#  'decomposition',
#  'decoupage',
#  'decouvert',
#  'decouverte',
#  'decouverte motif',
#  'decouvrir',
#  'decouvrir motif',
#  'decrir',
#  'decrire',
#  'decrit',
#  'decrite',
#  'decrivant',
#  'decriver',
#  'decrivons',
#  'dedie',
#  'dediee',
#  'dedition',
#  'dedonnee',
#  'deduire',
#  'defaut',
#  'deffectuer',
#  'defi',
#  'defi egc',
#  'defini',
#  'definie',
#  'definier',
#  'definir',
#  'definis',
#  'definisser',
#  'definissons',
#  'definit',
#  'definition',
#  'degager',
#  'degr',
#  'degre',
#  'delagage',
#  'delement',
#  'demander',
#  'demarch',
#  'demonstration',
#  'denrichir',
#  'dense',
#  'densembl',
#  'densite',
#  'dentiter',
#  'dentre',
#  'dentrepris',
#  'depart',
#  'dependanc',
#  'dependance',
#  'dependance fonctionnel',
#  'depender',
#  'deper',
#  'dequivalence',
#  'derive',
#  'derreur',
#  'descripteur',
#  'descriptif',
#  'description',
#  'desdonnee',
#  'desequilibre',
#  'destimer',
#  'detablir',
#  'detailler',
#  'detat',
#  'detecter',
#  'detection',
#  'detection changement',
#  'detectiond',
#  'detendre',
#  'determination',
#  'determine',
#  'determiner',
#  'detr',
#  'detre',
#  'detude',
#  'detudier',
#  'deuxieme',
#  'devaluation',
#  'devaluer',
#  'devaluer qualite',
#  'developp',
#  'developpe',
#  'developpee',
#  'developpement',
#  'developpemer',
#  'developper',
#  'devenement',
#  'devenir',
#  'devenir plaire',
#  'devoir',
#  'devoir permettre',
#  'devolution',
#  'dexecution',
#  'dexempl',
#  'dexperience',
#  'dexperimentation',
#  'dexploiter',
#  'dexploration',
#  'dexplorer',
#  'dexpression',
#  'dexprimer',
#  'dextraction',
#  'dextraction connaissance',
#  'dextraction connaissance partir',
#  'dextraction motif',
#  'dextrair',
#  'dextraire',
#  'dheuristiqu',
#  'diagnostic',
#  'dictionnair',
#  'didentification',
#  'didentifier',
#  'difference',
#  'differenter',
#  'difficile',
#  'difficilement',
#  'difficult',
#  'difficulte',
#  'diffusion',
#  'dimag',
#  'dimage',
#  'dimager',
#  'dimension',
#  'dincertitude',
#  'dindexation',
#  'dindice',
#  'dindividus',
#  'dinduction',
#  'dinference',
#  'dinferer',
#  'dinfluence',
#  'dinform',
#  'dinformation',
#  'dintegration',
#  'dintegrer',
#  'dinteraction',
#  'dinteraction entrer',
#  'dinteret',
#  'dinternet',
#  'dinterpretation',
#  'dinterrogation',
#  'dintroduir',
#  'direct',
#  'direction',
#  'discret',
#  'discretisation',
#  'discriminant',
#  'discriminanter',
#  'discrimination',
#  'discriminer',
#  'discussion',
#  'discuter',
#  'disponible',
#  'disposer',
#  'dispositif',
#  'disposition',
#  'dissimilarit',
#  'dissimilarite',
#  'dissimilarite entrer',
#  'distance',
#  'distancer',
#  'distancer entrer',
#  'distinct',
#  'distinguer',
#  'distribu',
#  'distribuer',
#  'distribution',
#  'ditems',
#  'ditemset',
#  'ditemset frequent',
#  'diversite',
#  'diviser',
#  'dizaine',
#  'dobjet',
#  'dobjets',
#  'dobtenir',
#  'docu',
#  'document',
#  'document textuel',
#  'document xml',
#  'documentaire',
#  'doffr',
#  'domaine',
#  'domaine dapplication',
#  'domaine lapprentissage',
#  'don',
#  'donne',
#  'donnee',
#  'donnee article',
#  'donnee artificiel',
#  'donnee baser',
#  'donnee cluster',
#  'donnee disponible',
#  'donnee geographiqu',
#  'donnee issu',
#  'donnee massif',
#  'donnee multidimensionnel',
#  'donnee numeriqu',
#  'donnee permettre',
#  'donnee plaire',
#  'donnee pouvoir',
#  'donnee presenter',
#  'donnee qualitatif',
#  'donnee reel',
#  'donnee reell',
#  'donnee reell issu',
#  'donnee reell montrer',
#  'donnee relationnel',
#  'donnee sequentiell',
#  'donnee simuleer',
#  'donnee symbolique',
#  'donnee synthetiqu',
#  'donnee textuel',
#  'donnee tr',
#  'donnee visualisation',
#  'donneer',
#  'donneer article',
#  'donneer luci',
#  'donneer plaire',
#  'donneer reell',
#  'donneer textuel',
#  'donnees',
#  'donner',
#  'donner resultat',
#  'dontologie',
#  'dontologie partir',
#  'dontologier',
#  'dopinion',
#  'doptimisation',
#  'dordre',
#  'dorigine',
#  'doter',
#  'doutil',
#  'doutils',
#  'duree',
#  'durer',
#  'durer processus',
#  'dusage',
#  'dutilisateur',
#  'dutilisation',
#  'dutiliser',
#  'dynam',
#  'dynamique',
#  'ecd',
#  'echantillon',
#  'echantillonnage',
#  'echell',
#  'echelle',
#  'eclairage',
#  'economiqu',
#  'effectu',
#  'efficace',
#  'efficacement',
#  'efficacite',
#  'effort',
#  'eg',
#  'egc',
#  'element',
#  'elev',
#  'eleve',
#  'elevee',
#  'emergent',
#  'empirique',
#  'empiriquement',
#  'employer',
#  'encompte',
#  'encourageant',
#  'encourageant prometteur',
#  'engendrer',
#  'enjeu',
#  'enjeu majeur',
#  'enregistrement',
#  'enrichir',
#  'enrichissement',
#  'ensembl',
#  'ensembl donnee',
#  'ensembl donneer',
#  'ensembl mesure',
#  'ensemble',
#  'ensemble donnee',
#  'ensemble donneer',
#  'ensemble regl',
#  'ensembliste',
#  'entite',
#  'entrainer',
#  'entrepot',
#  'entrepot donnee',
#  'entreprendre',
#  'entreprise',
#  'entrer',
#  'entrer attribut',
#  'entrer classe',
#  'entrer concept',
#  'entrer donnee',
#  'entrer ensemble',
#  'entrer groupe',
#  'entrer individu',
#  'entrer objet',
#  'entrer ontologie',
#  'entrer variable',
#  'environnement',
#  'envisageable',
#  'equivalent',
#  'erreur',
#  'espac',
#  'espace',
#  'espacer',
#  'essentiel',
#  'essentiellement',
#  'estim',
#  'estimateur',
#  'estimation',
#  'estimation densite',
#  'estimee',
#  'estimer',
#  'etablie',
#  'etablir',
#  'etablisser',
#  'etape',
#  'etat',
#  'etde',
#  'ete',
#  'ete developpe',
#  'ete etudie',
#  'ete implemente',
#  'ete propos',
#  'ete propose',
#  'ete proposees',
#  'etendu',
#  'eter',
#  'etiquetage',
#  'etiquete',
#  'etl',
#  'etle',
#  'etroitement',
#  'etude',
#  'etude comparatif',
#  'etude experimental',
#  'etuder',
#  'etudie',
#  'etudiee',
#  'etudier',
#  'euclidien',
#  'evalu',
#  'evaluation',
#  'evalue',
#  'evaluee',
#  'evaluees',
#  'evaluer',
#  'evenement',
#  'evidence',
#  'eviter',
#  'evoluer',
#  'evolution',
#  'evolutiv',
#  'ex',
#  'exact',
#  'examiner',
#  'exemple',
#  'exhaustif',
#  'exhiber',
#  'existant',
#  'exister',
#  'exister entrer',
#  'experience',
#  'experience montrer',
#  'experiment',
#  'experimental',
#  'experimentalement',
#  'experimentation',
#  'experimentation jeu',
#  'experimentation jeu donnee',
#  'experimentation menee',
#  'experimentation montrer',
#  'experimentaux',
#  'experimentaux montrer',
#  'expert',
#  'expert domaine',
#  'explicatif',
#  'expliciter',
#  'expliquer',
#  'exploitable',
#  'exploitation',
#  'exploiter',
#  'exploration',
#  'exploratoire',
#  'explorer',
#  'exponentiel',
#  'exposer',
#  'expression',
#  'exprimeer',
#  'exprimer',
#  'extension',
#  'extraction',
#  'extraction connaissance',
#  'extraction motif',
#  'extraction regl',
#  'extraire',
#  'extraire connaissance',
#  'extraire motif',
#  'extrait',
#  'extraite',
#  'face',
#  'facile',
#  'facilement',
#  'faciliter',
#  'facteur',
#  'factoriel',
#  'factoriel correspondance',
#  'factoriel correspondance afc',
#  'factorisation',
#  'faible',
#  'faire',
#  'faire appel',
#  'faire face',
#  'faire lobjet',
#  'faire partir',
#  'faisabilite',
#  'famille',
#  'favoriser',
#  'feature',
#  'ferme',
#  'ferme frequent',
#  'fiabilite',
#  'fiable',
#  'fichier',
#  'filtrage',
#  'filtrer',
#  'fin',
#  'final',
#  'finalement',
#  'financier',
#  'fixe',
#  'fixer',
#  'flexible',
#  'flot',
#  'flot donneer',
#  'flou',
#  'flouer',
#  'flux',
#  'flux don',
#  'flux donne',
#  'flux donnee',
#  'flux donneer',
#  'focaliser',
#  'fonction',
#  'fonction croyance',
#  'fonctionnalite',
#  'fonctionnel',
#  'fonctionnement',
#  'fonctionner',
#  'fond',
#  'fondamental',
#  'fondee',
#  'fondre',
#  'for',
#  'foret',
#  'foret aleatoir',
#  'formalisation',
#  'formaliser',
#  'formalisme',
#  'format',
#  'formation',
#  'forme',
#  'formel',
#  'formel concept',
#  'former',
#  'former regl',
#  'formulation',
#  'formuler',
#  'fort',
#  'fortement',
#  'fouill',
#  'fouill donneer',
#  'fouiller',
#  'fouiller donne',
#  'fouiller donnee',
#  'fouiller donneer',
#  'fouiller grand',
#  'fouiller texter',
#  ...]

# %%
# From here, the end use LSA :P Then the code below isn't important

# %%
#params
nb_concepts = 30
min_gram = 1
max_gram = 3

# Creation of cleandocs, which is usable[] with ngrams
cleandocs = []
for t in usable:
    doc = []
    for n in range(min_gram, max_gram+1):
        for gram in ngrams(t.split(), n):
            doc.append(" ".join(gram))
    cleandocs.append(doc)

# Creation of tfidf model, a tool to create ours tfidf
corpus = []
dictionary = corpora.Dictionary(cleandocs)
for doc in cleandocs:
    newVec = dictionary.doc2bow(doc)
    corpus.append(newVec)
tfidf = models.TfidfModel(corpus)

# Creation of partitions_lsa[], which give us the LSA of each partition
partitions_lsa = []
beg = 0
for l in limits:
    last = l
    corpus_tfidf = tfidf[corpus]
    lsi = models.LsiModel(corpus_tfidf, num_topics=nb_concepts, id2word=dictionary)
    corpus_lsi = lsi[corpus_tfidf[beg:last]]
    partitions_lsa.append(corpus_lsi)
    beg = l
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f56a40bfd21f> in <module>
#      27     last = l
#      28     corpus_tfidf = tfidf[corpus]
# ---> 29     lsi = models.LsiModel(corpus_tfidf, num_topics=nb_concepts, id2word=dictionary)
#      30     corpus_lsi = lsi[corpus_tfidf[beg:last]]
#      31     partitions_lsa.append(corpus_lsi)
#
# ~/venv/lib/python3.5/site-packages/gensim/models/lsimodel.py in __init__(self, corpus, num_topics, id2word, chunksize, decay, distributed, onepass, power_iters, extra_samples, dtype)
#     439
#     440         if corpus is not None:
# --> 441             self.add_documents(corpus)
#     442
#     443     def add_documents(self, corpus, chunksize=None, decay=None):
#
# ~/venv/lib/python3.5/site-packages/gensim/models/lsimodel.py in add_documents(self, corpus, chunksize, decay)
#     485                     logger.info('initializing %s workers', self.numworkers)
#     486                     self.dispatcher.reset()
# --> 487                 for chunk_no, chunk in enumerate(utils.grouper(corpus, chunksize)):
#     488                     logger.info("preparing a new chunk of documents")
#     489                     nnz = sum(len(doc) for doc in chunk)
#
# ~/venv/lib/python3.5/site-packages/gensim/utils.py in chunkize_serial(iterable, chunksize, as_numpy, dtype)
#    1147             wrapped_chunk = [[np.array(doc, dtype=dtype) for doc in itertools.islice(it, int(chunksize))]]
#    1148         else:
# -> 1149             wrapped_chunk = [list(itertools.islice(it, int(chunksize)))]
#    1150         if not wrapped_chunk[0]:
#    1151             break
#
# ~/venv/lib/python3.5/site-packages/gensim/interfaces.py in __iter__(self)
#     173         else:
#     174             for doc in self.corpus:
# --> 175                 yield self.obj[doc]
#     176
#     177     def __getitem__(self, docno):
#
# ~/venv/lib/python3.5/site-packages/gensim/models/tfidfmodel.py in __getitem__(self, bow, eps)
#     444         if self.pivot is None:
#     445             norm_vector = self.normalize(vector)
# --> 446             norm_vector = [(termid, weight) for termid, weight in norm_vector if abs(weight) > self.eps]
#     447         else:
#     448             _, old_norm = self.normalize(vector, return_norm=True)
#
# ~/venv/lib/python3.5/site-packages/gensim/models/tfidfmodel.py in <listcomp>(.0)
#     444         if self.pivot is None:
#     445             norm_vector = self.normalize(vector)
# --> 446             norm_vector = [(termid, weight) for termid, weight in norm_vector if abs(weight) > self.eps]
#     447         else:
#     448             _, old_norm = self.normalize(vector, return_norm=True)
#
# KeyboardInterrupt:

# %%
num_partition = 0
for lsa in partitions_lsa:
    print("Partition numéro:",num_partition)
    num_partition+=1
    i=0
    for doc in lsa:
        if (i<3):
            print("document number ", i)
            i+=1
            print(doc)

# %%
# Let's create ours partitions
partitions = []

# You must specify a treshold, to know what are the doc you keep, and what are the doc you drop
tresh = 0.03

for corpus_lsi in partitions_lsa:
    # Let's create ours clusters
    clusters = []

    for i in range(0, nb_concepts):
        dic = {}
        num_doc = 0
        for doc in corpus_lsi:
            if abs(doc[i][1]) > tresh:
                dic[num_doc] = doc[i][1]
            num_doc+=1
        clusters.append(dic)
    partitions.append(clusters)
    
# TODO: it would be nice to know how many articles are in no cluster anymore

# %%
# Display clusters 3 of partition 0 
partitions[0][3]

# %%
nb_labels_by_cluster = 5

# Let's labelize our clusters
# For this, we will use the tfidf matrix

vectorizer = TfidfVectorizer(stop_words=sourceFST, use_idf=True, ngram_range=(min_gram, max_gram))
tfidf = vectorizer.fit_transform(usable)

# We can access the value in the tfidf using:
#tfidf.toarray().item(num_doc, num_word)
# To know the number of the word searched, we will use:
#vectorizer.vocabulary_[word]

# take less than 8h to compute x)
labels = []
for clusters in partitions:
    l = []
    for clus in clusters:
        first_arti = True
        for article in clus:
            link = abs(clus[article])
            if first_arti:
                coef_list = (tfidf.toarray()[article] * link)
                first = False
            else:
                # the more an article have a high coeficient, the more he is implied in the labeling step
                coef_list += (tfidf.toarray()[article] * link)
        # Now we have coef_list filled by every coeficient in the multiple tfidf
        # Let's find the best ones, to finally get the labels
        res = dict(zip(vectorizer.get_feature_names(), coef_list))

        l.append(Counter(res).most_common(nb_labels_by_cluster))
    labels.append(l)

# TODO: on observe beaucoup de labels identiques entre deux clusters
# Je pense que c'est parce que l'on a trop de clusters, mais j'aimerais en être sûr

# %%
# Display labels
# labels is composed by an array for each partition
labels
