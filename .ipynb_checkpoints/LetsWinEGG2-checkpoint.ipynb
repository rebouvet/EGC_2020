# %%
import nltk
import pandas as pd
import random
import numpy as np
import string
import math

from nltk import ngrams
from nltk.corpus import stopwords
from nltk.stem.snowball import FrenchStemmer
from nltk.tokenize import word_tokenize

from numpy import array
from collections import Counter
from scipy.sparse import csr_matrix

from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans

from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
from gensim import corpora, models, utils
from gensim.test.utils import common_corpus, common_dictionary, get_tmpfile
from gensim.models import LsiModel
from gensim.corpora import Dictionary

import re

# %%
# Use spacy lib
# On https://spacy.io/

import spacy
nlp = spacy.load('fr')

# %%
##############
# Parameters #
##############

min_gram = 1
max_gram = 3

# To create ours partitions, we must first know the years which will be the limits
limit_years = [2007, 2010, 2014]

# Ignore words that appear at a frequency less than max_frequ in the corpus
max_frequ = 0.8

# Ignore words appearing less than min_appear in the whole corpus
min_appear = 5

# Number of clusters by partitions
nb_clusters = 5

# %%
# Datas preprocessing methods.

# Lemmatisation without poncutations

stemmer = nltk.stem.snowball.FrenchStemmer()
fstw = stopwords.words('french')

# French Stop Words, extraits depuis le fichier stopwords-fr.txt + stopwords french de nltk
sourceFST = [x.replace('\n', '') for x in open('stopwords-fr.txt', mode="r", encoding="utf-8").readlines()]+fstw
sourceFST += [x.replace('\n', '') for x in open('perso_words-fr.txt', mode="r", encoding="utf-8").readlines()]

# Based on ration of french and english stopwords
def isEnglish(article):
    total_fsw = len([x for x in article.split() if x in sourceFST])
    total_esw = len([x for x in article.split() if x in stopwords.words('english')])
    ratio = 100
    if total_fsw != 0:
        ratio = total_esw/total_fsw
    return ratio > 1 and total_esw > 3

def lemmatize(article):
    artiregex = article
    artiregex = re.sub(" [0-z][0-z] ", " ", artiregex) # word of length < 2
    artiregex = artiregex.lower()
    artiregex = re.sub("(é|è|ê)", "e", artiregex)
    artiregex = re.sub("à", "a", artiregex)
    artiregex = re.sub("ô", "o", artiregex)
    artiregex = re.sub("î", "i", artiregex)
    output = []
    outPonc = artiregex.translate(artiregex.maketrans("","", string.punctuation))
    outLem = nlp(outPonc)
    for token in outLem:
        if token.lemma_ not in sourceFST and [x for x in token.lemma_ if x not in "0123456789"] != []:
            output.append(token.lemma_)
    res = ' '.join(output)
    return res

# %%
re.sub(" [0-z][0-z] ", " ", "ceci est un test")
# Out:
# 'ceci est test'

# %%
# Data Reading
data = pd.read_csv('export_articles_EGC_2004_2018.csv', sep='\t', header=0)

# %%
# Let's process our corpus, and determine a limit to split it in partitions

# usable[] correspond to our corpus processed
# limits[] let us know when to delimit partitions
limits = []
usable = []

prev_year = data['year'][0]
numArti = 0
for i in range(0, len(data['abstract']), 1):
    #if not null, empty, or whatever (so if there is a abstract):
    if not isinstance(data['abstract'][i], float) and not isEnglish(data['abstract'][i]):
        text = data['abstract'][i]
        if not isinstance(data['title'][i], float):
            text += " "+data['title'][i]

        numArti+=1
        usable.append(stemmer.stem(lemmatize(text)))
        year = data['year'][i]
        if year != prev_year:
            prev_year = year
            if year in limit_years:
                limits.append(numArti)
limits.append(numArti)

# %%
# Display pre-processed datas

vectorizer = TfidfVectorizer(stop_words=sourceFST, use_idf=True, ngram_range=(min_gram, max_gram), max_df=max_frequ, min_df=min_appear)
tfidf = vectorizer.fit_transform(usable)

print("nombre d'articles =", len(usable))
print("nombre de mots =", len(tfidf.toarray()[0]))
print("limits =", limits)

usable[0]
# Out:
# /info/etu/m2/i140302/venv/lib/python3.5/site-packages/sklearn/feature_extraction/text.py:286: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['quelqu'] not in stop_words.
#   sorted(inconsistent))
# nombre d'articles = 991
# nombre de mots = 2410
# limits = [223, 468, 694, 991]
# 'plateforme objectif permettre citoyen euxmemer tweet politique devenement specifiqu francepour cas lelection presidentiell ideo2017 analyser quasitemps reel message candidat fournir principal caracteristiqueslusage lexiqu politique comparaison entrer candidat ideo2017   plateforme citoyen dediee lanalyse tweet evenement polit'

# %%
# Creation of partitions_tfidf[], which give us the TFIDF of each cluster of each partition
# partitions_tfidf[num_partition][num_doc][num_word]
# Beware, num_doc can't be equals to 1091 (max). You have partitions, so every doc aren't in every partitions
# num_word can be found via vectorizer.get_feature_name()
partitions_tfidf = []
beg = 0
for l in limits:
    last = l
    partitions_tfidf.append([list(x) for x in list(tfidf.toarray())[beg:last]])
    beg = l

# %%
len(partitions_tfidf)
# Out:
# 4

# %% [markdown]
# # KMeans

# %%
# Applying KMeans on tfidf
# the labels_ give assignment of doc to the cluster number 
km = KMeans(n_clusters=nb_clusters)
km.fit(tfidf)
cluster = km.labels_

cluster_partition = [cluster[:limits[0]],cluster[limits[0]:limits[1]],cluster[limits[1]:limits[2]],cluster[limits[2]:limits[3]]]

# %%
part_km = []
for i in range(0, len(limits)):
    dash = km.fit(partitions_tfidf[i])
    part_km.append(dash)

# %%
#(part_km[1]).labels_
#
#all_labels = []
#for i in range(0,len(limits)):
#    for j in range(0, len((part_km[i]).labels_)):

# %%
# doc_clustering is a dictionnary 
# it looks like -> { doc_number : [partition_number, cluster_number] }
# This is used to reassign doc number to their respective partition and and cluster
doc_clustering = {}
for i in range(0,len(usable)):
    if i < limits[0]:
        doc_clustering[i] = [0, cluster[i]]
    elif i >= limits[0] and i < limits[1]:
        doc_clustering[i] = [1, cluster[i]]
    elif i >= limits[1] and i < limits[2]:
        doc_clustering[i] = [2, cluster[i]]
    else:
        doc_clustering[i] = [3, cluster[i]]

# %%
# Allows to get list of documents number
# return [dou numbers]
# params : partition_number , cluster number
partitions = []
def get_doc(part, clust):
    docs = []
    for i in range(0,len(doc_clustering)):
        if doc_clustering[i][0] == part and doc_clustering[i][1] == clust:
            docs.append(i)
    return docs

# %%
# Get the partitions variable
# Here partitions[part][cluster] = list of docs numbe
partitions = []
for i in range(0, len(limits)):
    clusters = []
    for j in range(0, nb_clusters):
        clusters.append(get_doc(i,j))
    partitions.append(clusters)

# %%
# example of output for doc_clustering
# doc 465 is in cluster 1 of the partition 1
# doc 154 is in cluster 2 of the partition 0

print(doc_clustering[465])
print(doc_clustering[154])
print()

# Here, just count docs number by cluster.
print(Counter(cluster_partition[0]))
print(Counter(cluster_partition[1]))
print(Counter(cluster_partition[2]))
print(Counter(cluster_partition[3]))
# Out:
# [1, 4]
# [0, 3]
#
# Counter({4: 151, 2: 26, 3: 24, 1: 16, 0: 6})
# Counter({4: 140, 3: 44, 2: 31, 1: 21, 0: 9})
# Counter({4: 134, 3: 35, 2: 33, 0: 12, 1: 12})
# Counter({4: 152, 2: 54, 3: 42, 0: 31, 1: 18})

# %% [markdown]
# # Quality Measure

# %%
# INSERT QUALITY MEASURE HERE

# %% [markdown]
# # Khi²

# %%
# tf_of_your_word = tf[numDoc][strWord]
tf = []
for doc in usable:
    tf_doc = {}
    for word in vectorizer.get_feature_names():
        tf_doc[word] = doc.count(word)
    tf.append(tf_doc)

# %%
# Number total of words
# nb_total_word[numPartition]
nb_total_word = []
nb = 0

for numDoc in range(0, len(usable)):
    for word in vectorizer.get_feature_names():
        nb += tf[numDoc][word]
    if numDoc+1 in limits:
        nb_total_word.append(nb)
        nb=0

# %%
nb_total_word
# Out:
# [34546, 37954, 33837, 45673]

# %%
tf[0]
# Out:
# {'panel': 0,
#  'debut': 0,
#  'laver': 0,
#  'decouverte motif': 0,
#  'formulation': 0,
#  'vis vis': 0,
#  'method danalyse': 0,
#  'reconstruction': 0,
#  'stocker': 0,
#  'developpe': 0,
#  'devaluation': 0,
#  'tableau donnee': 0,
#  'mene': 0,
#  'durer processus': 0,
#  'structurer sousjacent': 0,
#  'decrir': 0,
#  'presenter resultat': 0,
#  'habituellement': 0,
#  '3d': 0,
#  'strategie': 0,
#  'lextractionde': 0,
#  'lagregation': 0,
#  'realisation': 0,
#  'commun': 0,
#  'variable': 0,
#  'determination': 0,
#  'perte': 0,
#  'scenario': 0,
#  'complexe': 0,
#  'linteret': 0,
#  'nombre classe': 0,
#  'grand volume donnee': 0,
#  'reseaux bayesien': 0,
#  'souffrir': 0,
#  'original': 0,
#  'them': 0,
#  'applique': 0,
#  'specificite': 0,
#  'detat': 0,
#  'quune': 0,
#  'technique permettre': 0,
#  'algorithme fouiller': 0,
#  'dacquisition': 0,
#  'utiliser modele': 0,
#  'vis': 0,
#  'precision': 0,
#  'induit': 0,
#  'axer': 0,
#  'linteret methode': 0,
#  'tr': 2,
#  'devenir plaire': 0,
#  'delagage': 0,
#  'loptimisation': 0,
#  'modele predictif': 0,
#  'perdre': 0,
#  'validee': 0,
#  'gerer': 0,
#  'fouiller': 0,
#  'systeme gestion': 0,
#  'lapprentissage supervis': 0,
#  'strategiqu': 0,
#  'performer': 0,
#  'foret aleatoir': 0,
#  'dynam': 0,
#  'text': 0,
#  'concevoir': 0,
#  'sadapter': 0,
#  'statique': 0,
#  'tableau': 0,
#  'actif': 0,
#  'initialement': 0,
#  'orient': 0,
#  'comprendre': 0,
#  'labsence': 0,
#  'associe': 0,
#  'informationnel': 0,
#  'utiliser technique': 0,
#  'lheure actuel': 0,
#  'optique': 0,
#  'system rechercher': 0,
#  'liees': 0,
#  'rester': 0,
#  'pourtant': 0,
#  'potentiel': 0,
#  'outil visualisation': 0,
#  'ouvrir': 0,
#  'selectionner': 0,
#  'dinteret': 0,
#  'long': 0,
#  'baptis': 0,
#  'lespace representation': 0,
#  'article etuder': 0,
#  'opinion': 0,
#  'quun': 0,
#  'populaire': 0,
#  'viser': 0,
#  'profil': 0,
#  'repartition': 0,
#  'dattribut': 0,
#  'distribuer': 0,
#  'flot donneer': 0,
#  'permettre mettre': 0,
#  'proposer dutiliser': 0,
#  'surune': 0,
#  'levaluation': 0,
#  'connaiss': 0,
#  'lon': 0,
#  'condensees': 0,
#  'maximisation': 0,
#  'actuel': 0,
#  'proposonsune': 0,
#  'parametre': 0,
#  'etablisser': 0,
#  'dequivalence': 0,
#  'modifier': 0,
#  'uniforme': 0,
#  'etat': 0,
#  'typer': 0,
#  'flouer': 0,
#  'discriminant': 0,
#  'demonstration': 0,
#  'parametr': 0,
#  'sousgraphe': 0,
#  'obtenir montrer': 0,
#  'remedier probleme': 0,
#  'requérir': 0,
#  'mesurer similarite': 0,
#  'automatiser': 0,
#  'quantite': 0,
#  'caracterisation': 0,
#  'objectif': 1,
#  'modele conceptuel': 0,
#  'classification multilabel': 0,
#  'ex': 1,
#  'methode reposer': 0,
#  'gros': 0,
#  'theme': 0,
#  'detailler': 0,
#  'focaliser': 0,
#  'association': 0,
#  'appele': 0,
#  'moindre': 0,
#  'production': 0,
#  'fouiller grand': 0,
#  'associ': 0,
#  'visualiser': 0,
#  'dinduction': 0,
#  'choisir': 0,
#  'pertinence': 0,
#  'definisser': 0,
#  'uniquement': 0,
#  'amelioration': 0,
#  'produit': 0,
#  'dexpression': 0,
#  'distribu': 0,
#  'communaute': 0,
#  'methode classification': 0,
#  'travailler': 0,
#  'artificiel': 0,
#  'serier': 0,
#  'entrainer': 0,
#  'manier': 0,
#  'caracteriseer': 0,
#  'serveur': 0,
#  'reduction': 0,
#  'difficulte': 0,
#  'croître': 0,
#  'repondre besoin': 0,
#  'maximum': 0,
#  'dobjets': 0,
#  'derive': 0,
#  'ville': 0,
#  'sequenc': 0,
#  'regroupement': 0,
#  'yu': 0,
#  'efficace': 0,
#  'construction darbr': 0,
#  'permettre utilisateur': 0,
#  'linteret lapproch': 0,
#  'partir corpus': 0,
#  'classifieur': 0,
#  'anormal': 0,
#  'tâcher important': 0,
#  'exponentiel': 0,
#  'symbolique': 0,
#  'ecd': 0,
#  'dapplication': 0,
#  'distancer': 0,
#  'modele': 0,
#  'application donnee': 0,
#  'superviser': 0,
#  'atteindre': 0,
#  'permettre reduir': 0,
#  'proposer modele': 0,
#  'predictif': 0,
#  'petit': 0,
#  'pr': 2,
#  'regle dassoci': 0,
#  'flux donne': 0,
#  'activite': 0,
#  'jusquer': 0,
#  'correspondant': 0,
#  'ensembl mesure': 0,
#  'conception': 0,
#  'genre': 0,
#  'chercheur': 0,
#  'lobjectif': 0,
#  'generee': 0,
#  'treillis galoi': 0,
#  'augmenter': 0,
#  'annot': 0,
#  'continu': 0,
#  'sappui': 0,
#  'modalite': 0,
#  'defi': 0,
#  'qualite': 0,
#  'lapproche': 0,
#  'adn': 0,
#  'annotation': 0,
#  'cart': 0,
#  'changement': 0,
#  'modele graphe': 0,
#  'svm support': 0,
#  'capturer': 0,
#  'dexprimer': 0,
#  'efficacement': 0,
#  'poindre voir': 0,
#  'position': 0,
#  'ignorer': 0,
#  'placer': 0,
#  'problem': 0,
#  'estimateur': 0,
#  'realise': 0,
#  'vision': 0,
#  'dorigine': 0,
#  'terminologique': 0,
#  'rechercher dinformation': 0,
#  'priser compter': 0,
#  'role': 0,
#  'detecter': 0,
#  'typique': 0,
#  'manipulation': 0,
#  'montrer method': 0,
#  'lespac': 0,
#  'cell': 0,
#  'temp': 1,
#  'apr': 0,
#  'cellule': 0,
#  'danalyser': 0,
#  'or': 2,
#  'lien entrer': 0,
#  'prealablement': 0,
#  'validite': 0,
#  'satellit': 0,
#  'caracteristique': 1,
#  'applicable': 0,
#  'typer donnee': 0,
#  'grand nombre': 0,
#  'integr': 0,
#  'voter': 0,
#  'nexist': 0,
#  'autour': 0,
#  'verification': 0,
#  'conjointement': 0,
#  'documentaire': 0,
#  'baser donneer': 0,
#  'donnee massif': 0,
#  'linguistique': 0,
#  'convergence': 0,
#  'concept treillis': 0,
#  'informatif': 0,
#  'cadrer article': 0,
#  'pratiquer': 0,
#  'ete propose': 0,
#  'programmation': 0,
#  'qualitatif': 0,
#  'traditionnel': 0,
#  'degager': 0,
#  'an': 5,
#  'structure': 0,
#  'block': 0,
#  'maximiser': 0,
#  'equivalent': 0,
#  'baser donne': 0,
#  'garantir': 0,
#  'lextraction regl': 0,
#  'loriginalite': 0,
#  'daugmenter': 0,
#  'intelligible': 0,
#  'presenter papier': 0,
#  'testee': 0,
#  'tâche classification': 0,
#  'temps reel': 1,
#  'appliquees': 0,
#  'dinteraction': 0,
#  'cas donnee': 0,
#  'lobjectif travail': 0,
#  'xml': 0,
#  'dimage': 0,
#  'propagation': 0,
#  'description': 0,
#  'docu': 0,
#  'permettre': 1,
#  'generees': 0,
#  'defi egc': 0,
#  'jouer role': 0,
#  'multidimensionnel': 0,
#  'dexempl': 0,
#  'heterogen': 0,
#  'propriete': 0,
#  'paradigme': 0,
#  'langue': 0,
#  'parcimonieux': 0,
#  'tirer': 0,
#  'culturel': 0,
#  'bioinformatique': 0,
#  'algorithm classification': 0,
#  'contribuer': 0,
#  'loi': 0,
#  'grand tailler': 0,
#  'commercial': 0,
#  'proportion': 0,
#  'connaissance': 0,
#  'requete': 0,
#  'parcours': 0,
#  'traire': 0,
#  'gain': 0,
#  'reposer lutilisation': 0,
#  'travers': 0,
#  'exhaustif': 0,
#  'referent': 0,
#  'lapproch': 0,
#  'mining': 0,
#  'nont': 0,
#  'semantiquement': 0,
#  'automate': 0,
#  'mobilite': 0,
#  'majeur': 0,
#  'travail': 0,
#  'donnee pouvoir': 0,
#  'famille': 0,
#  'nature': 0,
#  'lerreur': 0,
#  'distribution': 0,
#  'depart': 0,
#  'luire': 0,
#  'varieer': 0,
#  'detre': 0,
#  'centaine': 0,
#  'donne': 0,
#  'exprimeer': 0,
#  'permettre determiner': 0,
#  'base donneer': 0,
#  'semiautomatique': 0,
#  'eleve': 0,
#  'experimentation montrer': 0,
#  'structurer donneer': 0,
#  'traduire': 0,
#  'presentation': 0,
#  'essentiel': 0,
#  'situation': 0,
#  'generateur': 0,
#  'mesure': 0,
#  'centree': 0,
#  'vaste marge': 0,
#  'constituer': 0,
#  'jeu donnee reell': 0,
#  'pondere': 0,
#  'comprehension': 0,
#  'conduire': 0,
#  'caracteristiquer': 0,
#  'effectu': 0,
#  'complex': 0,
#  'anne': 0,
#  'expert': 0,
#  'outrer': 0,
#  'entrepot donnee': 0,
#  'meilleur qualite': 0,
#  'robuste': 0,
#  'dexperience': 0,
#  'agent': 0,
#  'video': 0,
#  'evaluee': 0,
#  'selectionde': 0,
#  'danalyse': 0,
#  'traiter probleme': 0,
#  'projection': 0,
#  'algorithm dapprentissage': 0,
#  'coclustering': 0,
#  'meilleur resultat': 0,
#  'programmation logique': 0,
#  'entrer donnee': 0,
#  'darticl': 0,
#  'grâce algorithme': 0,
#  'dense': 0,
#  'luire permettre': 0,
#  'extraire motif': 0,
#  'recommandation': 0,
#  'decouvrir': 0,
#  'dexperimentation': 0,
#  'present methode': 0,
#  'operation': 0,
#  'gestion connaissance': 0,
#  'dizaine': 0,
#  'resumer': 0,
#  'linterrogation': 0,
#  'visualis': 0,
#  'evolution': 0,
#  'permettre representer': 0,
#  'former regl': 0,
#  'collaboratif': 0,
#  'creation': 0,
#  'danscet article': 0,
#  'fond': 0,
#  'nousproposon': 0,
#  'obtenu': 0,
#  'survenir': 0,
#  'detection': 0,
#  'daid decision': 0,
#  'modelisation': 0,
#  'prendre decision': 0,
#  'degr': 0,
#  'doutils': 0,
#  'web semantiqu': 0,
#  'enregistrement': 0,
#  'intensif': 0,
#  'dater': 0,
#  'tre grand': 0,
#  'travail rechercher': 0,
#  'cancer': 0,
#  'destimer': 0,
#  'multicriter': 0,
#  'kmoyenne': 0,
#  'ascendant hierarchiqu': 0,
#  'mieux comprendre': 0,
#  'knn': 0,
#  'mond': 0,
#  'intelligent': 0,
#  'resultat experimentaux montrer': 0,
#  'loin': 0,
#  'securite': 0,
#  'dentrepris': 0,
#  'rapide': 0,
#  'desdonnee': 0,
#  'domaine lapprentissage': 0,
#  'repondre': 0,
#  'caractere': 0,
#  'dassociation': 0,
#  'developp': 0,
#  'proposees': 0,
#  'elevee': 0,
#  'veiller': 0,
#  'demander': 0,
#  'tot': 0,
#  'voire': 0,
#  'longueur': 0,
#  'ie': 2,
#  'entrer ensemble': 0,
#  'formel concept': 0,
#  'lindustrie': 0,
#  'caracter': 1,
#  'malheureusement': 0,
#  'comportement': 0,
#  'plateform': 2,
#  'essentiellement': 0,
#  'doptimisation': 0,
#  'bibliographique': 0,
#  'algorithm efficace': 0,
#  'decriver': 0,
#  'trace': 0,
#  'naïf': 0,
#  'assurer': 0,
#  'systematiqu': 0,
#  'synthetiser': 0,
#  'baser connaissance': 0,
#  'chronique': 0,
#  'technique': 0,
#  'meilleur': 0,
#  'france': 1,
#  'article present methode': 0,
#  'disponible': 0,
#  'validation connaissance': 0,
#  'memoir': 0,
#  'localement': 0,
#  'consist': 0,
#  'dintroduir': 0,
#  'modele generatif': 0,
#  'extraire connaissance': 0,
#  'succe': 0,
#  'metadonne': 0,
#  'poser probleme': 0,
#  'dedie': 1,
#  'regl': 0,
#  'appartenir': 0,
#  'ligne': 0,
#  'domaine dapplication': 0,
#  'expression': 0,
#  'lalgorithme': 0,
#  'assister': 0,
#  'importer': 0,
#  'protocole': 0,
#  'carte autoorganisatrice': 0,
#  'resultat issu': 0,
#  'provenir': 0,
#  'traiter grand': 0,
#  'combinaison': 0,
#  'reduire': 0,
#  'lensembl': 0,
#  'devoir permettre': 0,
#  'recommander': 0,
#  'article proposer method': 0,
#  'lextraction': 0,
#  'theoriqu': 0,
#  'structuration': 0,
#  'relever': 0,
#  'optimiser': 0,
#  'aprer': 0,
#  'qualitativement': 0,
#  'donnee numeriqu': 0,
#  'apprentissage automatique': 0,
#  'successif': 0,
#  'itemset frequent': 0,
#  'flot': 0,
#  'trer': 1,
#  'danscet article proposer': 0,
#  'ferme frequent': 0,
#  'donnee simuleer': 0,
#  'echell': 0,
#  'presentee': 0,
#  'euclidien': 0,
#  'permettre traiter': 0,
#  'determine': 0,
#  'connaissance baser': 0,
#  'lintroduction': 0,
#  'conserver': 0,
#  'factoriel correspondance afc': 0,
#  'mesurer': 0,
#  'partir ensemble': 0,
#  'dabord': 0,
#  'monder': 0,
#  'respecter': 0,
#  'devoir': 0,
#  'collectif': 0,
#  'coupl': 0,
#  'dapporter': 0,
#  'fonction croyance': 0,
#  'qualite recommandation': 0,
#  'sequenc devenement': 0,
#  'dobtenir': 0,
#  'dependance fonctionnel': 0,
#  'decd': 0,
#  'dissimilarite entrer': 0,
#  'projet anr': 0,
#  'pair': 0,
#  'methode fouiller': 0,
#  'cartographique': 0,
#  'conclure': 0,
#  'consideree': 0,
#  'numeriqu': 0,
#  'conçu': 0,
#  'presentent': 0,
#  'similarite': 0,
#  'apporter': 0,
#  'vecteur': 0,
#  'impliquer': 0,
#  'travail recent': 0,
#  'vecteur support': 0,
#  'ordre': 0,
#  'taux': 0,
#  'categoriel': 0,
#  'intervall': 0,
#  'programmation logique inductif': 0,
#  'premiere': 0,
#  'derreur': 0,
#  'resultat rechercher': 0,
#  'faire appel': 0,
#  'etudie': 0,
#  'refleter': 0,
#  'charger': 0,
#  'ditemset frequent': 0,
#  'document textuel': 0,
#  'pratique': 0,
#  'sousgraph': 0,
#  'jour': 0,
#  'suffisamment': 0,
#  'dindividus': 0,
#  'hierarchiqu': 0,
#  'diviser': 0,
#  'manipuler': 0,
#  'chercher': 0,
#  'cartographie': 0,
#  'log': 0,
#  'proposer algorithm': 0,
#  'priori': 0,
#  'particulierement': 0,
#  'darbr decision': 0,
#  'approximatif': 0,
#  'precision rappel': 0,
#  'donnee sequentiell': 0,
#  'negativ': 0,
#  'lextraction motif sequentiel': 0,
#  'proposon': 0,
#  'donner resultat': 0,
#  'detr': 0,
#  'maintenir': 0,
#  'ferme': 0,
#  'million': 0,
#  'travail proposer': 0,
#  'utilise': 0,
#  'propre': 0,
#  'couple': 0,
#  'hierarchi': 0,
#  'proposer nouvel algorithme': 0,
#  'redondant': 0,
#  'mettre placer': 0,
#  'modification': 0,
#  'constant': 0,
#  'avantage': 0,
#  'exprimer': 0,
#  'simplifier': 0,
#  'donneer luci': 0,
#  'fort': 0,
#  'donnee presenter': 0,
#  'decider': 0,
#  'dexploiter': 0,
#  'jeu dedonnee': 0,
#  'lune': 0,
#  'signatur': 0,
#  'performance': 0,
#  'priser decision': 0,
#  'pretraitement': 0,
#  'necessitent': 0,
#  'milieu': 0,
#  'enjeu': 0,
#  'iteration': 0,
#  'passage lechelle': 0,
#  'identifier': 0,
#  'munir': 0,
#  'source dinformation': 0,
#  'selection': 0,
#  'pouvoir trouver': 0,
#  'automatiquement': 0,
#  'partir': 0,
#  'selection variable': 0,
#  'lelaboration': 0,
#  'mixte': 0,
#  'serie': 0,
#  'test': 0,
#  'ressourc': 0,
#  'generalisation': 0,
#  'traduction': 0,
#  'developpee': 0,
#  'evaluer': 0,
#  'propose permettre': 0,
#  'dater stream': 0,
#  'tâcher': 0,
#  'lidentification': 0,
#  'adapte': 0,
#  'observation': 0,
#  'guid': 0,
#  'montrer lapproche': 0,
#  'international': 0,
#  'recouvrant': 0,
#  'projet': 0,
#  'situer': 0,
#  'pouvoir faire': 0,
#  'tâche': 0,
#  'degre': 0,
#  'appropriee': 0,
#  'lanalyse statistique': 0,
#  'seuil': 0,
#  'topologique': 0,
#  'variation': 0,
#  'massif': 0,
#  'expliciter': 0,
#  'lespace': 0,
#  'owl': 0,
#  'permettre visualiser': 0,
#  'article montrer': 0,
#  'faciliter': 0,
#  'sest': 0,
#  'gen': 0,
#  'discriminer': 0,
#  'donneer textuel': 0,
#  'appel': 0,
#  'definissons': 0,
#  'article interesser': 0,
#  'faire lobjet': 0,
#  'susceptible': 0,
#  'frequence': 0,
#  'plaire important': 0,
#  'fixe': 0,
#  'inspiree': 0,
#  'selectionn': 0,
#  'contextuel': 0,
#  'diversite': 0,
#  'methode': 0,
#  'grand ensembl': 0,
#  'libre': 0,
#  'fiable': 0,
#  'matrice': 0,
#  'central': 0,
#  'systeme recommandation': 0,
#  'representation connaissance': 0,
#  'plaire complexe': 0,
#  'donnee relationnel': 0,
#  'sequence': 0,
#  'algorithme ete': 0,
#  'machiner': 0,
#  'connaître': 0,
#  'lextraction regl dassociation': 0,
#  'quon': 0,
#  'surl': 0,
#  'groupement': 0,
#  'cadrer general': 0,
#  'cas': 1,
#  'developpement': 0,
#  'experimentation jeu donnee': 0,
#  'analyser semantiqu': 0,
#  'theorie': 0,
#  'etudier': 0,
#  'objet': 0,
#  'segmentation': 0,
#  'etle': 0,
#  'contrairement': 0,
#  'source donnee': 0,
#  'dispositif': 0,
#  'ontologie': 0,
#  'frequente': 0,
#  'verifier': 0,
#  'mettre': 1,
#  'issu': 0,
#  'fusion': 0,
#  'graphe voisinage': 0,
#  'sappuie': 0,
#  'robustesse': 0,
#  'interessant': 0,
#  'donnees': 0,
#  'ensembl': 0,
#  'lanalyse exploratoire': 0,
#  'mem': 1,
#  'permettre didentifier': 0,
#  'minimiser': 0,
#  'virtuel': 0,
#  'diagnostic': 0,
#  'analytique': 0,
#  'standard': 0,
#  'comparee': 0,
#  'lanalyse': 1,
#  'laplacien': 0,
#  'ete propos': 0,
#  'resolu': 0,
#  'facile': 0,
#  'reseaux': 0,
#  'contenir document': 0,
#  'proposee': 0,
#  'experimentalement': 0,
#  'reduiser': 0,
#  'trouver': 0,
#  'utile': 0,
#  'concerner': 0,
#  'regler': 0,
#  'français': 0,
#  'prometteur': 0,
#  'classification automatique': 0,
#  'court': 0,
#  'mesurer similarit': 0,
#  'donnee artificiel': 0,
#  'concepteur': 0,
#  'processus dextraction': 0,
#  'papier present': 0,
#  'classe': 0,
#  'fixer': 0,
#  'amont': 0,
#  'constater': 0,
#  'correspondance': 0,
#  'performance predictiv': 0,
#  'source': 0,
#  'bayesienn': 0,
#  'ditemset': 0,
#  'connu': 0,
#  'grâce': 0,
#  'machine': 0,
#  'marge': 0,
#  'realiser': 0,
#  'neuron': 0,
#  'distinguer': 0,
#  'grand echelle': 0,
#  'devenir': 0,
#  'encourageant prometteur': 0,
#  'reseaux neuron': 0,
#  'centrer': 0,
#  'pendre': 0,
#  'contrainte': 0,
#  'presenter': 0,
#  'grapher': 0,
#  'acce': 0,
#  'donnee textuel': 0,
#  'donnee cluster': 0,
#  'specifiquement': 0,
#  'represent': 0,
#  'arborescent': 0,
#  'entrer': 1,
#  'stockeer': 0,
#  'referentiel': 0,
#  'litterature': 0,
#  'linfluence': 0,
#  'mieux': 0,
#  'confronter': 0,
#  'echelle': 0,
#  'didentification': 0,
#  'partition': 0,
#  'doutil': 0,
#  'cluster': 0,
#  'lapprentissage automatique': 0,
#  'entrer ontologie': 0,
#  'limage': 0,
#  'separateur': 0,
#  'extraite': 0,
#  'environnement': 0,
#  'dautre': 0,
#  'fondre': 0,
#  'concret': 0,
#  'interaction entrer': 0,
#  'extraction connaissance': 0,
#  'raisonnement': 0,
#  'mettre jour': 0,
#  'lajout': 0,
#  'souligner': 0,
#  'manuellemer': 0,
#  'implemente': 0,
#  'perspectif': 0,
#  'lecart': 0,
#  'markov': 0,
#  'document': 0,
#  'variable cibl': 0,
#  'generaliser': 0,
#  'apprendre': 0,
#  'historique': 0,
#  'dechantillonnage': 0,
#  'laclassification': 0,
#  'lie': 0,
#  'appelee': 0,
#  'logique inductif': 0,
#  'examiner': 0,
#  'proposer article': 0,
#  'cibler': 0,
#  'analyse': 2,
#  'som': 0,
#  'comparatif': 0,
#  'operateur': 0,
#  'propos': 0,
#  'partir document': 0,
#  'parametriqu': 0,
#  'scor': 0,
#  'supplementair': 0,
#  'vivre': 0,
#  'graphe': 0,
#  'resoudre probleme': 0,
#  'guider': 0,
#  'ressortir': 0,
#  'cognitif': 0,
#  'groupe': 0,
#  'choix mesurer': 0,
#  'itemset': 0,
#  'proposer permettre': 0,
#  'actuellement': 0,
#  'classification document': 0,
#  'fiabilite': 0,
#  'enrichissement': 0,
#  'thematiqu': 0,
#  'illustree': 0,
#  'lanalyse donnee': 0,
#  'methode existant': 0,
#  'formalisme': 0,
#  'categorisation': 0,
#  'participatif': 0,
#  'support': 0,
#  'introduire notion': 0,
#  'donnee permettre': 0,
#  'gene': 0,
#  'profiter': 0,
#  'reel': 1,
#  'montrer linteret': 0,
#  'procedure': 0,
#  'volee': 0,
#  'exemple': 0,
#  'venir': 0,
#  'facteur': 0,
#  'factoriel correspondance': 0,
#  'proposer nouvel': 0,
#  'dameliorer performance': 0,
#  'patron': 0,
#  'phraser': 0,
#  'integrer': 0,
#  'permettre decouvrir': 0,
#  'comparaison': 1,
#  'method permettre': 0,
#  'gestion flux donneer': 0,
#  'decis': 0,
#  'experimentation': 0,
#  'clustering': 0,
#  'avancee': 0,
#  'principalement': 0,
#  'graph': 0,
#  'pouvoir prendre': 0,
#  'desequilibre': 0,
#  'eclairage': 0,
#  'propose': 0,
#  'caracteriser': 0,
#  'interesser': 0,
#  'lexperimentation': 0,
#  'conditionnel': 0,
#  'inclure': 0,
#  'dutilisateur': 0,
#  'permettre meilleur': 0,
#  'devenement': 1,
#  'annees': 0,
#  'mesurer proximite': 0,
#  'sens': 0,
#  'mediation': 0,
#  'afc': 0,
#  'plaire grand': 0,
#  'lapproche propose': 0,
#  'lextraction motif': 0,
#  'dannotation': 0,
#  'reconnaissance': 0,
#  'sou former regl': 0,
#  'dindice': 0,
#  'passer': 0,
#  'arbre decision': 0,
#  'multitabl': 0,
#  'disposer': 0,
#  'categorie': 0,
#  'public': 0,
#  'ponder': 0,
#  'produire': 0,
#  'donnee reel': 0,
#  'eter': 0,
#  'cesser': 0,
#  'compact': 0,
#  'pedagogiqu': 0,
#  'calcul': 0,
#  'donnee article': 0,
#  'context': 0,
#  'specifier': 0,
#  'lefficacite': 0,
#  'dobjet': 0,
#  'exploiter': 0,
#  'biologique': 0,
#  'discuter': 0,
#  'prediction': 0,
#  'mutuel': 0,
#  'interpreter': 0,
#  'simultanee': 0,
#  'presente': 0,
#  'utilisee': 0,
#  'dynamique': 0,
#  'dimag': 0,
#  'p2p': 0,
#  'approximation': 0,
#  'voisinage': 0,
#  'poindre': 0,
#  'temps': 1,
#  'fonction': 0,
#  'presenter nouvel algorithme': 0,
#  'reponse requete': 0,
#  'represente': 0,
#  'structurer': 0,
#  'method propose': 0,
#  'positionner': 0,
#  'deuxieme': 0,
#  'partir ensembl': 0,
#  'exploitable': 0,
#  'type': 0,
#  'courir temps': 0,
#  'mod': 0,
#  'deffectuer': 0,
#  'consommation': 0,
#  'langage': 0,
#  'fonctionnalite': 0,
#  'primordial': 0,
#  'detectiond': 0,
#  'grand quantite': 0,
#  'detude': 0,
#  'grand graphe': 0,
#  'denrichir': 0,
#  'difficult': 0,
#  'representation donnee': 0,
#  'espace': 0,
#  'indicateur': 0,
#  'wikipedia': 0,
#  'intuitif': 0,
#  'mettre oeuvrer': 0,
#  'partir donnee': 0,
#  'agregation': 0,
#  'reseau': 0,
#  'compatible': 0,
#  'similarite entrer': 0,
#  'savoir': 0,
#  ...}

# %%
# nb_word[num_partition][word]
nb_word = []

word_in_this_parti = {}
for word in vectorizer.get_feature_names():
    word_in_this_parti[word] = 0

for numDoc in range(0, len(usable)):
    for word in vectorizer.get_feature_names():
        word_in_this_parti[word] += tf[numDoc][word]
    if numDoc+1 in limits:
        nb_word.append(word_in_this_parti)
        word_in_this_parti = {}
        for word in vectorizer.get_feature_names():
            word_in_this_parti[word] = 0

# %%
len(nb_word)
# Out:
# 4

# %%
# nb_word_by_cluster[numPartition][numCluster]
nb_word_by_cluster = []
for parti in partitions:
    nb_word_clus = []
    for cluster in parti:
        nb = 0
        for numDoc in cluster:
            for word in vectorizer.get_feature_names():
                nb += tf[numDoc][word]
        nb_word_clus.append(nb)
    nb_word_by_cluster.append(nb_word_clus)

# %%
# Expected values, if nothing were dependant
# exp[numPartition][numCluster][numWord]
#exp = []
#for numParti in range(0, len(partitions)):
#    exp_clus = []
#    for numCluster in range(0, len(partitions[numParti])):
#        exp_word = []
#        for numWord in range(0, vectorizer.get_feature_names()):
#            exp_word.append((nb_word[numParti][numWord] + nb_word_by_cluster[numPart][numCluster]) / nb_total_word[numParti])
#        exp_cluster.append(exp_word)
#    exp.append(exp_clus)

# %%
# value_of_khi2 = khi2[numPartition][numCluster][word]
khi2 = []

for numParti in range(0, len(partitions)):
    khi2parti = []
    for numCluster in range(0, len(partitions[numParti])):
        khi2cluster = {}
        
        for word in vectorizer.get_feature_names():
            word_in_this_parti[word] = 0
            E = nb_word[numParti][word]
            E =+ nb_word_by_cluster[numParti][numCluster]
            E = E/ nb_total_word[numParti]
            N = 0
            for numDoc in partitions[numParti][numCluster]:
                N += tf[numDoc][word]
            khi2cluster[word] = (pow(N - E, 2)/E)        
        khi2parti.append(khi2cluster)
    khi2.append(khi2parti)

# %%
# list of your labels = labels[numPartition][numCluster]
labels = []

for numPartition in range(0, len(nb_word_by_cluster)):
    label_clus = []
    for numCluster in range(0, len(nb_word_by_cluster[numPartition])):
        label_clus.append(Counter(khi2[numPartition][numCluster]).most_common(5))
    labels.append(label_clus)

# %%
labels
# Out:
# [[[('pr', 42080.27806668308),
#    ('eg', 33004.46930174283),
#    ('tr', 30907.5589431771),
#    ('regl', 19771.248186204986),
#    ('ie', 18156.054959113353)],
#   [('tr', 174743.52810179634),
#    ('an', 90624.85949503025),
#    ('al', 76300.19598102516),
#    ('ex', 72433.636504852),
#    ('or', 63207.0741185297)],
#   [('an', 209832.28105224724),
#    ('tr', 172527.30569435),
#    ('or', 163195.48123999656),
#    ('pr', 118459.83327003644),
#    ('ex', 82502.59318554922)],
#   [('tr', 140878.94964208183),
#    ('pr', 129994.88429253777),
#    ('al', 109539.2915873706),
#    ('an', 89059.448122325),
#    ('or', 87302.6472104709)],
#   [('pr', 1215317.6342542265),
#    ('tr', 1049592.5468472126),
#    ('an', 903048.0728833444),
#    ('al', 735355.3590151191),
#    ('or', 679198.684998116)]],
#  [[('eg', 104241.54173473154),
#    ('tr', 98015.71850240829),
#    ('an', 64686.20335089313),
#    ('regl', 64686.20335089313),
#    ('pr', 44217.66925998404)],
#   [('tr', 355369.1923770508),
#    ('pr', 140251.94412628125),
#    ('ie', 116902.56265412898),
#    ('or', 108157.6670481956),
#    ('ex', 83962.4898861469)],
#   [('pr', 202539.43413828756),
#    ('an', 194962.65823976745),
#    ('tr', 177845.20158014802),
#    ('or', 131211.00327147995),
#    ('ie', 95116.47430742075)],
#   [('pr', 356971.633258645),
#    ('tr', 291926.4522151407),
#    ('cl', 193825.96783780478),
#    ('or', 163641.42904276814),
#    ('al', 143128.89084572822)],
#   [('tr', 1123315.5547473643),
#    ('pr', 1056552.5842169125),
#    ('an', 783786.4604448103),
#    ('al', 746492.9437453997),
#    ('or', 625229.3255397677)]],
#  [[('tr', 92323.64067016439),
#    ('pr', 59888.09823474002),
#    ('eg', 55825.23687469785),
#    ('ie', 44492.83413352758),
#    ('regl', 41000.76033278957)],
#   [('tr', 167864.00896194248),
#    ('ex', 45734.33330283766),
#    ('motif', 43806.93967929382),
#    ('ie', 38273.71282460345),
#    ('pr', 38273.71282460345)],
#   [('an', 223918.03004709858),
#    ('tr', 200711.5821851331),
#    ('pr', 174539.1950883589),
#    ('ie', 103717.41489331017),
#    ('al', 100497.6346982614)],
#   [('pr', 239394.5819026529),
#    ('al', 180049.2581616457),
#    ('cl', 171668.22883126384),
#    ('or', 161472.82484675915),
#    ('tr', 155505.3865512417)],
#   [('tr', 861013.3545886575),
#    ('pr', 777693.3865481585),
#    ('al', 562994.8694690011),
#    ('an', 529937.6123100729),
#    ('or', 454325.84881037974)]],
#  [[('eg', 266395.12044695136),
#    ('tr', 266395.12044695136),
#    ('regl', 192686.6351074452),
#    ('an', 179877.53499170448),
#    ('pr', 174877.24023861808)],
#   [('tr', 340239.85944468214),
#    ('pr', 112786.44636224482),
#    ('or', 103081.43083058413),
#    ('motif', 87148.07808267494),
#    ('al', 70575.55717467016)],
#   [('an', 537051.8777710599),
#    ('tr', 491931.9414971786),
#    ('pr', 260304.88354103046),
#    ('or', 222294.595042505),
#    ('al', 161043.37116764925)],
#   [('pr', 394133.55255962606),
#    ('tr', 344695.6327182438),
#    ('al', 301355.36434265965),
#    ('or', 266148.2768196459),
#    ('an', 248096.18292359717)],
#   [('pr', 1251976.9775820784),
#    ('tr', 1223307.1433286788),
#    ('an', 794365.8076615185),
#    ('al', 784190.0877207617),
#    ('or', 693174.3206097704)]]]
